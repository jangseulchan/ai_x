# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:98% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:20pt;}
div.text_cell_render.rendered_html{font-size:18pt;}
div.text_cell_render.rendered_html{font-size:15pt;}
div.output {font-size:18pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:18pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:18pt;padding:5px;}
table.dataframe{font-size:18px;}
</style>
"""))
# Out:
# <style>
# div.container{width:98% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:20pt;}
# div.text_cell_render.rendered_html{font-size:18pt;}
# div.text_cell_render.rendered_html{font-size:15pt;}
# div.output {font-size:18pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:18pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:18pt;padding:5px;}
# table.dataframe{font-size:18px;}
# </style>

# %% [markdown]
# # 1. 환경(패키지 및 환경변수)
# - pip install openai langchain-openai

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # 2. LLM 답변 생성
# ## 2.1 openAI SDK 를 선택
# - 세밀한 제어가 필요할 때, 성능 최적화가 중요할 때

# %%
from openai import OpenAI
client = OpenAI()
response = client.chat.completions.create(
    model="gpt-4.1-nano",
    messages = [
        {"role":"system", "content":"너는 친절하게 대답해 주는 비서야"},
        {"role":"user",   "content":"2020년 월드 시리즈 누가 우승했어?"}
    ]
)

# %%
response.choices[0].message.content
# Out:
# '2020년 월드 시리즈는 야구 팀인 로스앤젤레스 다저스가 우승했습니다. 다저스는 텍사스 Rangers를 상대로 시리즈에서 승리하여 32년 만에 우승을 차지했습니다.'

# %% [markdown]
# ## 2.2 LangChain을 선택
# - 내부적으로 자동 메세지 형태를 변환해 줌

# %%
from langchain_openai import ChatOpenAI
# .env OPEN_API_KEY가 등록
llm = ChatOpenAI(
    model="gpt-4.1-nano" # 기본 모델 : gpt-3.5-turbo
)
ai_message = llm.invoke("2020년 월드 시리즈 누가 우승했나요?")

# %%
ai_message.content
# Out:
# '2020년 월드 시리즈는 워싱턴 내셔널스가 우승했습니다. 내셔널스는 샌프란시스코 자이언츠를 4승 3패로 이기고, 최초로 월드 시리즈 정상을 차지했어요.'
