# %% [markdown]
# # 4개 모델 성능 비교
# ```
# 4개 모델 성능 비교표
#
#     모델	Accuracy	Recall (flood=1)	ROC AUC
# RandomForest	0.9811	         0.8000	                0.9843
# XGBoost     	0.9641	         0.8765              	0.9775
# LSTM+CNN	0.5873	         0.8642              	0.7688
# Transformer	0.7299	         0.6790              	0.7812
#
# 해석 요약
# RandomForest: 전체적으로 가장 안정적. Accuracy, Recall, ROC AUC 모두 우수.
#
# XGBoost: 침수 예측(Recall)에 가장 뛰어남. 성능 균형 좋음.
#
# LSTM+CNN: Accuracy는 낮지만 Recall은 높아, 침수 감지엔 민감한 편.
#
# Transformer: Recall은 나쁘지 않지만 Precision이 낮고 전체 정확도도 낮은 편.
# ```

# %%
import matplotlib.pyplot as plt

models = ["RandomForest", "XGBoost", "LSTM+CNN", "Transformer"]
accuracy = [0.9811, 0.9641, 0.5873, 0.7299]
recall = [0.8000, 0.8765, 0.8642, 0.6790]
roc_auc = [0.9843, 0.9775, 0.7688, 0.7812]

plt.figure(figsize=(10, 6))
x = range(len(models))

plt.bar(x, accuracy, width=0.2, label="Accuracy", align="center")
plt.bar([i + 0.2 for i in x], recall, width=0.2, label="Recall (Flood)", align="center")
plt.bar([i + 0.4 for i in x], roc_auc, width=0.2, label="ROC AUC", align="center")

plt.xticks([i + 0.2 for i in x], models)
plt.ylim(0, 1.05)
plt.title("Flood Prediction Model Comparison (Daily Data)")
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.savefig("daily_model_comparison.png")
plt.show()

# %% [markdown]
# # 한글설정, 워닝제거

# %%
# 한글설정
import matplotlib.pyplot as plt
import matplotlib
plt.rcParams['font.family'] = 'Malgun Gothic'  # Windows용 한글 폰트
plt.rcParams['axes.unicode_minus'] = False     # 마이너스(-) 깨짐 방지

#워닝 제거
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # api key 활용 및 데이터 수집

# %%
import os
from dotenv import load_dotenv
OPENWEATHER_API_KEY = load_dotenv('.env')
OPENWEATHER_API_KEY = os.getenv('OPENWEATHER_API_KEY')
# print(os.getenv('OPENWEATHER_API_KEY'))

# %% [markdown]
# # 데이터 수집하기

# %%
import os
import time
import requests
import pandas as pd
import datetime
import schedule

#  사용자 설정
SERVICE_KEY = os.getenv("OPENWEATHER_API_KEY")
CSV_FILE = 'asos_seoul_daily.csv'
STN_ID = 108
NUM_OF_ROWS = 100
API_URL = "http://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList"

START_DATE = datetime.date(2000, 1, 10)
END_DATE = datetime.date.today() - datetime.timedelta(days=1)

#  기존 날짜 로드
def load_existing_dates():
    if not os.path.exists(CSV_FILE):
        return set()
    df = pd.read_csv(CSV_FILE)
    return set(pd.to_datetime(df['tm']).dt.date.astype(str))

#  하루치 수집 함수
def fetch_day_data(date_obj):
    params = {
        'serviceKey': SERVICE_KEY,
        'numOfRows': NUM_OF_ROWS,
        'pageNo': 1,
        'dataCd': 'ASOS',
        'dateCd': 'DAY',
        'startDt': date_obj.strftime("%Y%m%d"),
        'endDt': date_obj.strftime("%Y%m%d"),
        'stnIds': STN_ID,
        'dataType': 'JSON'
    }

    try:
        response = requests.get(API_URL, params=params, timeout=60)
        response.raise_for_status()
        data = response.json()
        items = data['response']['body']['items'].get('item', [])
        return items
    except Exception as e:
        print(f"❌ [{date_obj}] 에러 발생: {e}")
        return []

#  결측치 많은 컬럼 자동 제거 및 저장
def append_to_csv(items):
    if not items:
        return

    df = pd.DataFrame(items)

    useful_columns = [
        'tm', 'avgTa', 'minTa', 'maxTa', 'sumRn', 'avgWs', 'avgRhm',
        'avgTs', 'ddMefs', 'sumGsr', 'maxInsWs', 'hr3Fhsc',
        'sumSmlEv', 'avgTd', 'avgPs'
    ]
    df = df[[col for col in useful_columns if col in df.columns]]

    #  결측치가 5% 이상인 컬럼 제거
    missing_ratio = df.isna().mean()
    keep_cols = missing_ratio[missing_ratio < 0.05].index.tolist()
    df = df[keep_cols]

    # CSV 저장
    write_header = not os.path.exists(CSV_FILE)
    df.to_csv(CSV_FILE, mode='a', header=write_header, index=False)

#  마지막 수집일 이후로 수집
def get_last_collected_date():
    if not os.path.exists(CSV_FILE):
        return START_DATE
    df = pd.read_csv(CSV_FILE)
    last_date = pd.to_datetime(df['tm']).max().date()
    return last_date + datetime.timedelta(days=1)

#  전체 수집 프로세스
def job():
    existing_dates = load_existing_dates()
    current_date = get_last_collected_date()

    while current_date <= END_DATE:
        if str(current_date) in existing_dates:
            current_date += datetime.timedelta(days=1)
            continue

        items = fetch_day_data(current_date)
        append_to_csv(items)

        print(f" [{current_date}] 저장 완료")
        current_date += datetime.timedelta(days=1)
        time.sleep(0.3)

#  최초 실행
job()

#  매시간마다 자동 실행
schedule.every(1).hours.do(job)
print(" 자동 수집 대기 중...")
while True:
    schedule.run_pending()
    time.sleep(60)
# Out:
#  [2005-04-29] 저장 완료
#  [2005-04-30] 저장 완료
#  [2005-05-01] 저장 완료
#  [2005-05-02] 저장 완료
#  [2005-05-03] 저장 완료
#  [2005-05-04] 저장 완료
#  [2005-05-05] 저장 완료
#  [2005-05-06] 저장 완료
#  [2005-05-07] 저장 완료
#  [2005-05-08] 저장 완료
#  [2005-05-09] 저장 완료
#  [2005-05-10] 저장 완료
#  [2005-05-11] 저장 완료
#  [2005-05-12] 저장 완료
#  [2005-05-13] 저장 완료
#  [2005-05-14] 저장 완료
#  [2005-05-15] 저장 완료
#  [2005-05-16] 저장 완료
#  [2005-05-17] 저장 완료
#  [2005-05-18] 저장 완료
#  [2005-05-19] 저장 완료
#  [2005-05-20] 저장 완료
#  [2005-05-21] 저장 완료
#  [2005-05-22] 저장 완료
#  [2005-05-23] 저장 완료
#  [2005-05-24] 저장 완료
#  [2005-05-25] 저장 완료
#  [2005-05-26] 저장 완료
#  [2005-05-27] 저장 완료
#  [2005-05-28] 저장 완료
#  [2005-05-29] 저장 완료
#  [2005-05-30] 저장 완료
#  [2005-05-31] 저장 완료
#  [2005-06-01] 저장 완료
#  [2005-06-02] 저장 완료
#  [2005-06-03] 저장 완료
#  [2005-06-04] 저장 완료
#  [2005-06-05] 저장 완료
#  [2005-06-06] 저장 완료
#  [2005-06-07] 저장 완료
#  [2005-06-08] 저장 완료
#  [2005-06-09] 저장 완료
#  [2005-06-10] 저장 완료
#  [2005-06-11] 저장 완료
#  [2005-06-12] 저장 완료
#  [2005-06-13] 저장 완료
#  [2005-06-14] 저장 완료
#  [2005-06-15] 저장 완료
#  [2005-06-16] 저장 완료
#  [2005-06-17] 저장 완료
#  [2005-06-18] 저장 완료
#  [2005-06-19] 저장 완료
#  [2005-06-20] 저장 완료
#  [2005-06-21] 저장 완료
#  [2005-06-22] 저장 완료
#  [2005-06-23] 저장 완료
#  [2005-06-24] 저장 완료
#  [2005-06-25] 저장 완료
#  [2005-06-26] 저장 완료
#  [2005-06-27] 저장 완료
#  [2005-06-28] 저장 완료
#  [2005-06-29] 저장 완료
#  [2005-06-30] 저장 완료
#  [2005-07-01] 저장 완료
#  [2005-07-02] 저장 완료
#  [2005-07-03] 저장 완료
#  [2005-07-04] 저장 완료
#  [2005-07-05] 저장 완료
#  [2005-07-06] 저장 완료
#  [2005-07-07] 저장 완료
#  [2005-07-08] 저장 완료
#  [2005-07-09] 저장 완료
#  [2005-07-10] 저장 완료
#  [2005-07-11] 저장 완료
#  [2005-07-12] 저장 완료
#  [2005-07-13] 저장 완료
#  [2005-07-14] 저장 완료
#  [2005-07-15] 저장 완료
#  [2005-07-16] 저장 완료
#  [2005-07-17] 저장 완료
#  [2005-07-18] 저장 완료
#  [2005-07-19] 저장 완료
#  [2005-07-20] 저장 완료
#  [2005-07-21] 저장 완료
#  [2005-07-22] 저장 완료
#  [2005-07-23] 저장 완료
#  [2005-07-24] 저장 완료
#  [2005-07-25] 저장 완료
#  [2005-07-26] 저장 완료
#  [2005-07-27] 저장 완료
#  [2005-07-28] 저장 완료
#  [2005-07-29] 저장 완료
#  [2005-07-30] 저장 완료
#  [2005-07-31] 저장 완료
#  [2005-08-01] 저장 완료
#  [2005-08-02] 저장 완료
#  [2005-08-03] 저장 완료
#  [2005-08-04] 저장 완료
#  [2005-08-05] 저장 완료
#  [2005-08-06] 저장 완료
#  [2005-08-07] 저장 완료
#  [2005-08-08] 저장 완료
#  [2005-08-09] 저장 완료
#  [2005-08-10] 저장 완료
#  [2005-08-11] 저장 완료
#  [2005-08-12] 저장 완료
#  [2005-08-13] 저장 완료
#  [2005-08-14] 저장 완료
#  [2005-08-15] 저장 완료
#  [2005-08-16] 저장 완료
#  [2005-08-17] 저장 완료
#  [2005-08-18] 저장 완료
#  [2005-08-19] 저장 완료
#  [2005-08-20] 저장 완료
#  [2005-08-21] 저장 완료
#  [2005-08-22] 저장 완료
#  [2005-08-23] 저장 완료
#  [2005-08-24] 저장 완료
#  [2005-08-25] 저장 완료
#  [2005-08-26] 저장 완료
#  [2005-08-27] 저장 완료
#  [2005-08-28] 저장 완료
#  [2005-08-29] 저장 완료
#  [2005-08-30] 저장 완료
#  [2005-08-31] 저장 완료
#  [2005-09-01] 저장 완료
#  [2005-09-02] 저장 완료
#  [2005-09-03] 저장 완료
#  [2005-09-04] 저장 완료
#  [2005-09-05] 저장 완료
#  [2005-09-06] 저장 완료
#  [2005-09-07] 저장 완료
#  [2005-09-08] 저장 완료
#  [2005-09-09] 저장 완료
#  [2005-09-10] 저장 완료
#  [2005-09-11] 저장 완료
#  [2005-09-12] 저장 완료
#  [2005-09-13] 저장 완료
#  [2005-09-14] 저장 완료
#  [2005-09-15] 저장 완료
#  [2005-09-16] 저장 완료
#  [2005-09-17] 저장 완료
#  [2005-09-18] 저장 완료
#  [2005-09-19] 저장 완료
#  [2005-09-20] 저장 완료
#  [2005-09-21] 저장 완료
#  [2005-09-22] 저장 완료
#  [2005-09-23] 저장 완료
#  [2005-09-24] 저장 완료
#  [2005-09-25] 저장 완료
#  [2005-09-26] 저장 완료
#  [2005-09-27] 저장 완료
#  [2005-09-28] 저장 완료
#  [2005-09-29] 저장 완료
#  [2005-09-30] 저장 완료
#  [2005-10-01] 저장 완료
#  [2005-10-02] 저장 완료
#  [2005-10-03] 저장 완료
#  [2005-10-04] 저장 완료
#  [2005-10-05] 저장 완료
#  [2005-10-06] 저장 완료
#  [2005-10-07] 저장 완료
#  [2005-10-08] 저장 완료
#  [2005-10-09] 저장 완료
#  [2005-10-10] 저장 완료
#  [2005-10-11] 저장 완료
# ❌ [2005-10-12] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2005-10-12] 저장 완료
#  [2005-10-13] 저장 완료
#  [2005-10-14] 저장 완료
#  [2005-10-15] 저장 완료
#  [2005-10-16] 저장 완료
#  [2005-10-17] 저장 완료
#  [2005-10-18] 저장 완료
#  [2005-10-19] 저장 완료
#  [2005-10-20] 저장 완료
#  [2005-10-21] 저장 완료
#  [2005-10-22] 저장 완료
#  [2005-10-23] 저장 완료
#  [2005-10-24] 저장 완료
#  [2005-10-25] 저장 완료
#  [2005-10-26] 저장 완료
#  [2005-10-27] 저장 완료
#  [2005-10-28] 저장 완료
#  [2005-10-29] 저장 완료
#  [2005-10-30] 저장 완료
#  [2005-10-31] 저장 완료
#  [2005-11-01] 저장 완료
#  [2005-11-02] 저장 완료
#  [2005-11-03] 저장 완료
#  [2005-11-04] 저장 완료
#  [2005-11-05] 저장 완료
#  [2005-11-06] 저장 완료
#  [2005-11-07] 저장 완료
#  [2005-11-08] 저장 완료
#  [2005-11-09] 저장 완료
#  [2005-11-10] 저장 완료
#  [2005-11-11] 저장 완료
#  [2005-11-12] 저장 완료
#  [2005-11-13] 저장 완료
#  [2005-11-14] 저장 완료
#  [2005-11-15] 저장 완료
#  [2005-11-16] 저장 완료
#  [2005-11-17] 저장 완료
#  [2005-11-18] 저장 완료
#  [2005-11-19] 저장 완료
#  [2005-11-20] 저장 완료
#  [2005-11-21] 저장 완료
#  [2005-11-22] 저장 완료
#  [2005-11-23] 저장 완료
#  [2005-11-24] 저장 완료
#  [2005-11-25] 저장 완료
#  [2005-11-26] 저장 완료
#  [2005-11-27] 저장 완료
#  [2005-11-28] 저장 완료
#  [2005-11-29] 저장 완료
#  [2005-11-30] 저장 완료
#  [2005-12-01] 저장 완료
#  [2005-12-02] 저장 완료
#  [2005-12-03] 저장 완료
#  [2005-12-04] 저장 완료
#  [2005-12-05] 저장 완료
#  [2005-12-06] 저장 완료
#  [2005-12-07] 저장 완료
#  [2005-12-08] 저장 완료
#  [2005-12-09] 저장 완료
#  [2005-12-10] 저장 완료
#  [2005-12-11] 저장 완료
#  [2005-12-12] 저장 완료
#  [2005-12-13] 저장 완료
#  [2005-12-14] 저장 완료
#  [2005-12-15] 저장 완료
#  [2005-12-16] 저장 완료
#  [2005-12-17] 저장 완료
#  [2005-12-18] 저장 완료
#  [2005-12-19] 저장 완료
#  [2005-12-20] 저장 완료
#  [2005-12-21] 저장 완료
#  [2005-12-22] 저장 완료
#  [2005-12-23] 저장 완료
#  [2005-12-24] 저장 완료
#  [2005-12-25] 저장 완료
#  [2005-12-26] 저장 완료
#  [2005-12-27] 저장 완료
#  [2005-12-28] 저장 완료
#  [2005-12-29] 저장 완료
#  [2005-12-30] 저장 완료
#  [2005-12-31] 저장 완료
#  [2006-01-01] 저장 완료
#  [2006-01-02] 저장 완료
#  [2006-01-03] 저장 완료
#  [2006-01-04] 저장 완료
#  [2006-01-05] 저장 완료
#  [2006-01-06] 저장 완료
#  [2006-01-07] 저장 완료
#  [2006-01-08] 저장 완료
#  [2006-01-09] 저장 완료
#  [2006-01-10] 저장 완료
#  [2006-01-11] 저장 완료
#  [2006-01-12] 저장 완료
#  [2006-01-13] 저장 완료
#  [2006-01-14] 저장 완료
#  [2006-01-15] 저장 완료
#  [2006-01-16] 저장 완료
#  [2006-01-17] 저장 완료
#  [2006-01-18] 저장 완료
#  [2006-01-19] 저장 완료
#  [2006-01-20] 저장 완료
#  [2006-01-21] 저장 완료
#  [2006-01-22] 저장 완료
#  [2006-01-23] 저장 완료
#  [2006-01-24] 저장 완료
#  [2006-01-25] 저장 완료
#  [2006-01-26] 저장 완료
#  [2006-01-27] 저장 완료
#  [2006-01-28] 저장 완료
#  [2006-01-29] 저장 완료
#  [2006-01-30] 저장 완료
#  [2006-01-31] 저장 완료
#  [2006-02-01] 저장 완료
#  [2006-02-02] 저장 완료
#  [2006-02-03] 저장 완료
#  [2006-02-04] 저장 완료
#  [2006-02-05] 저장 완료
#  [2006-02-06] 저장 완료
#  [2006-02-07] 저장 완료
#  [2006-02-08] 저장 완료
#  [2006-02-09] 저장 완료
#  [2006-02-10] 저장 완료
#  [2006-02-11] 저장 완료
#  [2006-02-12] 저장 완료
#  [2006-02-13] 저장 완료
#  [2006-02-14] 저장 완료
#  [2006-02-15] 저장 완료
#  [2006-02-16] 저장 완료
#  [2006-02-17] 저장 완료
#  [2006-02-18] 저장 완료
#  [2006-02-19] 저장 완료
#  [2006-02-20] 저장 완료
#  [2006-02-21] 저장 완료
#  [2006-02-22] 저장 완료
#  [2006-02-23] 저장 완료
#  [2006-02-24] 저장 완료
#  [2006-02-25] 저장 완료
#  [2006-02-26] 저장 완료
#  [2006-02-27] 저장 완료
#  [2006-02-28] 저장 완료
#  [2006-03-01] 저장 완료
#  [2006-03-02] 저장 완료
#  [2006-03-03] 저장 완료
#  [2006-03-04] 저장 완료
#  [2006-03-05] 저장 완료
#  [2006-03-06] 저장 완료
#  [2006-03-07] 저장 완료
#  [2006-03-08] 저장 완료
#  [2006-03-09] 저장 완료
#  [2006-03-10] 저장 완료
#  [2006-03-11] 저장 완료
#  [2006-03-12] 저장 완료
#  [2006-03-13] 저장 완료
#  [2006-03-14] 저장 완료
#  [2006-03-15] 저장 완료
#  [2006-03-16] 저장 완료
# ❌ [2006-03-17] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2006-03-17] 저장 완료
#  [2006-03-18] 저장 완료
#  [2006-03-19] 저장 완료
#  [2006-03-20] 저장 완료
#  [2006-03-21] 저장 완료
#  [2006-03-22] 저장 완료
#  [2006-03-23] 저장 완료
#  [2006-03-24] 저장 완료
#  [2006-03-25] 저장 완료
#  [2006-03-26] 저장 완료
#  [2006-03-27] 저장 완료
#  [2006-03-28] 저장 완료
#  [2006-03-29] 저장 완료
#  [2006-03-30] 저장 완료
#  [2006-03-31] 저장 완료
#  [2006-04-01] 저장 완료
#  [2006-04-02] 저장 완료
#  [2006-04-03] 저장 완료
#  [2006-04-04] 저장 완료
#  [2006-04-05] 저장 완료
#  [2006-04-06] 저장 완료
#  [2006-04-07] 저장 완료
#  [2006-04-08] 저장 완료
#  [2006-04-09] 저장 완료
#  [2006-04-10] 저장 완료
#  [2006-04-11] 저장 완료
#  [2006-04-12] 저장 완료
#  [2006-04-13] 저장 완료
#  [2006-04-14] 저장 완료
#  [2006-04-15] 저장 완료
#  [2006-04-16] 저장 완료
#  [2006-04-17] 저장 완료
#  [2006-04-18] 저장 완료
#  [2006-04-19] 저장 완료
#  [2006-04-20] 저장 완료
#  [2006-04-21] 저장 완료
#  [2006-04-22] 저장 완료
#  [2006-04-23] 저장 완료
#  [2006-04-24] 저장 완료
#  [2006-04-25] 저장 완료
#  [2006-04-26] 저장 완료
#  [2006-04-27] 저장 완료
#  [2006-04-28] 저장 완료
#  [2006-04-29] 저장 완료
#  [2006-04-30] 저장 완료
#  [2006-05-01] 저장 완료
#  [2006-05-02] 저장 완료
#  [2006-05-03] 저장 완료
#  [2006-05-04] 저장 완료
#  [2006-05-05] 저장 완료
#  [2006-05-06] 저장 완료
#  [2006-05-07] 저장 완료
#  [2006-05-08] 저장 완료
#  [2006-05-09] 저장 완료
#  [2006-05-10] 저장 완료
#  [2006-05-11] 저장 완료
#  [2006-05-12] 저장 완료
#  [2006-05-13] 저장 완료
#  [2006-05-14] 저장 완료
#  [2006-05-15] 저장 완료
#  [2006-05-16] 저장 완료
#  [2006-05-17] 저장 완료
#  [2006-05-18] 저장 완료
#  [2006-05-19] 저장 완료
#  [2006-05-20] 저장 완료
#  [2006-05-21] 저장 완료
#  [2006-05-22] 저장 완료
#  [2006-05-23] 저장 완료
#  [2006-05-24] 저장 완료
#  [2006-05-25] 저장 완료
#  [2006-05-26] 저장 완료
#  [2006-05-27] 저장 완료
#  [2006-05-28] 저장 완료
#  [2006-05-29] 저장 완료
#  [2006-05-30] 저장 완료
#  [2006-05-31] 저장 완료
#  [2006-06-01] 저장 완료
#  [2006-06-02] 저장 완료
#  [2006-06-03] 저장 완료
#  [2006-06-04] 저장 완료
#  [2006-06-05] 저장 완료
#  [2006-06-06] 저장 완료
#  [2006-06-07] 저장 완료
#  [2006-06-08] 저장 완료
#  [2006-06-09] 저장 완료
#  [2006-06-10] 저장 완료
#  [2006-06-11] 저장 완료
#  [2006-06-12] 저장 완료
#  [2006-06-13] 저장 완료
#  [2006-06-14] 저장 완료
#  [2006-06-15] 저장 완료
#  [2006-06-16] 저장 완료
#  [2006-06-17] 저장 완료
#  [2006-06-18] 저장 완료
#  [2006-06-19] 저장 완료
#  [2006-06-20] 저장 완료
#  [2006-06-21] 저장 완료
#  [2006-06-22] 저장 완료
#  [2006-06-23] 저장 완료
#  [2006-06-24] 저장 완료
#  [2006-06-25] 저장 완료
#  [2006-06-26] 저장 완료
#  [2006-06-27] 저장 완료
#  [2006-06-28] 저장 완료
#  [2006-06-29] 저장 완료
#  [2006-06-30] 저장 완료
#  [2006-07-01] 저장 완료
#  [2006-07-02] 저장 완료
#  [2006-07-03] 저장 완료
#  [2006-07-04] 저장 완료
#  [2006-07-05] 저장 완료
#  [2006-07-06] 저장 완료
#  [2006-07-07] 저장 완료
#  [2006-07-08] 저장 완료
#  [2006-07-09] 저장 완료
#  [2006-07-10] 저장 완료
#  [2006-07-11] 저장 완료
#  [2006-07-12] 저장 완료
#  [2006-07-13] 저장 완료
#  [2006-07-14] 저장 완료
#  [2006-07-15] 저장 완료
#  [2006-07-16] 저장 완료
#  [2006-07-17] 저장 완료
#  [2006-07-18] 저장 완료
#  [2006-07-19] 저장 완료
#  [2006-07-20] 저장 완료
#  [2006-07-21] 저장 완료
#  [2006-07-22] 저장 완료
#  [2006-07-23] 저장 완료
#  [2006-07-24] 저장 완료
#  [2006-07-25] 저장 완료
#  [2006-07-26] 저장 완료
#  [2006-07-27] 저장 완료
#  [2006-07-28] 저장 완료
#  [2006-07-29] 저장 완료
#  [2006-07-30] 저장 완료
#  [2006-07-31] 저장 완료
#  [2006-08-01] 저장 완료
#  [2006-08-02] 저장 완료
#  [2006-08-03] 저장 완료
#  [2006-08-04] 저장 완료
#  [2006-08-05] 저장 완료
#  [2006-08-06] 저장 완료
#  [2006-08-07] 저장 완료
#  [2006-08-08] 저장 완료
#  [2006-08-09] 저장 완료
#  [2006-08-10] 저장 완료
#  [2006-08-11] 저장 완료
#  [2006-08-12] 저장 완료
#  [2006-08-13] 저장 완료
#  [2006-08-14] 저장 완료
#  [2006-08-15] 저장 완료
#  [2006-08-16] 저장 완료
#  [2006-08-17] 저장 완료
#  [2006-08-18] 저장 완료
#  [2006-08-19] 저장 완료
#  [2006-08-20] 저장 완료
#  [2006-08-21] 저장 완료
#  [2006-08-22] 저장 완료
#  [2006-08-23] 저장 완료
#  [2006-08-24] 저장 완료
#  [2006-08-25] 저장 완료
#  [2006-08-26] 저장 완료
#  [2006-08-27] 저장 완료
#  [2006-08-28] 저장 완료
#  [2006-08-29] 저장 완료
#  [2006-08-30] 저장 완료
#  [2006-08-31] 저장 완료
#  [2006-09-01] 저장 완료
#  [2006-09-02] 저장 완료
#  [2006-09-03] 저장 완료
#  [2006-09-04] 저장 완료
#  [2006-09-05] 저장 완료
#  [2006-09-06] 저장 완료
#  [2006-09-07] 저장 완료
#  [2006-09-08] 저장 완료
#  [2006-09-09] 저장 완료
#  [2006-09-10] 저장 완료
#  [2006-09-11] 저장 완료
#  [2006-09-12] 저장 완료
#  [2006-09-13] 저장 완료
#  [2006-09-14] 저장 완료
#  [2006-09-15] 저장 완료
#  [2006-09-16] 저장 완료
#  [2006-09-17] 저장 완료
#  [2006-09-18] 저장 완료
# ❌ [2006-09-19] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2006-09-19] 저장 완료
#  [2006-09-20] 저장 완료
#  [2006-09-21] 저장 완료
#  [2006-09-22] 저장 완료
#  [2006-09-23] 저장 완료
#  [2006-09-24] 저장 완료
#  [2006-09-25] 저장 완료
#  [2006-09-26] 저장 완료
#  [2006-09-27] 저장 완료
#  [2006-09-28] 저장 완료
#  [2006-09-29] 저장 완료
#  [2006-09-30] 저장 완료
#  [2006-10-01] 저장 완료
#  [2006-10-02] 저장 완료
#  [2006-10-03] 저장 완료
#  [2006-10-04] 저장 완료
#  [2006-10-05] 저장 완료
#  [2006-10-06] 저장 완료
#  [2006-10-07] 저장 완료
#  [2006-10-08] 저장 완료
#  [2006-10-09] 저장 완료
#  [2006-10-10] 저장 완료
#  [2006-10-11] 저장 완료
#  [2006-10-12] 저장 완료
#  [2006-10-13] 저장 완료
#  [2006-10-14] 저장 완료
#  [2006-10-15] 저장 완료
#  [2006-10-16] 저장 완료
#  [2006-10-17] 저장 완료
#  [2006-10-18] 저장 완료
#  [2006-10-19] 저장 완료
#  [2006-10-20] 저장 완료
#  [2006-10-21] 저장 완료
#  [2006-10-22] 저장 완료
#  [2006-10-23] 저장 완료
#  [2006-10-24] 저장 완료
#  [2006-10-25] 저장 완료
#  [2006-10-26] 저장 완료
#  [2006-10-27] 저장 완료
#  [2006-10-28] 저장 완료
#  [2006-10-29] 저장 완료
#  [2006-10-30] 저장 완료
#  [2006-10-31] 저장 완료
#  [2006-11-01] 저장 완료
#  [2006-11-02] 저장 완료
#  [2006-11-03] 저장 완료
#  [2006-11-04] 저장 완료
#  [2006-11-05] 저장 완료
#  [2006-11-06] 저장 완료
#  [2006-11-07] 저장 완료
#  [2006-11-08] 저장 완료
#  [2006-11-09] 저장 완료
#  [2006-11-10] 저장 완료
#  [2006-11-11] 저장 완료
#  [2006-11-12] 저장 완료
#  [2006-11-13] 저장 완료
#  [2006-11-14] 저장 완료
#  [2006-11-15] 저장 완료
#  [2006-11-16] 저장 완료
#  [2006-11-17] 저장 완료
#  [2006-11-18] 저장 완료
#  [2006-11-19] 저장 완료
#  [2006-11-20] 저장 완료
#  [2006-11-21] 저장 완료
#  [2006-11-22] 저장 완료
#  [2006-11-23] 저장 완료
#  [2006-11-24] 저장 완료
#  [2006-11-25] 저장 완료
#  [2006-11-26] 저장 완료
#  [2006-11-27] 저장 완료
#  [2006-11-28] 저장 완료
#  [2006-11-29] 저장 완료
#  [2006-11-30] 저장 완료
#  [2006-12-01] 저장 완료
#  [2006-12-02] 저장 완료
#  [2006-12-03] 저장 완료
#  [2006-12-04] 저장 완료
#  [2006-12-05] 저장 완료
#  [2006-12-06] 저장 완료
#  [2006-12-07] 저장 완료
#  [2006-12-08] 저장 완료
#  [2006-12-09] 저장 완료
#  [2006-12-10] 저장 완료
#  [2006-12-11] 저장 완료
#  [2006-12-12] 저장 완료
#  [2006-12-13] 저장 완료
#  [2006-12-14] 저장 완료
#  [2006-12-15] 저장 완료
#  [2006-12-16] 저장 완료
#  [2006-12-17] 저장 완료
#  [2006-12-18] 저장 완료
#  [2006-12-19] 저장 완료
#  [2006-12-20] 저장 완료
#  [2006-12-21] 저장 완료
#  [2006-12-22] 저장 완료
#  [2006-12-23] 저장 완료
#  [2006-12-24] 저장 완료
#  [2006-12-25] 저장 완료
#  [2006-12-26] 저장 완료
#  [2006-12-27] 저장 완료
#  [2006-12-28] 저장 완료
#  [2006-12-29] 저장 완료
#  [2006-12-30] 저장 완료
#  [2006-12-31] 저장 완료
#  [2007-01-01] 저장 완료
#  [2007-01-02] 저장 완료
#  [2007-01-03] 저장 완료
#  [2007-01-04] 저장 완료
#  [2007-01-05] 저장 완료
#  [2007-01-06] 저장 완료
#  [2007-01-07] 저장 완료
#  [2007-01-08] 저장 완료
#  [2007-01-09] 저장 완료
#  [2007-01-10] 저장 완료
#  [2007-01-11] 저장 완료
#  [2007-01-12] 저장 완료
#  [2007-01-13] 저장 완료
#  [2007-01-14] 저장 완료
#  [2007-01-15] 저장 완료
#  [2007-01-16] 저장 완료
#  [2007-01-17] 저장 완료
#  [2007-01-18] 저장 완료
#  [2007-01-19] 저장 완료
#  [2007-01-20] 저장 완료
#  [2007-01-21] 저장 완료
#  [2007-01-22] 저장 완료
#  [2007-01-23] 저장 완료
#  [2007-01-24] 저장 완료
#  [2007-01-25] 저장 완료
#  [2007-01-26] 저장 완료
#  [2007-01-27] 저장 완료
#  [2007-01-28] 저장 완료
#  [2007-01-29] 저장 완료
#  [2007-01-30] 저장 완료
#  [2007-01-31] 저장 완료
#  [2007-02-01] 저장 완료
#  [2007-02-02] 저장 완료
#  [2007-02-03] 저장 완료
#  [2007-02-04] 저장 완료
#  [2007-02-05] 저장 완료
#  [2007-02-06] 저장 완료
#  [2007-02-07] 저장 완료
#  [2007-02-08] 저장 완료
#  [2007-02-09] 저장 완료
#  [2007-02-10] 저장 완료
#  [2007-02-11] 저장 완료
#  [2007-02-12] 저장 완료
#  [2007-02-13] 저장 완료
#  [2007-02-14] 저장 완료
#  [2007-02-15] 저장 완료
#  [2007-02-16] 저장 완료
#  [2007-02-17] 저장 완료
#  [2007-02-18] 저장 완료
#  [2007-02-19] 저장 완료
#  [2007-02-20] 저장 완료
# ❌ [2007-02-21] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2007-02-21] 저장 완료
#  [2007-02-22] 저장 완료
#  [2007-02-23] 저장 완료
#  [2007-02-24] 저장 완료
#  [2007-02-25] 저장 완료
#  [2007-02-26] 저장 완료
#  [2007-02-27] 저장 완료
#  [2007-02-28] 저장 완료
#  [2007-03-01] 저장 완료
#  [2007-03-02] 저장 완료
#  [2007-03-03] 저장 완료
#  [2007-03-04] 저장 완료
#  [2007-03-05] 저장 완료
#  [2007-03-06] 저장 완료
#  [2007-03-07] 저장 완료
#  [2007-03-08] 저장 완료
#  [2007-03-09] 저장 완료
#  [2007-03-10] 저장 완료
#  [2007-03-11] 저장 완료
#  [2007-03-12] 저장 완료
#  [2007-03-13] 저장 완료
#  [2007-03-14] 저장 완료
#  [2007-03-15] 저장 완료
#  [2007-03-16] 저장 완료
#  [2007-03-17] 저장 완료
#  [2007-03-18] 저장 완료
#  [2007-03-19] 저장 완료
#  [2007-03-20] 저장 완료
#  [2007-03-21] 저장 완료
#  [2007-03-22] 저장 완료
#  [2007-03-23] 저장 완료
#  [2007-03-24] 저장 완료
#  [2007-03-25] 저장 완료
#  [2007-03-26] 저장 완료
#  [2007-03-27] 저장 완료
#  [2007-03-28] 저장 완료
#  [2007-03-29] 저장 완료
#  [2007-03-30] 저장 완료
#  [2007-03-31] 저장 완료
#  [2007-04-01] 저장 완료
#  [2007-04-02] 저장 완료
#  [2007-04-03] 저장 완료
#  [2007-04-04] 저장 완료
#  [2007-04-05] 저장 완료
#  [2007-04-06] 저장 완료
#  [2007-04-07] 저장 완료
#  [2007-04-08] 저장 완료
#  [2007-04-09] 저장 완료
#  [2007-04-10] 저장 완료
#  [2007-04-11] 저장 완료
#  [2007-04-12] 저장 완료
#  [2007-04-13] 저장 완료
#  [2007-04-14] 저장 완료
#  [2007-04-15] 저장 완료
# ❌ [2007-04-16] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2007-04-16] 저장 완료
#  [2007-04-17] 저장 완료
#  [2007-04-18] 저장 완료
#  [2007-04-19] 저장 완료
#  [2007-04-20] 저장 완료
#  [2007-04-21] 저장 완료
#  [2007-04-22] 저장 완료
#  [2007-04-23] 저장 완료
#  [2007-04-24] 저장 완료
#  [2007-04-25] 저장 완료
#  [2007-04-26] 저장 완료
#  [2007-04-27] 저장 완료
#  [2007-04-28] 저장 완료
#  [2007-04-29] 저장 완료
#  [2007-04-30] 저장 완료
#  [2007-05-01] 저장 완료
#  [2007-05-02] 저장 완료
#  [2007-05-03] 저장 완료
#  [2007-05-04] 저장 완료
#  [2007-05-05] 저장 완료
#  [2007-05-06] 저장 완료
#  [2007-05-07] 저장 완료
#  [2007-05-08] 저장 완료
#  [2007-05-09] 저장 완료
#  [2007-05-10] 저장 완료
#  [2007-05-11] 저장 완료
#  [2007-05-12] 저장 완료
#  [2007-05-13] 저장 완료
#  [2007-05-14] 저장 완료
#  [2007-05-15] 저장 완료
#  [2007-05-16] 저장 완료
#  [2007-05-17] 저장 완료
#  [2007-05-18] 저장 완료
#  [2007-05-19] 저장 완료
#  [2007-05-20] 저장 완료
#  [2007-05-21] 저장 완료
#  [2007-05-22] 저장 완료
#  [2007-05-23] 저장 완료
#  [2007-05-24] 저장 완료
#  [2007-05-25] 저장 완료
#  [2007-05-26] 저장 완료
#  [2007-05-27] 저장 완료
#  [2007-05-28] 저장 완료
#  [2007-05-29] 저장 완료
#  [2007-05-30] 저장 완료
#  [2007-05-31] 저장 완료
#  [2007-06-01] 저장 완료
#  [2007-06-02] 저장 완료
#  [2007-06-03] 저장 완료
#  [2007-06-04] 저장 완료
#  [2007-06-05] 저장 완료
#  [2007-06-06] 저장 완료
#  [2007-06-07] 저장 완료
#  [2007-06-08] 저장 완료
#  [2007-06-09] 저장 완료
#  [2007-06-10] 저장 완료
#  [2007-06-11] 저장 완료
#  [2007-06-12] 저장 완료
#  [2007-06-13] 저장 완료
#  [2007-06-14] 저장 완료
#  [2007-06-15] 저장 완료
#  [2007-06-16] 저장 완료
#  [2007-06-17] 저장 완료
#  [2007-06-18] 저장 완료
#  [2007-06-19] 저장 완료
#  [2007-06-20] 저장 완료
#  [2007-06-21] 저장 완료
#  [2007-06-22] 저장 완료
#  [2007-06-23] 저장 완료
#  [2007-06-24] 저장 완료
#  [2007-06-25] 저장 완료
#  [2007-06-26] 저장 완료
#  [2007-06-27] 저장 완료
#  [2007-06-28] 저장 완료
#  [2007-06-29] 저장 완료
#  [2007-06-30] 저장 완료
#  [2007-07-01] 저장 완료
#  [2007-07-02] 저장 완료
#  [2007-07-03] 저장 완료
#  [2007-07-04] 저장 완료
#  [2007-07-05] 저장 완료
#  [2007-07-06] 저장 완료
#  [2007-07-07] 저장 완료
#  [2007-07-08] 저장 완료
#  [2007-07-09] 저장 완료
#  [2007-07-10] 저장 완료
#  [2007-07-11] 저장 완료
#  [2007-07-12] 저장 완료
#  [2007-07-13] 저장 완료
#  [2007-07-14] 저장 완료
#  [2007-07-15] 저장 완료
#  [2007-07-16] 저장 완료
#  [2007-07-17] 저장 완료
#  [2007-07-18] 저장 완료
#  [2007-07-19] 저장 완료
#  [2007-07-20] 저장 완료
#  [2007-07-21] 저장 완료
#  [2007-07-22] 저장 완료
#  [2007-07-23] 저장 완료
#  [2007-07-24] 저장 완료
#  [2007-07-25] 저장 완료
#  [2007-07-26] 저장 완료
#  [2007-07-27] 저장 완료
#  [2007-07-28] 저장 완료
#  [2007-07-29] 저장 완료
#  [2007-07-30] 저장 완료
#  [2007-07-31] 저장 완료
#  [2007-08-01] 저장 완료
#  [2007-08-02] 저장 완료
#  [2007-08-03] 저장 완료
# ❌ [2007-08-04] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2007-08-04] 저장 완료
#  [2007-08-05] 저장 완료
#  [2007-08-06] 저장 완료
#  [2007-08-07] 저장 완료
#  [2007-08-08] 저장 완료
#  [2007-08-09] 저장 완료
#  [2007-08-10] 저장 완료
#  [2007-08-11] 저장 완료
#  [2007-08-12] 저장 완료
# ❌ [2007-08-13] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2007-08-13] 저장 완료
#  [2007-08-14] 저장 완료
#  [2007-08-15] 저장 완료
#  [2007-08-16] 저장 완료
#  [2007-08-17] 저장 완료
#  [2007-08-18] 저장 완료
#  [2007-08-19] 저장 완료
#  [2007-08-20] 저장 완료
#  [2007-08-21] 저장 완료
#  [2007-08-22] 저장 완료
#  [2007-08-23] 저장 완료
#  [2007-08-24] 저장 완료
#  [2007-08-25] 저장 완료
#  [2007-08-26] 저장 완료
#  [2007-08-27] 저장 완료
#  [2007-08-28] 저장 완료
#  [2007-08-29] 저장 완료
#  [2007-08-30] 저장 완료
#  [2007-08-31] 저장 완료
#  [2007-09-01] 저장 완료
#  [2007-09-02] 저장 완료
#  [2007-09-03] 저장 완료
#  [2007-09-04] 저장 완료
#  [2007-09-05] 저장 완료
#  [2007-09-06] 저장 완료
#  [2007-09-07] 저장 완료
#  [2007-09-08] 저장 완료
#  [2007-09-09] 저장 완료
#  [2007-09-10] 저장 완료
#  [2007-09-11] 저장 완료
#  [2007-09-12] 저장 완료
#  [2007-09-13] 저장 완료
#  [2007-09-14] 저장 완료
#  [2007-09-15] 저장 완료
#  [2007-09-16] 저장 완료
#  [2007-09-17] 저장 완료
#  [2007-09-18] 저장 완료
#  [2007-09-19] 저장 완료
#  [2007-09-20] 저장 완료
#  [2007-09-21] 저장 완료
#  [2007-09-22] 저장 완료
#  [2007-09-23] 저장 완료
#  [2007-09-24] 저장 완료
#  [2007-09-25] 저장 완료
#  [2007-09-26] 저장 완료
#  [2007-09-27] 저장 완료
#  [2007-09-28] 저장 완료
#  [2007-09-29] 저장 완료
#  [2007-09-30] 저장 완료
#  [2007-10-01] 저장 완료
#  [2007-10-02] 저장 완료
#  [2007-10-03] 저장 완료
#  [2007-10-04] 저장 완료
#  [2007-10-05] 저장 완료
#  [2007-10-06] 저장 완료
#  [2007-10-07] 저장 완료
#  [2007-10-08] 저장 완료
#  [2007-10-09] 저장 완료
#  [2007-10-10] 저장 완료
#  [2007-10-11] 저장 완료
#  [2007-10-12] 저장 완료
#  [2007-10-13] 저장 완료
#  [2007-10-14] 저장 완료
#  [2007-10-15] 저장 완료
#  [2007-10-16] 저장 완료
#  [2007-10-17] 저장 완료
#  [2007-10-18] 저장 완료
#  [2007-10-19] 저장 완료
#  [2007-10-20] 저장 완료
#  [2007-10-21] 저장 완료
#  [2007-10-22] 저장 완료
#  [2007-10-23] 저장 완료
#  [2007-10-24] 저장 완료
#  [2007-10-25] 저장 완료
#  [2007-10-26] 저장 완료
#  [2007-10-27] 저장 완료
#  [2007-10-28] 저장 완료
#  [2007-10-29] 저장 완료
#  [2007-10-30] 저장 완료
#  [2007-10-31] 저장 완료
#  [2007-11-01] 저장 완료
#  [2007-11-02] 저장 완료
#  [2007-11-03] 저장 완료
#  [2007-11-04] 저장 완료
#  [2007-11-05] 저장 완료
#  [2007-11-06] 저장 완료
#  [2007-11-07] 저장 완료
#  [2007-11-08] 저장 완료
#  [2007-11-09] 저장 완료
#  [2007-11-10] 저장 완료
#  [2007-11-11] 저장 완료
#  [2007-11-12] 저장 완료
#  [2007-11-13] 저장 완료
#  [2007-11-14] 저장 완료
#  [2007-11-15] 저장 완료
#  [2007-11-16] 저장 완료
#  [2007-11-17] 저장 완료
#  [2007-11-18] 저장 완료
#  [2007-11-19] 저장 완료
#  [2007-11-20] 저장 완료
#  [2007-11-21] 저장 완료
#  [2007-11-22] 저장 완료
#  [2007-11-23] 저장 완료
#  [2007-11-24] 저장 완료
#  [2007-11-25] 저장 완료
#  [2007-11-26] 저장 완료
#  [2007-11-27] 저장 완료
#  [2007-11-28] 저장 완료
#  [2007-11-29] 저장 완료
#  [2007-11-30] 저장 완료
#  [2007-12-01] 저장 완료
#  [2007-12-02] 저장 완료
#  [2007-12-03] 저장 완료
#  [2007-12-04] 저장 완료
#  [2007-12-05] 저장 완료
#  [2007-12-06] 저장 완료
#  [2007-12-07] 저장 완료
#  [2007-12-08] 저장 완료
#  [2007-12-09] 저장 완료
#  [2007-12-10] 저장 완료
#  [2007-12-11] 저장 완료
#  [2007-12-12] 저장 완료
#  [2007-12-13] 저장 완료
#  [2007-12-14] 저장 완료
#  [2007-12-15] 저장 완료
#  [2007-12-16] 저장 완료
#  [2007-12-17] 저장 완료
#  [2007-12-18] 저장 완료
#  [2007-12-19] 저장 완료
#  [2007-12-20] 저장 완료
#  [2007-12-21] 저장 완료
#  [2007-12-22] 저장 완료
#  [2007-12-23] 저장 완료
#  [2007-12-24] 저장 완료
#  [2007-12-25] 저장 완료
#  [2007-12-26] 저장 완료
#  [2007-12-27] 저장 완료
#  [2007-12-28] 저장 완료
#  [2007-12-29] 저장 완료
#  [2007-12-30] 저장 완료
#  [2007-12-31] 저장 완료
#  [2008-01-01] 저장 완료
#  [2008-01-02] 저장 완료
#  [2008-01-03] 저장 완료
#  [2008-01-04] 저장 완료
#  [2008-01-05] 저장 완료
#  [2008-01-06] 저장 완료
# ❌ [2008-01-07] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2008-01-07] 저장 완료
#  [2008-01-08] 저장 완료
#  [2008-01-09] 저장 완료
#  [2008-01-10] 저장 완료
#  [2008-01-11] 저장 완료
#  [2008-01-12] 저장 완료
#  [2008-01-13] 저장 완료
#  [2008-01-14] 저장 완료
#  [2008-01-15] 저장 완료
#  [2008-01-16] 저장 완료
#  [2008-01-17] 저장 완료
#  [2008-01-18] 저장 완료
#  [2008-01-19] 저장 완료
#  [2008-01-20] 저장 완료
#  [2008-01-21] 저장 완료
#  [2008-01-22] 저장 완료
#  [2008-01-23] 저장 완료
#  [2008-01-24] 저장 완료
#  [2008-01-25] 저장 완료
#  [2008-01-26] 저장 완료
#  [2008-01-27] 저장 완료
#  [2008-01-28] 저장 완료
#  [2008-01-29] 저장 완료
#  [2008-01-30] 저장 완료
#  [2008-01-31] 저장 완료
#  [2008-02-01] 저장 완료
#  [2008-02-02] 저장 완료
#  [2008-02-03] 저장 완료
#  [2008-02-04] 저장 완료
#  [2008-02-05] 저장 완료
#  [2008-02-06] 저장 완료
#  [2008-02-07] 저장 완료
#  [2008-02-08] 저장 완료
#  [2008-02-09] 저장 완료
#  [2008-02-10] 저장 완료
#  [2008-02-11] 저장 완료
#  [2008-02-12] 저장 완료
#  [2008-02-13] 저장 완료
#  [2008-02-14] 저장 완료
#  [2008-02-15] 저장 완료
#  [2008-02-16] 저장 완료
#  [2008-02-17] 저장 완료
#  [2008-02-18] 저장 완료
#  [2008-02-19] 저장 완료
#  [2008-02-20] 저장 완료
#  [2008-02-21] 저장 완료
#  [2008-02-22] 저장 완료
#  [2008-02-23] 저장 완료
#  [2008-02-24] 저장 완료
#  [2008-02-25] 저장 완료
#  [2008-02-26] 저장 완료
#  [2008-02-27] 저장 완료
#  [2008-02-28] 저장 완료
#  [2008-02-29] 저장 완료
#  [2008-03-01] 저장 완료
#  [2008-03-02] 저장 완료
#  [2008-03-03] 저장 완료
#  [2008-03-04] 저장 완료
#  [2008-03-05] 저장 완료
#  [2008-03-06] 저장 완료
#  [2008-03-07] 저장 완료
#  [2008-03-08] 저장 완료
#  [2008-03-09] 저장 완료
#  [2008-03-10] 저장 완료
#  [2008-03-11] 저장 완료
#  [2008-03-12] 저장 완료
#  [2008-03-13] 저장 완료
#  [2008-03-14] 저장 완료
#  [2008-03-15] 저장 완료
#  [2008-03-16] 저장 완료
#  [2008-03-17] 저장 완료
#  [2008-03-18] 저장 완료
#  [2008-03-19] 저장 완료
#  [2008-03-20] 저장 완료
#  [2008-03-21] 저장 완료
#  [2008-03-22] 저장 완료
#  [2008-03-23] 저장 완료
#  [2008-03-24] 저장 완료
#  [2008-03-25] 저장 완료
#  [2008-03-26] 저장 완료
#  [2008-03-27] 저장 완료
#  [2008-03-28] 저장 완료
#  [2008-03-29] 저장 완료
#  [2008-03-30] 저장 완료
#  [2008-03-31] 저장 완료
#  [2008-04-01] 저장 완료
#  [2008-04-02] 저장 완료
#  [2008-04-03] 저장 완료
#  [2008-04-04] 저장 완료
#  [2008-04-05] 저장 완료
#  [2008-04-06] 저장 완료
#  [2008-04-07] 저장 완료
#  [2008-04-08] 저장 완료
#  [2008-04-09] 저장 완료
#  [2008-04-10] 저장 완료
#  [2008-04-11] 저장 완료
#  [2008-04-12] 저장 완료
#  [2008-04-13] 저장 완료
#  [2008-04-14] 저장 완료
#  [2008-04-15] 저장 완료
#  [2008-04-16] 저장 완료
#  [2008-04-17] 저장 완료
#  [2008-04-18] 저장 완료
#  [2008-04-19] 저장 완료
#  [2008-04-20] 저장 완료
#  [2008-04-21] 저장 완료
#  [2008-04-22] 저장 완료
#  [2008-04-23] 저장 완료
#  [2008-04-24] 저장 완료
#  [2008-04-25] 저장 완료
#  [2008-04-26] 저장 완료
#  [2008-04-27] 저장 완료
#  [2008-04-28] 저장 완료
#  [2008-04-29] 저장 완료
#  [2008-04-30] 저장 완료
#  [2008-05-01] 저장 완료
#  [2008-05-02] 저장 완료
#  [2008-05-03] 저장 완료
#  [2008-05-04] 저장 완료
#  [2008-05-05] 저장 완료
#  [2008-05-06] 저장 완료
#  [2008-05-07] 저장 완료
#  [2008-05-08] 저장 완료
#  [2008-05-09] 저장 완료
#  [2008-05-10] 저장 완료
#  [2008-05-11] 저장 완료
#  [2008-05-12] 저장 완료
#  [2008-05-13] 저장 완료
#  [2008-05-14] 저장 완료
#  [2008-05-15] 저장 완료
#  [2008-05-16] 저장 완료
#  [2008-05-17] 저장 완료
#  [2008-05-18] 저장 완료
#  [2008-05-19] 저장 완료
#  [2008-05-20] 저장 완료
#  [2008-05-21] 저장 완료
#  [2008-05-22] 저장 완료
#  [2008-05-23] 저장 완료
#  [2008-05-24] 저장 완료
#  [2008-05-25] 저장 완료
#  [2008-05-26] 저장 완료
#  [2008-05-27] 저장 완료
#  [2008-05-28] 저장 완료
#  [2008-05-29] 저장 완료
#  [2008-05-30] 저장 완료
#  [2008-05-31] 저장 완료
#  [2008-06-01] 저장 완료
#  [2008-06-02] 저장 완료
#  [2008-06-03] 저장 완료
#  [2008-06-04] 저장 완료
#  [2008-06-05] 저장 완료
#  [2008-06-06] 저장 완료
#  [2008-06-07] 저장 완료
#  [2008-06-08] 저장 완료
#  [2008-06-09] 저장 완료
#  [2008-06-10] 저장 완료
#  [2008-06-11] 저장 완료
#  [2008-06-12] 저장 완료
#  [2008-06-13] 저장 완료
#  [2008-06-14] 저장 완료
#  [2008-06-15] 저장 완료
#  [2008-06-16] 저장 완료
#  [2008-06-17] 저장 완료
#  [2008-06-18] 저장 완료
#  [2008-06-19] 저장 완료
#  [2008-06-20] 저장 완료
#  [2008-06-21] 저장 완료
#  [2008-06-22] 저장 완료
#  [2008-06-23] 저장 완료
#  [2008-06-24] 저장 완료
#  [2008-06-25] 저장 완료
#  [2008-06-26] 저장 완료
#  [2008-06-27] 저장 완료
#  [2008-06-28] 저장 완료
#  [2008-06-29] 저장 완료
#  [2008-06-30] 저장 완료
#  [2008-07-01] 저장 완료
#  [2008-07-02] 저장 완료
#  [2008-07-03] 저장 완료
#  [2008-07-04] 저장 완료
#  [2008-07-05] 저장 완료
#  [2008-07-06] 저장 완료
#  [2008-07-07] 저장 완료
#  [2008-07-08] 저장 완료
#  [2008-07-09] 저장 완료
#  [2008-07-10] 저장 완료
#  [2008-07-11] 저장 완료
#  [2008-07-12] 저장 완료
#  [2008-07-13] 저장 완료
#  [2008-07-14] 저장 완료
#  [2008-07-15] 저장 완료
#  [2008-07-16] 저장 완료
#  [2008-07-17] 저장 완료
#  [2008-07-18] 저장 완료
#  [2008-07-19] 저장 완료
#  [2008-07-20] 저장 완료
#  [2008-07-21] 저장 완료
#  [2008-07-22] 저장 완료
#  [2008-07-23] 저장 완료
#  [2008-07-24] 저장 완료
#  [2008-07-25] 저장 완료
#  [2008-07-26] 저장 완료
#  [2008-07-27] 저장 완료
#  [2008-07-28] 저장 완료
#  [2008-07-29] 저장 완료
#  [2008-07-30] 저장 완료
#  [2008-07-31] 저장 완료
#  [2008-08-01] 저장 완료
#  [2008-08-02] 저장 완료
#  [2008-08-03] 저장 완료
#  [2008-08-04] 저장 완료
#  [2008-08-05] 저장 완료
#  [2008-08-06] 저장 완료
#  [2008-08-07] 저장 완료
#  [2008-08-08] 저장 완료
#  [2008-08-09] 저장 완료
#  [2008-08-10] 저장 완료
#  [2008-08-11] 저장 완료
#  [2008-08-12] 저장 완료
#  [2008-08-13] 저장 완료
#  [2008-08-14] 저장 완료
#  [2008-08-15] 저장 완료
#  [2008-08-16] 저장 완료
#  [2008-08-17] 저장 완료
#  [2008-08-18] 저장 완료
#  [2008-08-19] 저장 완료
#  [2008-08-20] 저장 완료
#  [2008-08-21] 저장 완료
#  [2008-08-22] 저장 완료
#  [2008-08-23] 저장 완료
#  [2008-08-24] 저장 완료
#  [2008-08-25] 저장 완료
#  [2008-08-26] 저장 완료
#  [2008-08-27] 저장 완료
#  [2008-08-28] 저장 완료
#  [2008-08-29] 저장 완료
#  [2008-08-30] 저장 완료
#  [2008-08-31] 저장 완료
#  [2008-09-01] 저장 완료
#  [2008-09-02] 저장 완료
#  [2008-09-03] 저장 완료
#  [2008-09-04] 저장 완료
#  [2008-09-05] 저장 완료
#  [2008-09-06] 저장 완료
#  [2008-09-07] 저장 완료
#  [2008-09-08] 저장 완료
#  [2008-09-09] 저장 완료
#  [2008-09-10] 저장 완료
#  [2008-09-11] 저장 완료
#  [2008-09-12] 저장 완료
#  [2008-09-13] 저장 완료
#  [2008-09-14] 저장 완료
#  [2008-09-15] 저장 완료
#  [2008-09-16] 저장 완료
#  [2008-09-17] 저장 완료
#  [2008-09-18] 저장 완료
#  [2008-09-19] 저장 완료
#  [2008-09-20] 저장 완료
#  [2008-09-21] 저장 완료
#  [2008-09-22] 저장 완료
#  [2008-09-23] 저장 완료
#  [2008-09-24] 저장 완료
#  [2008-09-25] 저장 완료
#  [2008-09-26] 저장 완료
#  [2008-09-27] 저장 완료
#  [2008-09-28] 저장 완료
#  [2008-09-29] 저장 완료
#  [2008-09-30] 저장 완료
#  [2008-10-01] 저장 완료
#  [2008-10-02] 저장 완료
#  [2008-10-03] 저장 완료
#  [2008-10-04] 저장 완료
#  [2008-10-05] 저장 완료
#  [2008-10-06] 저장 완료
#  [2008-10-07] 저장 완료
#  [2008-10-08] 저장 완료
#  [2008-10-09] 저장 완료
#  [2008-10-10] 저장 완료
#  [2008-10-11] 저장 완료
#  [2008-10-12] 저장 완료
#  [2008-10-13] 저장 완료
#  [2008-10-14] 저장 완료
#  [2008-10-15] 저장 완료
#  [2008-10-16] 저장 완료
#  [2008-10-17] 저장 완료
#  [2008-10-18] 저장 완료
#  [2008-10-19] 저장 완료
#  [2008-10-20] 저장 완료
#  [2008-10-21] 저장 완료
#  [2008-10-22] 저장 완료
#  [2008-10-23] 저장 완료
#  [2008-10-24] 저장 완료
#  [2008-10-25] 저장 완료
#  [2008-10-26] 저장 완료
#  [2008-10-27] 저장 완료
#  [2008-10-28] 저장 완료
#  [2008-10-29] 저장 완료
#  [2008-10-30] 저장 완료
#  [2008-10-31] 저장 완료
#  [2008-11-01] 저장 완료
#  [2008-11-02] 저장 완료
#  [2008-11-03] 저장 완료
#  [2008-11-04] 저장 완료
#  [2008-11-05] 저장 완료
#  [2008-11-06] 저장 완료
#  [2008-11-07] 저장 완료
#  [2008-11-08] 저장 완료
#  [2008-11-09] 저장 완료
#  [2008-11-10] 저장 완료
#  [2008-11-11] 저장 완료
#  [2008-11-12] 저장 완료
#  [2008-11-13] 저장 완료
#  [2008-11-14] 저장 완료
#  [2008-11-15] 저장 완료
#  [2008-11-16] 저장 완료
#  [2008-11-17] 저장 완료
#  [2008-11-18] 저장 완료
#  [2008-11-19] 저장 완료
#  [2008-11-20] 저장 완료
#  [2008-11-21] 저장 완료
#  [2008-11-22] 저장 완료
#  [2008-11-23] 저장 완료
#  [2008-11-24] 저장 완료
#  [2008-11-25] 저장 완료
#  [2008-11-26] 저장 완료
#  [2008-11-27] 저장 완료
# ❌ [2008-11-28] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2008-11-28] 저장 완료
#  [2008-11-29] 저장 완료
#  [2008-11-30] 저장 완료
#  [2008-12-01] 저장 완료
#  [2008-12-02] 저장 완료
#  [2008-12-03] 저장 완료
#  [2008-12-04] 저장 완료
#  [2008-12-05] 저장 완료
#  [2008-12-06] 저장 완료
#  [2008-12-07] 저장 완료
#  [2008-12-08] 저장 완료
#  [2008-12-09] 저장 완료
#  [2008-12-10] 저장 완료
#  [2008-12-11] 저장 완료
#  [2008-12-12] 저장 완료
#  [2008-12-13] 저장 완료
#  [2008-12-14] 저장 완료
#  [2008-12-15] 저장 완료
#  [2008-12-16] 저장 완료
#  [2008-12-17] 저장 완료
#  [2008-12-18] 저장 완료
#  [2008-12-19] 저장 완료
#  [2008-12-20] 저장 완료
#  [2008-12-21] 저장 완료
#  [2008-12-22] 저장 완료
#  [2008-12-23] 저장 완료
#  [2008-12-24] 저장 완료
#  [2008-12-25] 저장 완료
#  [2008-12-26] 저장 완료
#  [2008-12-27] 저장 완료
#  [2008-12-28] 저장 완료
#  [2008-12-29] 저장 완료
#  [2008-12-30] 저장 완료
#  [2008-12-31] 저장 완료
#  [2009-01-01] 저장 완료
#  [2009-01-02] 저장 완료
#  [2009-01-03] 저장 완료
#  [2009-01-04] 저장 완료
#  [2009-01-05] 저장 완료
# ❌ [2009-01-06] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2009-01-06] 저장 완료
#  [2009-01-07] 저장 완료
#  [2009-01-08] 저장 완료
#  [2009-01-09] 저장 완료
#  [2009-01-10] 저장 완료
#  [2009-01-11] 저장 완료
#  [2009-01-12] 저장 완료
#  [2009-01-13] 저장 완료
#  [2009-01-14] 저장 완료
#  [2009-01-15] 저장 완료
#  [2009-01-16] 저장 완료
#  [2009-01-17] 저장 완료
#  [2009-01-18] 저장 완료
#  [2009-01-19] 저장 완료
#  [2009-01-20] 저장 완료
#  [2009-01-21] 저장 완료
#  [2009-01-22] 저장 완료
#  [2009-01-23] 저장 완료
#  [2009-01-24] 저장 완료
#  [2009-01-25] 저장 완료
#  [2009-01-26] 저장 완료
#  [2009-01-27] 저장 완료
#  [2009-01-28] 저장 완료
#  [2009-01-29] 저장 완료
#  [2009-01-30] 저장 완료
#  [2009-01-31] 저장 완료
#  [2009-02-01] 저장 완료
#  [2009-02-02] 저장 완료
#  [2009-02-03] 저장 완료
#  [2009-02-04] 저장 완료
#  [2009-02-05] 저장 완료
#  [2009-02-06] 저장 완료
#  [2009-02-07] 저장 완료
#  [2009-02-08] 저장 완료
#  [2009-02-09] 저장 완료
#  [2009-02-10] 저장 완료
#  [2009-02-11] 저장 완료
#  [2009-02-12] 저장 완료
#  [2009-02-13] 저장 완료
#  [2009-02-14] 저장 완료
#  [2009-02-15] 저장 완료
#  [2009-02-16] 저장 완료
#  [2009-02-17] 저장 완료
#  [2009-02-18] 저장 완료
#  [2009-02-19] 저장 완료
#  [2009-02-20] 저장 완료
#  [2009-02-21] 저장 완료
#  [2009-02-22] 저장 완료
#  [2009-02-23] 저장 완료
#  [2009-02-24] 저장 완료
#  [2009-02-25] 저장 완료
#  [2009-02-26] 저장 완료
#  [2009-02-27] 저장 완료
#  [2009-02-28] 저장 완료
#  [2009-03-01] 저장 완료
#  [2009-03-02] 저장 완료
#  [2009-03-03] 저장 완료
#  [2009-03-04] 저장 완료
#  [2009-03-05] 저장 완료
#  [2009-03-06] 저장 완료
#  [2009-03-07] 저장 완료
#  [2009-03-08] 저장 완료
#  [2009-03-09] 저장 완료
#  [2009-03-10] 저장 완료
#  [2009-03-11] 저장 완료
#  [2009-03-12] 저장 완료
#  [2009-03-13] 저장 완료
#  [2009-03-14] 저장 완료
#  [2009-03-15] 저장 완료
#  [2009-03-16] 저장 완료
#  [2009-03-17] 저장 완료
#  [2009-03-18] 저장 완료
#  [2009-03-19] 저장 완료
#  [2009-03-20] 저장 완료
#  [2009-03-21] 저장 완료
#  [2009-03-22] 저장 완료
#  [2009-03-23] 저장 완료
#  [2009-03-24] 저장 완료
# ❌ [2009-03-25] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2009-03-25] 저장 완료
# ❌ [2009-03-26] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2009-03-26] 저장 완료
#  [2009-03-27] 저장 완료
#  [2009-03-28] 저장 완료
#  [2009-03-29] 저장 완료
#  [2009-03-30] 저장 완료
#  [2009-03-31] 저장 완료
#  [2009-04-01] 저장 완료
#  [2009-04-02] 저장 완료
#  [2009-04-03] 저장 완료
#  [2009-04-04] 저장 완료
#  [2009-04-05] 저장 완료
#  [2009-04-06] 저장 완료
#  [2009-04-07] 저장 완료
#  [2009-04-08] 저장 완료
#  [2009-04-09] 저장 완료
#  [2009-04-10] 저장 완료
#  [2009-04-11] 저장 완료
#  [2009-04-12] 저장 완료
#  [2009-04-13] 저장 완료
#  [2009-04-14] 저장 완료
#  [2009-04-15] 저장 완료
#  [2009-04-16] 저장 완료
#  [2009-04-17] 저장 완료
#  [2009-04-18] 저장 완료
#  [2009-04-19] 저장 완료
#  [2009-04-20] 저장 완료
#  [2009-04-21] 저장 완료
#  [2009-04-22] 저장 완료
#  [2009-04-23] 저장 완료
#  [2009-04-24] 저장 완료
#  [2009-04-25] 저장 완료
#  [2009-04-26] 저장 완료
#  [2009-04-27] 저장 완료
#  [2009-04-28] 저장 완료
#  [2009-04-29] 저장 완료
#  [2009-04-30] 저장 완료
#  [2009-05-01] 저장 완료
#  [2009-05-02] 저장 완료
#  [2009-05-03] 저장 완료
#  [2009-05-04] 저장 완료
#  [2009-05-05] 저장 완료
#  [2009-05-06] 저장 완료
#  [2009-05-07] 저장 완료
#  [2009-05-08] 저장 완료
#  [2009-05-09] 저장 완료
#  [2009-05-10] 저장 완료
#  [2009-05-11] 저장 완료
#  [2009-05-12] 저장 완료
#  [2009-05-13] 저장 완료
#  [2009-05-14] 저장 완료
#  [2009-05-15] 저장 완료
#  [2009-05-16] 저장 완료
#  [2009-05-17] 저장 완료
#  [2009-05-18] 저장 완료
#  [2009-05-19] 저장 완료
#  [2009-05-20] 저장 완료
#  [2009-05-21] 저장 완료
#  [2009-05-22] 저장 완료
#  [2009-05-23] 저장 완료
#  [2009-05-24] 저장 완료
#  [2009-05-25] 저장 완료
#  [2009-05-26] 저장 완료
#  [2009-05-27] 저장 완료
#  [2009-05-28] 저장 완료
#  [2009-05-29] 저장 완료
#  [2009-05-30] 저장 완료
#  [2009-05-31] 저장 완료
#  [2009-06-01] 저장 완료
#  [2009-06-02] 저장 완료
#  [2009-06-03] 저장 완료
#  [2009-06-04] 저장 완료
#  [2009-06-05] 저장 완료
#  [2009-06-06] 저장 완료
#  [2009-06-07] 저장 완료
#  [2009-06-08] 저장 완료
#  [2009-06-09] 저장 완료
#  [2009-06-10] 저장 완료
#  [2009-06-11] 저장 완료
#  [2009-06-12] 저장 완료
#  [2009-06-13] 저장 완료
#  [2009-06-14] 저장 완료
#  [2009-06-15] 저장 완료
#  [2009-06-16] 저장 완료
#  [2009-06-17] 저장 완료
#  [2009-06-18] 저장 완료
#  [2009-06-19] 저장 완료
#  [2009-06-20] 저장 완료
#  [2009-06-21] 저장 완료
#  [2009-06-22] 저장 완료
#  [2009-06-23] 저장 완료
#  [2009-06-24] 저장 완료
#  [2009-06-25] 저장 완료
#  [2009-06-26] 저장 완료
#  [2009-06-27] 저장 완료
#  [2009-06-28] 저장 완료
#  [2009-06-29] 저장 완료
#  [2009-06-30] 저장 완료
#  [2009-07-01] 저장 완료
#  [2009-07-02] 저장 완료
#  [2009-07-03] 저장 완료
#  [2009-07-04] 저장 완료
#  [2009-07-05] 저장 완료
#  [2009-07-06] 저장 완료
#  [2009-07-07] 저장 완료
#  [2009-07-08] 저장 완료
#  [2009-07-09] 저장 완료
#  [2009-07-10] 저장 완료
#  [2009-07-11] 저장 완료
#  [2009-07-12] 저장 완료
#  [2009-07-13] 저장 완료
#  [2009-07-14] 저장 완료
#  [2009-07-15] 저장 완료
#  [2009-07-16] 저장 완료
#  [2009-07-17] 저장 완료
#  [2009-07-18] 저장 완료
#  [2009-07-19] 저장 완료
#  [2009-07-20] 저장 완료
#  [2009-07-21] 저장 완료
#  [2009-07-22] 저장 완료
#  [2009-07-23] 저장 완료
#  [2009-07-24] 저장 완료
#  [2009-07-25] 저장 완료
#  [2009-07-26] 저장 완료
#  [2009-07-27] 저장 완료
#  [2009-07-28] 저장 완료
#  [2009-07-29] 저장 완료
#  [2009-07-30] 저장 완료
#  [2009-07-31] 저장 완료
#  [2009-08-01] 저장 완료
#  [2009-08-02] 저장 완료
#  [2009-08-03] 저장 완료
#  [2009-08-04] 저장 완료
#  [2009-08-05] 저장 완료
#  [2009-08-06] 저장 완료
#  [2009-08-07] 저장 완료
#  [2009-08-08] 저장 완료
#  [2009-08-09] 저장 완료
#  [2009-08-10] 저장 완료
#  [2009-08-11] 저장 완료
#  [2009-08-12] 저장 완료
#  [2009-08-13] 저장 완료
#  [2009-08-14] 저장 완료
#  [2009-08-15] 저장 완료
#  [2009-08-16] 저장 완료
#  [2009-08-17] 저장 완료
#  [2009-08-18] 저장 완료
#  [2009-08-19] 저장 완료
#  [2009-08-20] 저장 완료
#  [2009-08-21] 저장 완료
#  [2009-08-22] 저장 완료
#  [2009-08-23] 저장 완료
#  [2009-08-24] 저장 완료
#  [2009-08-25] 저장 완료
#  [2009-08-26] 저장 완료
#  [2009-08-27] 저장 완료
#  [2009-08-28] 저장 완료
#  [2009-08-29] 저장 완료
#  [2009-08-30] 저장 완료
#  [2009-08-31] 저장 완료
#  [2009-09-01] 저장 완료
#  [2009-09-02] 저장 완료
#  [2009-09-03] 저장 완료
#  [2009-09-04] 저장 완료
#  [2009-09-05] 저장 완료
#  [2009-09-06] 저장 완료
#  [2009-09-07] 저장 완료
#  [2009-09-08] 저장 완료
#  [2009-09-09] 저장 완료
#  [2009-09-10] 저장 완료
#  [2009-09-11] 저장 완료
#  [2009-09-12] 저장 완료
#  [2009-09-13] 저장 완료
#  [2009-09-14] 저장 완료
#  [2009-09-15] 저장 완료
#  [2009-09-16] 저장 완료
#  [2009-09-17] 저장 완료
#  [2009-09-18] 저장 완료
#  [2009-09-19] 저장 완료
#  [2009-09-20] 저장 완료
#  [2009-09-21] 저장 완료
#  [2009-09-22] 저장 완료
#  [2009-09-23] 저장 완료
#  [2009-09-24] 저장 완료
#  [2009-09-25] 저장 완료
#  [2009-09-26] 저장 완료
#  [2009-09-27] 저장 완료
#  [2009-09-28] 저장 완료
#  [2009-09-29] 저장 완료
#  [2009-09-30] 저장 완료
#  [2009-10-01] 저장 완료
#  [2009-10-02] 저장 완료
#  [2009-10-03] 저장 완료
#  [2009-10-04] 저장 완료
#  [2009-10-05] 저장 완료
#  [2009-10-06] 저장 완료
#  [2009-10-07] 저장 완료
#  [2009-10-08] 저장 완료
#  [2009-10-09] 저장 완료
#  [2009-10-10] 저장 완료
#  [2009-10-11] 저장 완료
#  [2009-10-12] 저장 완료
#  [2009-10-13] 저장 완료
#  [2009-10-14] 저장 완료
#  [2009-10-15] 저장 완료
#  [2009-10-16] 저장 완료
#  [2009-10-17] 저장 완료
#  [2009-10-18] 저장 완료
#  [2009-10-19] 저장 완료
#  [2009-10-20] 저장 완료
#  [2009-10-21] 저장 완료
#  [2009-10-22] 저장 완료
#  [2009-10-23] 저장 완료
#  [2009-10-24] 저장 완료
#  [2009-10-25] 저장 완료
#  [2009-10-26] 저장 완료
#  [2009-10-27] 저장 완료
#  [2009-10-28] 저장 완료
#  [2009-10-29] 저장 완료
#  [2009-10-30] 저장 완료
#  [2009-10-31] 저장 완료
#  [2009-11-01] 저장 완료
#  [2009-11-02] 저장 완료
#  [2009-11-03] 저장 완료
#  [2009-11-04] 저장 완료
#  [2009-11-05] 저장 완료
#  [2009-11-06] 저장 완료
#  [2009-11-07] 저장 완료
#  [2009-11-08] 저장 완료
#  [2009-11-09] 저장 완료
#  [2009-11-10] 저장 완료
#  [2009-11-11] 저장 완료
#  [2009-11-12] 저장 완료
#  [2009-11-13] 저장 완료
#  [2009-11-14] 저장 완료
#  [2009-11-15] 저장 완료
#  [2009-11-16] 저장 완료
#  [2009-11-17] 저장 완료
#  [2009-11-18] 저장 완료
#  [2009-11-19] 저장 완료
#  [2009-11-20] 저장 완료
#  [2009-11-21] 저장 완료
#  [2009-11-22] 저장 완료
#  [2009-11-23] 저장 완료
#  [2009-11-24] 저장 완료
#  [2009-11-25] 저장 완료
#  [2009-11-26] 저장 완료
#  [2009-11-27] 저장 완료
#  [2009-11-28] 저장 완료
#  [2009-11-29] 저장 완료
#  [2009-11-30] 저장 완료
#  [2009-12-01] 저장 완료
#  [2009-12-02] 저장 완료
#  [2009-12-03] 저장 완료
#  [2009-12-04] 저장 완료
#  [2009-12-05] 저장 완료
#  [2009-12-06] 저장 완료
#  [2009-12-07] 저장 완료
#  [2009-12-08] 저장 완료
#  [2009-12-09] 저장 완료
#  [2009-12-10] 저장 완료
#  [2009-12-11] 저장 완료
#  [2009-12-12] 저장 완료
#  [2009-12-13] 저장 완료
#  [2009-12-14] 저장 완료
#  [2009-12-15] 저장 완료
#  [2009-12-16] 저장 완료
#  [2009-12-17] 저장 완료
#  [2009-12-18] 저장 완료
#  [2009-12-19] 저장 완료
#  [2009-12-20] 저장 완료
#  [2009-12-21] 저장 완료
#  [2009-12-22] 저장 완료
#  [2009-12-23] 저장 완료
#  [2009-12-24] 저장 완료
#  [2009-12-25] 저장 완료
#  [2009-12-26] 저장 완료
#  [2009-12-27] 저장 완료
#  [2009-12-28] 저장 완료
#  [2009-12-29] 저장 완료
#  [2009-12-30] 저장 완료
#  [2009-12-31] 저장 완료
#  [2010-01-01] 저장 완료
#  [2010-01-02] 저장 완료
#  [2010-01-03] 저장 완료
#  [2010-01-04] 저장 완료
#  [2010-01-05] 저장 완료
#  [2010-01-06] 저장 완료
#  [2010-01-07] 저장 완료
#  [2010-01-08] 저장 완료
#  [2010-01-09] 저장 완료
#  [2010-01-10] 저장 완료
#  [2010-01-11] 저장 완료
#  [2010-01-12] 저장 완료
#  [2010-01-13] 저장 완료
#  [2010-01-14] 저장 완료
#  [2010-01-15] 저장 완료
#  [2010-01-16] 저장 완료
#  [2010-01-17] 저장 완료
#  [2010-01-18] 저장 완료
#  [2010-01-19] 저장 완료
#  [2010-01-20] 저장 완료
#  [2010-01-21] 저장 완료
#  [2010-01-22] 저장 완료
#  [2010-01-23] 저장 완료
#  [2010-01-24] 저장 완료
#  [2010-01-25] 저장 완료
#  [2010-01-26] 저장 완료
#  [2010-01-27] 저장 완료
#  [2010-01-28] 저장 완료
#  [2010-01-29] 저장 완료
#  [2010-01-30] 저장 완료
#  [2010-01-31] 저장 완료
#  [2010-02-01] 저장 완료
#  [2010-02-02] 저장 완료
#  [2010-02-03] 저장 완료
#  [2010-02-04] 저장 완료
#  [2010-02-05] 저장 완료
#  [2010-02-06] 저장 완료
#  [2010-02-07] 저장 완료
#  [2010-02-08] 저장 완료
#  [2010-02-09] 저장 완료
#  [2010-02-10] 저장 완료
#  [2010-02-11] 저장 완료
#  [2010-02-12] 저장 완료
#  [2010-02-13] 저장 완료
#  [2010-02-14] 저장 완료
#  [2010-02-15] 저장 완료
#  [2010-02-16] 저장 완료
#  [2010-02-17] 저장 완료
#  [2010-02-18] 저장 완료
#  [2010-02-19] 저장 완료
#  [2010-02-20] 저장 완료
#  [2010-02-21] 저장 완료
#  [2010-02-22] 저장 완료
#  [2010-02-23] 저장 완료
#  [2010-02-24] 저장 완료
#  [2010-02-25] 저장 완료
#  [2010-02-26] 저장 완료
#  [2010-02-27] 저장 완료
#  [2010-02-28] 저장 완료
#  [2010-03-01] 저장 완료
#  [2010-03-02] 저장 완료
#  [2010-03-03] 저장 완료
#  [2010-03-04] 저장 완료
#  [2010-03-05] 저장 완료
#  [2010-03-06] 저장 완료
#  [2010-03-07] 저장 완료
#  [2010-03-08] 저장 완료
#  [2010-03-09] 저장 완료
#  [2010-03-10] 저장 완료
#  [2010-03-11] 저장 완료
#  [2010-03-12] 저장 완료
#  [2010-03-13] 저장 완료
#  [2010-03-14] 저장 완료
#  [2010-03-15] 저장 완료
#  [2010-03-16] 저장 완료
#  [2010-03-17] 저장 완료
#  [2010-03-18] 저장 완료
#  [2010-03-19] 저장 완료
#  [2010-03-20] 저장 완료
#  [2010-03-21] 저장 완료
#  [2010-03-22] 저장 완료
#  [2010-03-23] 저장 완료
#  [2010-03-24] 저장 완료
# ❌ [2010-03-25] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2010-03-25] 저장 완료
#  [2010-03-26] 저장 완료
#  [2010-03-27] 저장 완료
#  [2010-03-28] 저장 완료
#  [2010-03-29] 저장 완료
#  [2010-03-30] 저장 완료
#  [2010-03-31] 저장 완료
#  [2010-04-01] 저장 완료
#  [2010-04-02] 저장 완료
#  [2010-04-03] 저장 완료
#  [2010-04-04] 저장 완료
#  [2010-04-05] 저장 완료
#  [2010-04-06] 저장 완료
# ❌ [2010-04-07] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2010-04-07] 저장 완료
#  [2010-04-08] 저장 완료
#  [2010-04-09] 저장 완료
#  [2010-04-10] 저장 완료
#  [2010-04-11] 저장 완료
#  [2010-04-12] 저장 완료
#  [2010-04-13] 저장 완료
#  [2010-04-14] 저장 완료
#  [2010-04-15] 저장 완료
#  [2010-04-16] 저장 완료
#  [2010-04-17] 저장 완료
#  [2010-04-18] 저장 완료
#  [2010-04-19] 저장 완료
# ❌ [2010-04-20] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2010-04-20] 저장 완료
#  [2010-04-21] 저장 완료
#  [2010-04-22] 저장 완료
# ❌ [2010-04-23] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2010-04-23] 저장 완료
#  [2010-04-24] 저장 완료
#  [2010-04-25] 저장 완료
# ❌ [2010-04-26] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2010-04-26] 저장 완료
#  [2010-04-27] 저장 완료
#  [2010-04-28] 저장 완료
#  [2010-04-29] 저장 완료
#  [2010-04-30] 저장 완료
#  [2010-05-01] 저장 완료
#  [2010-05-02] 저장 완료
#  [2010-05-03] 저장 완료
#  [2010-05-04] 저장 완료
# ❌ [2010-05-05] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2010-05-05] 저장 완료
#  [2010-05-06] 저장 완료
#  [2010-05-07] 저장 완료
#  [2010-05-08] 저장 완료
#  [2010-05-09] 저장 완료
#  [2010-05-10] 저장 완료
#  [2010-05-11] 저장 완료
# ❌ [2010-05-12] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2010-05-12] 저장 완료
#  [2010-05-13] 저장 완료
#  [2010-05-14] 저장 완료
#  [2010-05-15] 저장 완료
#  [2010-05-16] 저장 완료
#  [2010-05-17] 저장 완료
#  [2010-05-18] 저장 완료
#  [2010-05-19] 저장 완료
#  [2010-05-20] 저장 완료
#  [2010-05-21] 저장 완료
#  [2010-05-22] 저장 완료
#  [2010-05-23] 저장 완료
#  [2010-05-24] 저장 완료
#  [2010-05-25] 저장 완료
#  [2010-05-26] 저장 완료
#  [2010-05-27] 저장 완료
#  [2010-05-28] 저장 완료
#  [2010-05-29] 저장 완료
#  [2010-05-30] 저장 완료
#  [2010-05-31] 저장 완료
#  [2010-06-01] 저장 완료
#  [2010-06-02] 저장 완료
#  [2010-06-03] 저장 완료
#  [2010-06-04] 저장 완료
#  [2010-06-05] 저장 완료
#  [2010-06-06] 저장 완료
#  [2010-06-07] 저장 완료
#  [2010-06-08] 저장 완료
#  [2010-06-09] 저장 완료
#  [2010-06-10] 저장 완료
#  [2010-06-11] 저장 완료
#  [2010-06-12] 저장 완료
#  [2010-06-13] 저장 완료
#  [2010-06-14] 저장 완료
#  [2010-06-15] 저장 완료
#  [2010-06-16] 저장 완료
#  [2010-06-17] 저장 완료
#  [2010-06-18] 저장 완료
#  [2010-06-19] 저장 완료
#  [2010-06-20] 저장 완료
#  [2010-06-21] 저장 완료
#  [2010-06-22] 저장 완료
#  [2010-06-23] 저장 완료
#  [2010-06-24] 저장 완료
#  [2010-06-25] 저장 완료
#  [2010-06-26] 저장 완료
#  [2010-06-27] 저장 완료
#  [2010-06-28] 저장 완료
#  [2010-06-29] 저장 완료
#  [2010-06-30] 저장 완료
#  [2010-07-01] 저장 완료
#  [2010-07-02] 저장 완료
#  [2010-07-03] 저장 완료
#  [2010-07-04] 저장 완료
#  [2010-07-05] 저장 완료
#  [2010-07-06] 저장 완료
#  [2010-07-07] 저장 완료
#  [2010-07-08] 저장 완료
#  [2010-07-09] 저장 완료
#  [2010-07-10] 저장 완료
#  [2010-07-11] 저장 완료
#  [2010-07-12] 저장 완료
#  [2010-07-13] 저장 완료
#  [2010-07-14] 저장 완료
#  [2010-07-15] 저장 완료
#  [2010-07-16] 저장 완료
#  [2010-07-17] 저장 완료
#  [2010-07-18] 저장 완료
#  [2010-07-19] 저장 완료
#  [2010-07-20] 저장 완료
#  [2010-07-21] 저장 완료
#  [2010-07-22] 저장 완료
#  [2010-07-23] 저장 완료
#  [2010-07-24] 저장 완료
#  [2010-07-25] 저장 완료
#  [2010-07-26] 저장 완료
#  [2010-07-27] 저장 완료
#  [2010-07-28] 저장 완료
#  [2010-07-29] 저장 완료
#  [2010-07-30] 저장 완료
#  [2010-07-31] 저장 완료
#  [2010-08-01] 저장 완료
#  [2010-08-02] 저장 완료
#  [2010-08-03] 저장 완료
#  [2010-08-04] 저장 완료
#  [2010-08-05] 저장 완료
#  [2010-08-06] 저장 완료
#  [2010-08-07] 저장 완료
#  [2010-08-08] 저장 완료
#  [2010-08-09] 저장 완료
#  [2010-08-10] 저장 완료
#  [2010-08-11] 저장 완료
#  [2010-08-12] 저장 완료
#  [2010-08-13] 저장 완료
#  [2010-08-14] 저장 완료
#  [2010-08-15] 저장 완료
#  [2010-08-16] 저장 완료
#  [2010-08-17] 저장 완료
#  [2010-08-18] 저장 완료
#  [2010-08-19] 저장 완료
#  [2010-08-20] 저장 완료
#  [2010-08-21] 저장 완료
#  [2010-08-22] 저장 완료
#  [2010-08-23] 저장 완료
#  [2010-08-24] 저장 완료
#  [2010-08-25] 저장 완료
#  [2010-08-26] 저장 완료
#  [2010-08-27] 저장 완료
#  [2010-08-28] 저장 완료
#  [2010-08-29] 저장 완료
#  [2010-08-30] 저장 완료
#  [2010-08-31] 저장 완료
#  [2010-09-01] 저장 완료
#  [2010-09-02] 저장 완료
#  [2010-09-03] 저장 완료
#  [2010-09-04] 저장 완료
#  [2010-09-05] 저장 완료
#  [2010-09-06] 저장 완료
#  [2010-09-07] 저장 완료
#  [2010-09-08] 저장 완료
#  [2010-09-09] 저장 완료
#  [2010-09-10] 저장 완료
#  [2010-09-11] 저장 완료
#  [2010-09-12] 저장 완료
#  [2010-09-13] 저장 완료
#  [2010-09-14] 저장 완료
#  [2010-09-15] 저장 완료
#  [2010-09-16] 저장 완료
#  [2010-09-17] 저장 완료
#  [2010-09-18] 저장 완료
#  [2010-09-19] 저장 완료
#  [2010-09-20] 저장 완료
#  [2010-09-21] 저장 완료
#  [2010-09-22] 저장 완료
#  [2010-09-23] 저장 완료
#  [2010-09-24] 저장 완료
#  [2010-09-25] 저장 완료
#  [2010-09-26] 저장 완료
#  [2010-09-27] 저장 완료
#  [2010-09-28] 저장 완료
#  [2010-09-29] 저장 완료
#  [2010-09-30] 저장 완료
#  [2010-10-01] 저장 완료
#  [2010-10-02] 저장 완료
#  [2010-10-03] 저장 완료
#  [2010-10-04] 저장 완료
#  [2010-10-05] 저장 완료
#  [2010-10-06] 저장 완료
#  [2010-10-07] 저장 완료
#  [2010-10-08] 저장 완료
#  [2010-10-09] 저장 완료
#  [2010-10-10] 저장 완료
#  [2010-10-11] 저장 완료
#  [2010-10-12] 저장 완료
#  [2010-10-13] 저장 완료
#  [2010-10-14] 저장 완료
#  [2010-10-15] 저장 완료
#  [2010-10-16] 저장 완료
#  [2010-10-17] 저장 완료
#  [2010-10-18] 저장 완료
#  [2010-10-19] 저장 완료
#  [2010-10-20] 저장 완료
#  [2010-10-21] 저장 완료
#  [2010-10-22] 저장 완료
#  [2010-10-23] 저장 완료
#  [2010-10-24] 저장 완료
#  [2010-10-25] 저장 완료
#  [2010-10-26] 저장 완료
#  [2010-10-27] 저장 완료
#  [2010-10-28] 저장 완료
#  [2010-10-29] 저장 완료
#  [2010-10-30] 저장 완료
#  [2010-10-31] 저장 완료
#  [2010-11-01] 저장 완료
#  [2010-11-02] 저장 완료
#  [2010-11-03] 저장 완료
#  [2010-11-04] 저장 완료
#  [2010-11-05] 저장 완료
#  [2010-11-06] 저장 완료
#  [2010-11-07] 저장 완료
#  [2010-11-08] 저장 완료
#  [2010-11-09] 저장 완료
#  [2010-11-10] 저장 완료
#  [2010-11-11] 저장 완료
#  [2010-11-12] 저장 완료
#  [2010-11-13] 저장 완료
#  [2010-11-14] 저장 완료
#  [2010-11-15] 저장 완료
#  [2010-11-16] 저장 완료
#  [2010-11-17] 저장 완료
#  [2010-11-18] 저장 완료
#  [2010-11-19] 저장 완료
#  [2010-11-20] 저장 완료
#  [2010-11-21] 저장 완료
#  [2010-11-22] 저장 완료
#  [2010-11-23] 저장 완료
#  [2010-11-24] 저장 완료
#  [2010-11-25] 저장 완료
#  [2010-11-26] 저장 완료
#  [2010-11-27] 저장 완료
#  [2010-11-28] 저장 완료
#  [2010-11-29] 저장 완료
#  [2010-11-30] 저장 완료
#  [2010-12-01] 저장 완료
#  [2010-12-02] 저장 완료
#  [2010-12-03] 저장 완료
#  [2010-12-04] 저장 완료
#  [2010-12-05] 저장 완료
#  [2010-12-06] 저장 완료
#  [2010-12-07] 저장 완료
#  [2010-12-08] 저장 완료
#  [2010-12-09] 저장 완료
#  [2010-12-10] 저장 완료
#  [2010-12-11] 저장 완료
#  [2010-12-12] 저장 완료
#  [2010-12-13] 저장 완료
#  [2010-12-14] 저장 완료
#  [2010-12-15] 저장 완료
#  [2010-12-16] 저장 완료
#  [2010-12-17] 저장 완료
#  [2010-12-18] 저장 완료
#  [2010-12-19] 저장 완료
#  [2010-12-20] 저장 완료
#  [2010-12-21] 저장 완료
#  [2010-12-22] 저장 완료
#  [2010-12-23] 저장 완료
#  [2010-12-24] 저장 완료
#  [2010-12-25] 저장 완료
#  [2010-12-26] 저장 완료
#  [2010-12-27] 저장 완료
#  [2010-12-28] 저장 완료
#  [2010-12-29] 저장 완료
#  [2010-12-30] 저장 완료
#  [2010-12-31] 저장 완료
#  [2011-01-01] 저장 완료
#  [2011-01-02] 저장 완료
#  [2011-01-03] 저장 완료
#  [2011-01-04] 저장 완료
#  [2011-01-05] 저장 완료
#  [2011-01-06] 저장 완료
#  [2011-01-07] 저장 완료
#  [2011-01-08] 저장 완료
#  [2011-01-09] 저장 완료
#  [2011-01-10] 저장 완료
#  [2011-01-11] 저장 완료
#  [2011-01-12] 저장 완료
#  [2011-01-13] 저장 완료
#  [2011-01-14] 저장 완료
#  [2011-01-15] 저장 완료
#  [2011-01-16] 저장 완료
#  [2011-01-17] 저장 완료
#  [2011-01-18] 저장 완료
#  [2011-01-19] 저장 완료
#  [2011-01-20] 저장 완료
#  [2011-01-21] 저장 완료
#  [2011-01-22] 저장 완료
#  [2011-01-23] 저장 완료
#  [2011-01-24] 저장 완료
#  [2011-01-25] 저장 완료
#  [2011-01-26] 저장 완료
#  [2011-01-27] 저장 완료
#  [2011-01-28] 저장 완료
#  [2011-01-29] 저장 완료
#  [2011-01-30] 저장 완료
#  [2011-01-31] 저장 완료
#  [2011-02-01] 저장 완료
#  [2011-02-02] 저장 완료
#  [2011-02-03] 저장 완료
#  [2011-02-04] 저장 완료
#  [2011-02-05] 저장 완료
#  [2011-02-06] 저장 완료
#  [2011-02-07] 저장 완료
#  [2011-02-08] 저장 완료
#  [2011-02-09] 저장 완료
#  [2011-02-10] 저장 완료
#  [2011-02-11] 저장 완료
#  [2011-02-12] 저장 완료
#  [2011-02-13] 저장 완료
#  [2011-02-14] 저장 완료
#  [2011-02-15] 저장 완료
#  [2011-02-16] 저장 완료
#  [2011-02-17] 저장 완료
#  [2011-02-18] 저장 완료
#  [2011-02-19] 저장 완료
#  [2011-02-20] 저장 완료
#  [2011-02-21] 저장 완료
#  [2011-02-22] 저장 완료
#  [2011-02-23] 저장 완료
#  [2011-02-24] 저장 완료
#  [2011-02-25] 저장 완료
#  [2011-02-26] 저장 완료
#  [2011-02-27] 저장 완료
#  [2011-02-28] 저장 완료
#  [2011-03-01] 저장 완료
#  [2011-03-02] 저장 완료
#  [2011-03-03] 저장 완료
#  [2011-03-04] 저장 완료
#  [2011-03-05] 저장 완료
#  [2011-03-06] 저장 완료
#  [2011-03-07] 저장 완료
#  [2011-03-08] 저장 완료
#  [2011-03-09] 저장 완료
#  [2011-03-10] 저장 완료
#  [2011-03-11] 저장 완료
#  [2011-03-12] 저장 완료
#  [2011-03-13] 저장 완료
#  [2011-03-14] 저장 완료
#  [2011-03-15] 저장 완료
#  [2011-03-16] 저장 완료
#  [2011-03-17] 저장 완료
#  [2011-03-18] 저장 완료
#  [2011-03-19] 저장 완료
#  [2011-03-20] 저장 완료
#  [2011-03-21] 저장 완료
#  [2011-03-22] 저장 완료
#  [2011-03-23] 저장 완료
#  [2011-03-24] 저장 완료
#  [2011-03-25] 저장 완료
#  [2011-03-26] 저장 완료
#  [2011-03-27] 저장 완료
#  [2011-03-28] 저장 완료
#  [2011-03-29] 저장 완료
#  [2011-03-30] 저장 완료
#  [2011-03-31] 저장 완료
#  [2011-04-01] 저장 완료
#  [2011-04-02] 저장 완료
#  [2011-04-03] 저장 완료
#  [2011-04-04] 저장 완료
#  [2011-04-05] 저장 완료
#  [2011-04-06] 저장 완료
#  [2011-04-07] 저장 완료
#  [2011-04-08] 저장 완료
#  [2011-04-09] 저장 완료
#  [2011-04-10] 저장 완료
#  [2011-04-11] 저장 완료
#  [2011-04-12] 저장 완료
#  [2011-04-13] 저장 완료
#  [2011-04-14] 저장 완료
#  [2011-04-15] 저장 완료
#  [2011-04-16] 저장 완료
#  [2011-04-17] 저장 완료
#  [2011-04-18] 저장 완료
#  [2011-04-19] 저장 완료
#  [2011-04-20] 저장 완료
#  [2011-04-21] 저장 완료
#  [2011-04-22] 저장 완료
#  [2011-04-23] 저장 완료
#  [2011-04-24] 저장 완료
#  [2011-04-25] 저장 완료
#  [2011-04-26] 저장 완료
#  [2011-04-27] 저장 완료
#  [2011-04-28] 저장 완료
#  [2011-04-29] 저장 완료
#  [2011-04-30] 저장 완료
#  [2011-05-01] 저장 완료
#  [2011-05-02] 저장 완료
#  [2011-05-03] 저장 완료
#  [2011-05-04] 저장 완료
#  [2011-05-05] 저장 완료
#  [2011-05-06] 저장 완료
#  [2011-05-07] 저장 완료
#  [2011-05-08] 저장 완료
#  [2011-05-09] 저장 완료
#  [2011-05-10] 저장 완료
#  [2011-05-11] 저장 완료
#  [2011-05-12] 저장 완료
#  [2011-05-13] 저장 완료
#  [2011-05-14] 저장 완료
#  [2011-05-15] 저장 완료
#  [2011-05-16] 저장 완료
#  [2011-05-17] 저장 완료
#  [2011-05-18] 저장 완료
#  [2011-05-19] 저장 완료
#  [2011-05-20] 저장 완료
#  [2011-05-21] 저장 완료
#  [2011-05-22] 저장 완료
#  [2011-05-23] 저장 완료
#  [2011-05-24] 저장 완료
#  [2011-05-25] 저장 완료
#  [2011-05-26] 저장 완료
#  [2011-05-27] 저장 완료
#  [2011-05-28] 저장 완료
#  [2011-05-29] 저장 완료
#  [2011-05-30] 저장 완료
#  [2011-05-31] 저장 완료
#  [2011-06-01] 저장 완료
#  [2011-06-02] 저장 완료
#  [2011-06-03] 저장 완료
#  [2011-06-04] 저장 완료
#  [2011-06-05] 저장 완료
#  [2011-06-06] 저장 완료
#  [2011-06-07] 저장 완료
#  [2011-06-08] 저장 완료
#  [2011-06-09] 저장 완료
#  [2011-06-10] 저장 완료
#  [2011-06-11] 저장 완료
#  [2011-06-12] 저장 완료
#  [2011-06-13] 저장 완료
#  [2011-06-14] 저장 완료
#  [2011-06-15] 저장 완료
#  [2011-06-16] 저장 완료
#  [2011-06-17] 저장 완료
#  [2011-06-18] 저장 완료
#  [2011-06-19] 저장 완료
#  [2011-06-20] 저장 완료
#  [2011-06-21] 저장 완료
#  [2011-06-22] 저장 완료
#  [2011-06-23] 저장 완료
#  [2011-06-24] 저장 완료
#  [2011-06-25] 저장 완료
#  [2011-06-26] 저장 완료
#  [2011-06-27] 저장 완료
#  [2011-06-28] 저장 완료
#  [2011-06-29] 저장 완료
#  [2011-06-30] 저장 완료
#  [2011-07-01] 저장 완료
#  [2011-07-02] 저장 완료
#  [2011-07-03] 저장 완료
#  [2011-07-04] 저장 완료
#  [2011-07-05] 저장 완료
#  [2011-07-06] 저장 완료
#  [2011-07-07] 저장 완료
#  [2011-07-08] 저장 완료
#  [2011-07-09] 저장 완료
#  [2011-07-10] 저장 완료
#  [2011-07-11] 저장 완료
#  [2011-07-12] 저장 완료
#  [2011-07-13] 저장 완료
#  [2011-07-14] 저장 완료
#  [2011-07-15] 저장 완료
#  [2011-07-16] 저장 완료
#  [2011-07-17] 저장 완료
#  [2011-07-18] 저장 완료
#  [2011-07-19] 저장 완료
#  [2011-07-20] 저장 완료
#  [2011-07-21] 저장 완료
#  [2011-07-22] 저장 완료
#  [2011-07-23] 저장 완료
#  [2011-07-24] 저장 완료
#  [2011-07-25] 저장 완료
#  [2011-07-26] 저장 완료
#  [2011-07-27] 저장 완료
#  [2011-07-28] 저장 완료
#  [2011-07-29] 저장 완료
#  [2011-07-30] 저장 완료
#  [2011-07-31] 저장 완료
#  [2011-08-01] 저장 완료
#  [2011-08-02] 저장 완료
#  [2011-08-03] 저장 완료
#  [2011-08-04] 저장 완료
#  [2011-08-05] 저장 완료
#  [2011-08-06] 저장 완료
#  [2011-08-07] 저장 완료
#  [2011-08-08] 저장 완료
#  [2011-08-09] 저장 완료
#  [2011-08-10] 저장 완료
#  [2011-08-11] 저장 완료
#  [2011-08-12] 저장 완료
#  [2011-08-13] 저장 완료
#  [2011-08-14] 저장 완료
#  [2011-08-15] 저장 완료
#  [2011-08-16] 저장 완료
#  [2011-08-17] 저장 완료
#  [2011-08-18] 저장 완료
#  [2011-08-19] 저장 완료
#  [2011-08-20] 저장 완료
#  [2011-08-21] 저장 완료
#  [2011-08-22] 저장 완료
#  [2011-08-23] 저장 완료
#  [2011-08-24] 저장 완료
#  [2011-08-25] 저장 완료
#  [2011-08-26] 저장 완료
#  [2011-08-27] 저장 완료
#  [2011-08-28] 저장 완료
#  [2011-08-29] 저장 완료
#  [2011-08-30] 저장 완료
#  [2011-08-31] 저장 완료
#  [2011-09-01] 저장 완료
#  [2011-09-02] 저장 완료
#  [2011-09-03] 저장 완료
#  [2011-09-04] 저장 완료
#  [2011-09-05] 저장 완료
#  [2011-09-06] 저장 완료
#  [2011-09-07] 저장 완료
#  [2011-09-08] 저장 완료
#  [2011-09-09] 저장 완료
#  [2011-09-10] 저장 완료
#  [2011-09-11] 저장 완료
#  [2011-09-12] 저장 완료
#  [2011-09-13] 저장 완료
#  [2011-09-14] 저장 완료
#  [2011-09-15] 저장 완료
#  [2011-09-16] 저장 완료
#  [2011-09-17] 저장 완료
#  [2011-09-18] 저장 완료
#  [2011-09-19] 저장 완료
#  [2011-09-20] 저장 완료
#  [2011-09-21] 저장 완료
#  [2011-09-22] 저장 완료
#  [2011-09-23] 저장 완료
# ...
#  [2023-05-20] 저장 완료
#  [2023-05-21] 저장 완료
#  [2023-05-22] 저장 완료
#  [2023-05-23] 저장 완료
#  [2023-05-24] 저장 완료
#  [2023-05-25] 저장 완료
#  [2023-05-26] 저장 완료
#  [2023-05-27] 저장 완료
#  [2023-05-28] 저장 완료
#  [2023-05-29] 저장 완료
#  [2023-05-30] 저장 완료
#  [2023-05-31] 저장 완료
#  [2023-06-01] 저장 완료
#  [2023-06-02] 저장 완료
#  [2023-06-03] 저장 완료
#  [2023-06-04] 저장 완료
#  [2023-06-05] 저장 완료
#  [2023-06-06] 저장 완료
#  [2023-06-07] 저장 완료
#  [2023-06-08] 저장 완료
#  [2023-06-09] 저장 완료
#  [2023-06-10] 저장 완료
#  [2023-06-11] 저장 완료
#  [2023-06-12] 저장 완료
#  [2023-06-13] 저장 완료
#  [2023-06-14] 저장 완료
#  [2023-06-15] 저장 완료
#  [2023-06-16] 저장 완료
#  [2023-06-17] 저장 완료
#  [2023-06-18] 저장 완료
#  [2023-06-19] 저장 완료
#  [2023-06-20] 저장 완료
#  [2023-06-21] 저장 완료
#  [2023-06-22] 저장 완료
#  [2023-06-23] 저장 완료
#  [2023-06-24] 저장 완료
#  [2023-06-25] 저장 완료
#  [2023-06-26] 저장 완료
#  [2023-06-27] 저장 완료
#  [2023-06-28] 저장 완료
#  [2023-06-29] 저장 완료
#  [2023-06-30] 저장 완료
#  [2023-07-01] 저장 완료
#  [2023-07-02] 저장 완료
#  [2023-07-03] 저장 완료
#  [2023-07-04] 저장 완료
#  [2023-07-05] 저장 완료
#  [2023-07-06] 저장 완료
#  [2023-07-07] 저장 완료
#  [2023-07-08] 저장 완료
#  [2023-07-09] 저장 완료
#  [2023-07-10] 저장 완료
#  [2023-07-11] 저장 완료
#  [2023-07-12] 저장 완료
#  [2023-07-13] 저장 완료
#  [2023-07-14] 저장 완료
#  [2023-07-15] 저장 완료
#  [2023-07-16] 저장 완료
#  [2023-07-17] 저장 완료
#  [2023-07-18] 저장 완료
#  [2023-07-19] 저장 완료
#  [2023-07-20] 저장 완료
#  [2023-07-21] 저장 완료
#  [2023-07-22] 저장 완료
#  [2023-07-23] 저장 완료
#  [2023-07-24] 저장 완료
#  [2023-07-25] 저장 완료
#  [2023-07-26] 저장 완료
#  [2023-07-27] 저장 완료
#  [2023-07-28] 저장 완료
#  [2023-07-29] 저장 완료
#  [2023-07-30] 저장 완료
#  [2023-07-31] 저장 완료
#  [2023-08-01] 저장 완료
#  [2023-08-02] 저장 완료
#  [2023-08-03] 저장 완료
#  [2023-08-04] 저장 완료
#  [2023-08-05] 저장 완료
#  [2023-08-06] 저장 완료
#  [2023-08-07] 저장 완료
#  [2023-08-08] 저장 완료
#  [2023-08-09] 저장 완료
#  [2023-08-10] 저장 완료
#  [2023-08-11] 저장 완료
#  [2023-08-12] 저장 완료
#  [2023-08-13] 저장 완료
#  [2023-08-14] 저장 완료
#  [2023-08-15] 저장 완료
#  [2023-08-16] 저장 완료
#  [2023-08-17] 저장 완료
#  [2023-08-18] 저장 완료
#  [2023-08-19] 저장 완료
#  [2023-08-20] 저장 완료
#  [2023-08-21] 저장 완료
#  [2023-08-22] 저장 완료
#  [2023-08-23] 저장 완료
#  [2023-08-24] 저장 완료
#  [2023-08-25] 저장 완료
#  [2023-08-26] 저장 완료
#  [2023-08-27] 저장 완료
#  [2023-08-28] 저장 완료
#  [2023-08-29] 저장 완료
#  [2023-08-30] 저장 완료
#  [2023-08-31] 저장 완료
#  [2023-09-01] 저장 완료
#  [2023-09-02] 저장 완료
#  [2023-09-03] 저장 완료
#  [2023-09-04] 저장 완료
#  [2023-09-05] 저장 완료
#  [2023-09-06] 저장 완료
#  [2023-09-07] 저장 완료
#  [2023-09-08] 저장 완료
#  [2023-09-09] 저장 완료
#  [2023-09-10] 저장 완료
#  [2023-09-11] 저장 완료
#  [2023-09-12] 저장 완료
#  [2023-09-13] 저장 완료
#  [2023-09-14] 저장 완료
#  [2023-09-15] 저장 완료
#  [2023-09-16] 저장 완료
#  [2023-09-17] 저장 완료
#  [2023-09-18] 저장 완료
#  [2023-09-19] 저장 완료
#  [2023-09-20] 저장 완료
#  [2023-09-21] 저장 완료
#  [2023-09-22] 저장 완료
#  [2023-09-23] 저장 완료
#  [2023-09-24] 저장 완료
#  [2023-09-25] 저장 완료
#  [2023-09-26] 저장 완료
#  [2023-09-27] 저장 완료
#  [2023-09-28] 저장 완료
#  [2023-09-29] 저장 완료
#  [2023-09-30] 저장 완료
#  [2023-10-01] 저장 완료
#  [2023-10-02] 저장 완료
#  [2023-10-03] 저장 완료
#  [2023-10-04] 저장 완료
#  [2023-10-05] 저장 완료
#  [2023-10-06] 저장 완료
#  [2023-10-07] 저장 완료
#  [2023-10-08] 저장 완료
#  [2023-10-09] 저장 완료
#  [2023-10-10] 저장 완료
#  [2023-10-11] 저장 완료
#  [2023-10-12] 저장 완료
#  [2023-10-13] 저장 완료
#  [2023-10-14] 저장 완료
#  [2023-10-15] 저장 완료
#  [2023-10-16] 저장 완료
#  [2023-10-17] 저장 완료
#  [2023-10-18] 저장 완료
#  [2023-10-19] 저장 완료
#  [2023-10-20] 저장 완료
#  [2023-10-21] 저장 완료
#  [2023-10-22] 저장 완료
#  [2023-10-23] 저장 완료
#  [2023-10-24] 저장 완료
#  [2023-10-25] 저장 완료
#  [2023-10-26] 저장 완료
#  [2023-10-27] 저장 완료
#  [2023-10-28] 저장 완료
#  [2023-10-29] 저장 완료
#  [2023-10-30] 저장 완료
#  [2023-10-31] 저장 완료
#  [2023-11-01] 저장 완료
#  [2023-11-02] 저장 완료
#  [2023-11-03] 저장 완료
#  [2023-11-04] 저장 완료
#  [2023-11-05] 저장 완료
#  [2023-11-06] 저장 완료
#  [2023-11-07] 저장 완료
#  [2023-11-08] 저장 완료
#  [2023-11-09] 저장 완료
#  [2023-11-10] 저장 완료
#  [2023-11-11] 저장 완료
#  [2023-11-12] 저장 완료
#  [2023-11-13] 저장 완료
#  [2023-11-14] 저장 완료
#  [2023-11-15] 저장 완료
#  [2023-11-16] 저장 완료
#  [2023-11-17] 저장 완료
#  [2023-11-18] 저장 완료
#  [2023-11-19] 저장 완료
#  [2023-11-20] 저장 완료
#  [2023-11-21] 저장 완료
#  [2023-11-22] 저장 완료
#  [2023-11-23] 저장 완료
#  [2023-11-24] 저장 완료
#  [2023-11-25] 저장 완료
#  [2023-11-26] 저장 완료
#  [2023-11-27] 저장 완료
#  [2023-11-28] 저장 완료
#  [2023-11-29] 저장 완료
#  [2023-11-30] 저장 완료
#  [2023-12-01] 저장 완료
#  [2023-12-02] 저장 완료
#  [2023-12-03] 저장 완료
#  [2023-12-04] 저장 완료
#  [2023-12-05] 저장 완료
#  [2023-12-06] 저장 완료
#  [2023-12-07] 저장 완료
#  [2023-12-08] 저장 완료
#  [2023-12-09] 저장 완료
#  [2023-12-10] 저장 완료
#  [2023-12-11] 저장 완료
#  [2023-12-12] 저장 완료
#  [2023-12-13] 저장 완료
#  [2023-12-14] 저장 완료
#  [2023-12-15] 저장 완료
#  [2023-12-16] 저장 완료
#  [2023-12-17] 저장 완료
#  [2023-12-18] 저장 완료
#  [2023-12-19] 저장 완료
#  [2023-12-20] 저장 완료
#  [2023-12-21] 저장 완료
#  [2023-12-22] 저장 완료
#  [2023-12-23] 저장 완료
#  [2023-12-24] 저장 완료
#  [2023-12-25] 저장 완료
#  [2023-12-26] 저장 완료
#  [2023-12-27] 저장 완료
#  [2023-12-28] 저장 완료
#  [2023-12-29] 저장 완료
#  [2023-12-30] 저장 완료
#  [2023-12-31] 저장 완료
#  [2024-01-01] 저장 완료
#  [2024-01-02] 저장 완료
#  [2024-01-03] 저장 완료
#  [2024-01-04] 저장 완료
#  [2024-01-05] 저장 완료
#  [2024-01-06] 저장 완료
#  [2024-01-07] 저장 완료
#  [2024-01-08] 저장 완료
#  [2024-01-09] 저장 완료
#  [2024-01-10] 저장 완료
#  [2024-01-11] 저장 완료
#  [2024-01-12] 저장 완료
#  [2024-01-13] 저장 완료
#  [2024-01-14] 저장 완료
#  [2024-01-15] 저장 완료
#  [2024-01-16] 저장 완료
#  [2024-01-17] 저장 완료
#  [2024-01-18] 저장 완료
#  [2024-01-19] 저장 완료
#  [2024-01-20] 저장 완료
#  [2024-01-21] 저장 완료
#  [2024-01-22] 저장 완료
#  [2024-01-23] 저장 완료
#  [2024-01-24] 저장 완료
#  [2024-01-25] 저장 완료
#  [2024-01-26] 저장 완료
#  [2024-01-27] 저장 완료
#  [2024-01-28] 저장 완료
#  [2024-01-29] 저장 완료
#  [2024-01-30] 저장 완료
#  [2024-01-31] 저장 완료
#  [2024-02-01] 저장 완료
#  [2024-02-02] 저장 완료
#  [2024-02-03] 저장 완료
#  [2024-02-04] 저장 완료
#  [2024-02-05] 저장 완료
#  [2024-02-06] 저장 완료
#  [2024-02-07] 저장 완료
#  [2024-02-08] 저장 완료
#  [2024-02-09] 저장 완료
#  [2024-02-10] 저장 완료
#  [2024-02-11] 저장 완료
#  [2024-02-12] 저장 완료
#  [2024-02-13] 저장 완료
#  [2024-02-14] 저장 완료
#  [2024-02-15] 저장 완료
#  [2024-02-16] 저장 완료
#  [2024-02-17] 저장 완료
#  [2024-02-18] 저장 완료
#  [2024-02-19] 저장 완료
#  [2024-02-20] 저장 완료
#  [2024-02-21] 저장 완료
#  [2024-02-22] 저장 완료
#  [2024-02-23] 저장 완료
#  [2024-02-24] 저장 완료
#  [2024-02-25] 저장 완료
#  [2024-02-26] 저장 완료
#  [2024-02-27] 저장 완료
#  [2024-02-28] 저장 완료
#  [2024-02-29] 저장 완료
#  [2024-03-01] 저장 완료
#  [2024-03-02] 저장 완료
#  [2024-03-03] 저장 완료
#  [2024-03-04] 저장 완료
#  [2024-03-05] 저장 완료
#  [2024-03-06] 저장 완료
#  [2024-03-07] 저장 완료
#  [2024-03-08] 저장 완료
#  [2024-03-09] 저장 완료
#  [2024-03-10] 저장 완료
#  [2024-03-11] 저장 완료
#  [2024-03-12] 저장 완료
#  [2024-03-13] 저장 완료
#  [2024-03-14] 저장 완료
#  [2024-03-15] 저장 완료
#  [2024-03-16] 저장 완료
#  [2024-03-17] 저장 완료
#  [2024-03-18] 저장 완료
#  [2024-03-19] 저장 완료
#  [2024-03-20] 저장 완료
#  [2024-03-21] 저장 완료
#  [2024-03-22] 저장 완료
#  [2024-03-23] 저장 완료
#  [2024-03-24] 저장 완료
#  [2024-03-25] 저장 완료
#  [2024-03-26] 저장 완료
#  [2024-03-27] 저장 완료
#  [2024-03-28] 저장 완료
#  [2024-03-29] 저장 완료
#  [2024-03-30] 저장 완료
#  [2024-03-31] 저장 완료
#  [2024-04-01] 저장 완료
#  [2024-04-02] 저장 완료
# ❌ [2024-04-03] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2024-04-03] 저장 완료
#  [2024-04-04] 저장 완료
#  [2024-04-05] 저장 완료
# ❌ [2024-04-06] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2024-04-06] 저장 완료
#  [2024-04-07] 저장 완료
#  [2024-04-08] 저장 완료
#  [2024-04-09] 저장 완료
#  [2024-04-10] 저장 완료
#  [2024-04-11] 저장 완료
#  [2024-04-12] 저장 완료
#  [2024-04-13] 저장 완료
#  [2024-04-14] 저장 완료
#  [2024-04-15] 저장 완료
#  [2024-04-16] 저장 완료
#  [2024-04-17] 저장 완료
#  [2024-04-18] 저장 완료
#  [2024-04-19] 저장 완료
#  [2024-04-20] 저장 완료
#  [2024-04-21] 저장 완료
#  [2024-04-22] 저장 완료
#  [2024-04-23] 저장 완료
#  [2024-04-24] 저장 완료
#  [2024-04-25] 저장 완료
#  [2024-04-26] 저장 완료
#  [2024-04-27] 저장 완료
#  [2024-04-28] 저장 완료
#  [2024-04-29] 저장 완료
#  [2024-04-30] 저장 완료
#  [2024-05-01] 저장 완료
#  [2024-05-02] 저장 완료
#  [2024-05-03] 저장 완료
#  [2024-05-04] 저장 완료
#  [2024-05-05] 저장 완료
#  [2024-05-06] 저장 완료
#  [2024-05-07] 저장 완료
#  [2024-05-08] 저장 완료
#  [2024-05-09] 저장 완료
#  [2024-05-10] 저장 완료
#  [2024-05-11] 저장 완료
#  [2024-05-12] 저장 완료
#  [2024-05-13] 저장 완료
#  [2024-05-14] 저장 완료
#  [2024-05-15] 저장 완료
#  [2024-05-16] 저장 완료
#  [2024-05-17] 저장 완료
#  [2024-05-18] 저장 완료
#  [2024-05-19] 저장 완료
#  [2024-05-20] 저장 완료
#  [2024-05-21] 저장 완료
#  [2024-05-22] 저장 완료
#  [2024-05-23] 저장 완료
#  [2024-05-24] 저장 완료
#  [2024-05-25] 저장 완료
#  [2024-05-26] 저장 완료
#  [2024-05-27] 저장 완료
#  [2024-05-28] 저장 완료
#  [2024-05-29] 저장 완료
#  [2024-05-30] 저장 완료
#  [2024-05-31] 저장 완료
#  [2024-06-01] 저장 완료
#  [2024-06-02] 저장 완료
#  [2024-06-03] 저장 완료
#  [2024-06-04] 저장 완료
#  [2024-06-05] 저장 완료
#  [2024-06-06] 저장 완료
#  [2024-06-07] 저장 완료
#  [2024-06-08] 저장 완료
#  [2024-06-09] 저장 완료
#  [2024-06-10] 저장 완료
#  [2024-06-11] 저장 완료
#  [2024-06-12] 저장 완료
#  [2024-06-13] 저장 완료
#  [2024-06-14] 저장 완료
#  [2024-06-15] 저장 완료
#  [2024-06-16] 저장 완료
#  [2024-06-17] 저장 완료
#  [2024-06-18] 저장 완료
#  [2024-06-19] 저장 완료
#  [2024-06-20] 저장 완료
#  [2024-06-21] 저장 완료
#  [2024-06-22] 저장 완료
#  [2024-06-23] 저장 완료
#  [2024-06-24] 저장 완료
#  [2024-06-25] 저장 완료
#  [2024-06-26] 저장 완료
#  [2024-06-27] 저장 완료
#  [2024-06-28] 저장 완료
#  [2024-06-29] 저장 완료
#  [2024-06-30] 저장 완료
#  [2024-07-01] 저장 완료
#  [2024-07-02] 저장 완료
#  [2024-07-03] 저장 완료
#  [2024-07-04] 저장 완료
#  [2024-07-05] 저장 완료
#  [2024-07-06] 저장 완료
#  [2024-07-07] 저장 완료
#  [2024-07-08] 저장 완료
#  [2024-07-09] 저장 완료
#  [2024-07-10] 저장 완료
#  [2024-07-11] 저장 완료
#  [2024-07-12] 저장 완료
#  [2024-07-13] 저장 완료
#  [2024-07-14] 저장 완료
#  [2024-07-15] 저장 완료
#  [2024-07-16] 저장 완료
#  [2024-07-17] 저장 완료
#  [2024-07-18] 저장 완료
#  [2024-07-19] 저장 완료
#  [2024-07-20] 저장 완료
#  [2024-07-21] 저장 완료
#  [2024-07-22] 저장 완료
#  [2024-07-23] 저장 완료
#  [2024-07-24] 저장 완료
#  [2024-07-25] 저장 완료
#  [2024-07-26] 저장 완료
#  [2024-07-27] 저장 완료
#  [2024-07-28] 저장 완료
#  [2024-07-29] 저장 완료
#  [2024-07-30] 저장 완료
#  [2024-07-31] 저장 완료
#  [2024-08-01] 저장 완료
#  [2024-08-02] 저장 완료
#  [2024-08-03] 저장 완료
#  [2024-08-04] 저장 완료
#  [2024-08-05] 저장 완료
#  [2024-08-06] 저장 완료
#  [2024-08-07] 저장 완료
#  [2024-08-08] 저장 완료
#  [2024-08-09] 저장 완료
#  [2024-08-10] 저장 완료
#  [2024-08-11] 저장 완료
#  [2024-08-12] 저장 완료
#  [2024-08-13] 저장 완료
#  [2024-08-14] 저장 완료
#  [2024-08-15] 저장 완료
#  [2024-08-16] 저장 완료
#  [2024-08-17] 저장 완료
#  [2024-08-18] 저장 완료
#  [2024-08-19] 저장 완료
#  [2024-08-20] 저장 완료
#  [2024-08-21] 저장 완료
#  [2024-08-22] 저장 완료
#  [2024-08-23] 저장 완료
#  [2024-08-24] 저장 완료
#  [2024-08-25] 저장 완료
#  [2024-08-26] 저장 완료
#  [2024-08-27] 저장 완료
#  [2024-08-28] 저장 완료
#  [2024-08-29] 저장 완료
#  [2024-08-30] 저장 완료
#  [2024-08-31] 저장 완료
#  [2024-09-01] 저장 완료
#  [2024-09-02] 저장 완료
#  [2024-09-03] 저장 완료
#  [2024-09-04] 저장 완료
#  [2024-09-05] 저장 완료
#  [2024-09-06] 저장 완료
#  [2024-09-07] 저장 완료
#  [2024-09-08] 저장 완료
#  [2024-09-09] 저장 완료
#  [2024-09-10] 저장 완료
#  [2024-09-11] 저장 완료
#  [2024-09-12] 저장 완료
#  [2024-09-13] 저장 완료
#  [2024-09-14] 저장 완료
#  [2024-09-15] 저장 완료
#  [2024-09-16] 저장 완료
#  [2024-09-17] 저장 완료
#  [2024-09-18] 저장 완료
#  [2024-09-19] 저장 완료
#  [2024-09-20] 저장 완료
#  [2024-09-21] 저장 완료
#  [2024-09-22] 저장 완료
#  [2024-09-23] 저장 완료
#  [2024-09-24] 저장 완료
#  [2024-09-25] 저장 완료
#  [2024-09-26] 저장 완료
#  [2024-09-27] 저장 완료
#  [2024-09-28] 저장 완료
#  [2024-09-29] 저장 완료
#  [2024-09-30] 저장 완료
# ❌ [2024-10-01] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2024-10-01] 저장 완료
#  [2024-10-02] 저장 완료
#  [2024-10-03] 저장 완료
#  [2024-10-04] 저장 완료
#  [2024-10-05] 저장 완료
#  [2024-10-06] 저장 완료
#  [2024-10-07] 저장 완료
#  [2024-10-08] 저장 완료
#  [2024-10-09] 저장 완료
#  [2024-10-10] 저장 완료
#  [2024-10-11] 저장 완료
#  [2024-10-12] 저장 완료
#  [2024-10-13] 저장 완료
#  [2024-10-14] 저장 완료
#  [2024-10-15] 저장 완료
#  [2024-10-16] 저장 완료
#  [2024-10-17] 저장 완료
#  [2024-10-18] 저장 완료
#  [2024-10-19] 저장 완료
#  [2024-10-20] 저장 완료
#  [2024-10-21] 저장 완료
#  [2024-10-22] 저장 완료
#  [2024-10-23] 저장 완료
#  [2024-10-24] 저장 완료
#  [2024-10-25] 저장 완료
#  [2024-10-26] 저장 완료
#  [2024-10-27] 저장 완료
#  [2024-10-28] 저장 완료
#  [2024-10-29] 저장 완료
#  [2024-10-30] 저장 완료
#  [2024-10-31] 저장 완료
#  [2024-11-01] 저장 완료
#  [2024-11-02] 저장 완료
#  [2024-11-03] 저장 완료
#  [2024-11-04] 저장 완료
#  [2024-11-05] 저장 완료
#  [2024-11-06] 저장 완료
#  [2024-11-07] 저장 완료
#  [2024-11-08] 저장 완료
#  [2024-11-09] 저장 완료
#  [2024-11-10] 저장 완료
#  [2024-11-11] 저장 완료
#  [2024-11-12] 저장 완료
#  [2024-11-13] 저장 완료
#  [2024-11-14] 저장 완료
#  [2024-11-15] 저장 완료
#  [2024-11-16] 저장 완료
#  [2024-11-17] 저장 완료
#  [2024-11-18] 저장 완료
#  [2024-11-19] 저장 완료
#  [2024-11-20] 저장 완료
#  [2024-11-21] 저장 완료
#  [2024-11-22] 저장 완료
#  [2024-11-23] 저장 완료
#  [2024-11-24] 저장 완료
#  [2024-11-25] 저장 완료
#  [2024-11-26] 저장 완료
#  [2024-11-27] 저장 완료
#  [2024-11-28] 저장 완료
#  [2024-11-29] 저장 완료
#  [2024-11-30] 저장 완료
#  [2024-12-01] 저장 완료
#  [2024-12-02] 저장 완료
#  [2024-12-03] 저장 완료
#  [2024-12-04] 저장 완료
#  [2024-12-05] 저장 완료
#  [2024-12-06] 저장 완료
#  [2024-12-07] 저장 완료
#  [2024-12-08] 저장 완료
#  [2024-12-09] 저장 완료
#  [2024-12-10] 저장 완료
#  [2024-12-11] 저장 완료
#  [2024-12-12] 저장 완료
#  [2024-12-13] 저장 완료
#  [2024-12-14] 저장 완료
# ❌ [2024-12-15] 에러 발생: Expecting value: line 1 column 1 (char 0)
#  [2024-12-15] 저장 완료
#  [2024-12-16] 저장 완료
#  [2024-12-17] 저장 완료
#  [2024-12-18] 저장 완료
#  [2024-12-19] 저장 완료
#  [2024-12-20] 저장 완료
#  [2024-12-21] 저장 완료
#  [2024-12-22] 저장 완료
#  [2024-12-23] 저장 완료
#  [2024-12-24] 저장 완료
#  [2024-12-25] 저장 완료
#  [2024-12-26] 저장 완료
#  [2024-12-27] 저장 완료
#  [2024-12-28] 저장 완료
#  [2024-12-29] 저장 완료
#  [2024-12-30] 저장 완료
#  [2024-12-31] 저장 완료
#  [2025-01-01] 저장 완료
#  [2025-01-02] 저장 완료
#  [2025-01-03] 저장 완료
#  [2025-01-04] 저장 완료
#  [2025-01-05] 저장 완료
#  [2025-01-06] 저장 완료
#  [2025-01-07] 저장 완료
#  [2025-01-08] 저장 완료
#  [2025-01-09] 저장 완료
#  [2025-01-10] 저장 완료
#  [2025-01-11] 저장 완료
#  [2025-01-12] 저장 완료
#  [2025-01-13] 저장 완료
#  [2025-01-14] 저장 완료
#  [2025-01-15] 저장 완료
#  [2025-01-16] 저장 완료
#  [2025-01-17] 저장 완료
#  [2025-01-18] 저장 완료
#  [2025-01-19] 저장 완료
#  [2025-01-20] 저장 완료
#  [2025-01-21] 저장 완료
#  [2025-01-22] 저장 완료
#  [2025-01-23] 저장 완료
#  [2025-01-24] 저장 완료
#  [2025-01-25] 저장 완료
#  [2025-01-26] 저장 완료
#  [2025-01-27] 저장 완료
#  [2025-01-28] 저장 완료
#  [2025-01-29] 저장 완료
#  [2025-01-30] 저장 완료
#  [2025-01-31] 저장 완료
#  [2025-02-01] 저장 완료
#  [2025-02-02] 저장 완료
#  [2025-02-03] 저장 완료
#  [2025-02-04] 저장 완료
#  [2025-02-05] 저장 완료
#  [2025-02-06] 저장 완료
#  [2025-02-07] 저장 완료
#  [2025-02-08] 저장 완료
#  [2025-02-09] 저장 완료
#  [2025-02-10] 저장 완료
#  [2025-02-11] 저장 완료
#  [2025-02-12] 저장 완료
#  [2025-02-13] 저장 완료
#  [2025-02-14] 저장 완료
#  [2025-02-15] 저장 완료
#  [2025-02-16] 저장 완료
#  [2025-02-17] 저장 완료
#  [2025-02-18] 저장 완료
#  [2025-02-19] 저장 완료
#  [2025-02-20] 저장 완료
#  [2025-02-21] 저장 완료
#  [2025-02-22] 저장 완료
#  [2025-02-23] 저장 완료
#  [2025-02-24] 저장 완료
#  [2025-02-25] 저장 완료
#  [2025-02-26] 저장 완료
#  [2025-02-27] 저장 완료
#  [2025-02-28] 저장 완료
#  [2025-03-01] 저장 완료
#  [2025-03-02] 저장 완료
#  [2025-03-03] 저장 완료
#  [2025-03-04] 저장 완료
#  [2025-03-05] 저장 완료
#  [2025-03-06] 저장 완료
#  [2025-03-07] 저장 완료
#  [2025-03-08] 저장 완료
#  [2025-03-09] 저장 완료
#  [2025-03-10] 저장 완료
#  [2025-03-11] 저장 완료
#  [2025-03-12] 저장 완료
#  [2025-03-13] 저장 완료
#  [2025-03-14] 저장 완료
#  [2025-03-15] 저장 완료
#  [2025-03-16] 저장 완료
#  [2025-03-17] 저장 완료
#  [2025-03-18] 저장 완료
#  [2025-03-19] 저장 완료
#  [2025-03-20] 저장 완료
#  [2025-03-21] 저장 완료
#  [2025-03-22] 저장 완료
#  [2025-03-23] 저장 완료
#  [2025-03-24] 저장 완료
#  [2025-03-25] 저장 완료
#  [2025-03-26] 저장 완료
#  [2025-03-27] 저장 완료
#  [2025-03-28] 저장 완료
#  [2025-03-29] 저장 완료
#  [2025-03-30] 저장 완료
#  [2025-03-31] 저장 완료
#  [2025-04-01] 저장 완료
#  [2025-04-02] 저장 완료
#  [2025-04-03] 저장 완료
#  [2025-04-04] 저장 완료
#  [2025-04-05] 저장 완료
#  [2025-04-06] 저장 완료
#  [2025-04-07] 저장 완료
#  [2025-04-08] 저장 완료
#  [2025-04-09] 저장 완료
#  [2025-04-10] 저장 완료
#  [2025-04-11] 저장 완료
#  [2025-04-12] 저장 완료
#  [2025-04-13] 저장 완료
#  [2025-04-14] 저장 완료
#  [2025-04-15] 저장 완료
#  [2025-04-16] 저장 완료
#  [2025-04-17] 저장 완료
#  [2025-04-18] 저장 완료
#  [2025-04-19] 저장 완료
#  [2025-04-20] 저장 완료
#  [2025-04-21] 저장 완료
#  [2025-04-22] 저장 완료
#  [2025-04-23] 저장 완료
#  [2025-04-24] 저장 완료
#  [2025-04-25] 저장 완료
#  [2025-04-26] 저장 완료
#  [2025-04-27] 저장 완료
#  [2025-04-28] 저장 완료
#  [2025-04-29] 저장 완료
#  [2025-04-30] 저장 완료
#  [2025-05-01] 저장 완료
#  [2025-05-02] 저장 완료
#  [2025-05-03] 저장 완료
#  [2025-05-04] 저장 완료
#  [2025-05-05] 저장 완료
#  [2025-05-06] 저장 완료
#  [2025-05-07] 저장 완료
#  [2025-05-08] 저장 완료
#  [2025-05-09] 저장 완료
#  [2025-05-10] 저장 완료
#  [2025-05-11] 저장 완료
#  [2025-05-12] 저장 완료
#  [2025-05-13] 저장 완료
#  [2025-05-14] 저장 완료
#  [2025-05-15] 저장 완료
#  [2025-05-16] 저장 완료
#  [2025-05-17] 저장 완료
#  [2025-05-18] 저장 완료
#  [2025-05-19] 저장 완료
#  [2025-05-20] 저장 완료
#  [2025-05-21] 저장 완료
#  [2025-05-22] 저장 완료
#  [2025-05-23] 저장 완료
#  [2025-05-24] 저장 완료
#  [2025-05-25] 저장 완료
#  [2025-05-26] 저장 완료
#  [2025-05-27] 저장 완료
#  [2025-05-28] 저장 완료
#  [2025-05-29] 저장 완료
#  [2025-05-30] 저장 완료
#  [2025-05-31] 저장 완료
#  [2025-06-01] 저장 완료
#  [2025-06-02] 저장 완료
#  [2025-06-03] 저장 완료
#  [2025-06-04] 저장 완료
#  [2025-06-05] 저장 완료
#  [2025-06-06] 저장 완료
#  [2025-06-07] 저장 완료
#  [2025-06-08] 저장 완료
#  [2025-06-09] 저장 완료
#  [2025-06-10] 저장 완료
#  [2025-06-11] 저장 완료
#  [2025-06-12] 저장 완료
#  [2025-06-13] 저장 완료
#  [2025-06-14] 저장 완료
#  [2025-06-15] 저장 완료
#  [2025-06-16] 저장 완료
#  [2025-06-17] 저장 완료
#  [2025-06-18] 저장 완료
#  [2025-06-19] 저장 완료
#  [2025-06-20] 저장 완료
#  [2025-06-21] 저장 완료
#  [2025-06-22] 저장 완료
#  [2025-06-23] 저장 완료
#  [2025-06-24] 저장 완료
#  [2025-06-25] 저장 완료
#  [2025-06-26] 저장 완료
#  [2025-06-27] 저장 완료
#  [2025-06-28] 저장 완료
#  [2025-06-29] 저장 완료
#  [2025-06-30] 저장 완료
#  [2025-07-01] 저장 완료
#  [2025-07-02] 저장 완료
#  [2025-07-03] 저장 완료
#  [2025-07-04] 저장 완료
#  [2025-07-05] 저장 완료
#  [2025-07-06] 저장 완료
#  [2025-07-07] 저장 완료
#  [2025-07-08] 저장 완료
#  [2025-07-09] 저장 완료
#  [2025-07-10] 저장 완료
#  [2025-07-11] 저장 완료
#  [2025-07-12] 저장 완료
#  [2025-07-13] 저장 완료
#  자동 수집 대기 중...

# %% [markdown]
# # 결측치 확인

# %%
import pandas as pd

df = pd.read_csv("asos_seoul_daily.csv")  # 저장된 파일명에 맞게 수정

# 결측치 개수 확인
missing_summary = df.isnull().sum()
print(" 결측치 현황:\n", missing_summary)
# Out:
#  결측치 현황:
#  tm             0
# avgTa          0
# minTa          1
# maxTa          1
# sumRn       5625
# avgWs          8
# avgRhm         0
# avgTs          1
# ddMefs      8918
# sumGsr        32
# maxInsWs       6
# sumSmlEv      28
# avgTd          0
# avgPs          1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9249 entries, 0 to 9248
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tm        9249 non-null   object
#  1   avgTa     9249 non-null   float64
#  2   minTa     9248 non-null   float64
#  3   maxTa     9248 non-null   float64
#  4   sumRn     3624 non-null   float64
#  5   avgWs     9241 non-null   float64
#  6   avgRhm    9249 non-null   float64
#  7   avgTs     9248 non-null   float64
#  8   ddMefs    331 non-null    float64
#  9   sumGsr    9217 non-null   float64
#  10  maxInsWs  9243 non-null   float64
#  11  sumSmlEv  9221 non-null   float64
#  12  avgTd     9249 non-null   float64
#  13  avgPs     9248 non-null   float64
# dtypes: float64(13), object(1)
# memory usage: 1011.7+ KB

# %% [markdown]
# # 결측치 처리
# ```
# 결측치 처리 기준
# 컬럼명	설명 (한국어)	결측치 처리 방법
# tm	날짜	 그대로 둠
# avgTa	평균기온(℃)	없음
# minTa, maxTa	최저/최고기온	 중간값 대체
# sumRn	강수량합(mm)	 0으로 대체 (비 없었을 확률 높음)
# avgWs	평균 풍속(m/s)	 중간값 대체
# avgRhm	평균 상대습도(%)	없음
# avgTs	평균 지면온도(℃)	 중간값 대체
# ddMefs	초상일수(눈 등)	 드롭 or 0 처리
# sumGsr	일조시간 합계(hr)	 중간값 대체
# maxInsWs	최대 순간풍속(m/s)	 중간값 대체
# sumSmlEv	소형 증발량(mm)	 중간값 대체
# avgTd	평균 이슬점온도(℃)	없음
# avgPs	평균 해면기압(hPa)	 중간값 대체
# ```

# %%
import pandas as pd

# 데이터 불러오기
df = pd.read_csv("asos_seoul_daily.csv")

# 날짜 처리
df['tm'] = pd.to_datetime(df['tm'])
df['month'] = df['tm'].dt.month
df['dayofweek'] = df['tm'].dt.dayofweek
df['year'] = df['tm'].dt.year

# 결측치 처리
df['sumRn'] = df['sumRn'].fillna(0)
median_cols = ['minTa', 'maxTa', 'avgWs', 'avgTs', 'sumGsr', 'maxInsWs', 'sumSmlEv', 'avgPs']
for col in median_cols:
    df[col] = df[col].fillna(df[col].median())

# 눈 관련 결측치는 드롭 또는 0
df['ddMefs'] = df['ddMefs'].fillna(0)

# 확인
print(" 전처리 완료. 결측치 재확인:\n", df.isnull().sum())
# Out:
#  전처리 완료. 결측치 재확인:
#  tm           0
# avgTa        0
# minTa        0
# maxTa        0
# sumRn        0
# avgWs        0
# avgRhm       0
# avgTs        0
# ddMefs       0
# sumGsr       0
# maxInsWs     0
# sumSmlEv     0
# avgTd        0
# avgPs        0
# month        0
# dayofweek    0
# year         0
# dtype: int64

# %% [markdown]
# # 실체 침수사례 포함 머신러닝용 데이터 만들기

# %%
import pandas as pd
from datetime import datetime, timedelta

# 1. 데이터 불러오기
df = pd.read_csv("asos_seoul_daily.csv")

# 2. 날짜 컬럼 처리
df['tm'] = pd.to_datetime(df['tm'])

# 3. 침수 사례 날짜 목록 정의
flood_periods = [
    ("2000-08-23", "2000-09-01"),
    ("2002-08-30", "2002-09-01"),
    ("2005-08-02", "2005-08-11"),
    ("2006-07-09", "2006-07-29"),
    ("2007-09-13", "2007-09-13"),
    ("2011-07-26", "2011-07-29"),
    ("2013-07-11", "2013-07-15"),
    ("2013-07-18", "2013-07-18"),
    ("2018-08-23", "2018-08-24"),
    ("2018-08-26", "2018-09-01"),
    ("2019-09-28", "2019-10-03"),
    ("2020-07-28", "2020-08-11"),
    ("2020-08-28", "2020-09-03"),
    ("2020-09-01", "2020-09-07"),
    ("2022-08-08", "2022-08-17"),
    ("2022-08-28", "2022-09-06")
]

# 4. 침수 날짜 생성
flood_dates = set()
for start_str, end_str in flood_periods:
    start = datetime.strptime(start_str, "%Y-%m-%d")
    end = datetime.strptime(end_str, "%Y-%m-%d")
    while start <= end:
        flood_dates.add(start.date())
        start += timedelta(days=1)

# 5. 침수 위험 라벨 초기화
df['flood_risk'] = 0

# 6. 침수 사례 날짜에 flood_risk = 1 설정
df.loc[df['tm'].dt.date.isin(flood_dates), 'flood_risk'] = 1

# 7. 강수량 30mm 이상인 날짜도 flood_risk = 1로 설정
df.loc[df['sumRn'] >= 30, 'flood_risk'] = 1

# 8. 저장
df.to_csv("asos_seoul_daily_with_flood_risk.csv", index=False)

# 9. 통계 확인
print("총 데이터 수:", len(df))
print("flood_risk=1 개수:", (df['flood_risk'] == 1).sum())
print("flood_risk=0 개수:", (df['flood_risk'] == 0).sum())
# Out:
# 총 데이터 수: 9249
# flood_risk=1 개수: 423
# flood_risk=0 개수: 8826

# %% [markdown]
# # RandomForest (SMOTE 적용)
# - 미적용시 성능 비교결과 recall 수치가 의미 없음

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sns

# 1. 데이터 불러오기
df = pd.read_csv("asos_seoul_daily_with_flood_risk.csv")  # 파일명은 맞게 조정

# 2. 결측치 처리 (30mm 이상 강수량이 있는 경우 포함시키기 위한 전처리)
df['sumRn'] = df['sumRn'].fillna(0)
numeric_cols = ['avgTa', 'minTa', 'maxTa', 'avgWs', 'avgRhm', 'avgTs',
                'ddMefs', 'sumGsr', 'maxInsWs', 'sumSmlEv', 'avgTd', 'avgPs']
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# 3. flood_risk + 강수량 기반 타겟 재정의
df['flood_risk'] = np.where((df['flood_risk'] == 1) | (df['sumRn'] >= 30), 1, 0)

# 4. 입력/출력 설정
features = ['avgTa', 'minTa', 'maxTa', 'sumRn', 'avgWs', 'avgRhm', 'avgTs',
            'ddMefs', 'sumGsr', 'maxInsWs', 'sumSmlEv', 'avgTd', 'avgPs']
X = df[features]
y = df['flood_risk']

# 5. 학습/테스트 분할
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# 6. SMOTE 적용
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# 7. RandomForest 학습
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train_resampled, y_train_resampled)

# 8. 예측 및 평가
y_pred = model.predict(X_test)
y_proba = model.predict_proba(X_test)[:, 1]

print(" Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\n Classification Report:\n", classification_report(y_test, y_pred, digits=4))
print("\n ROC AUC Score:", roc_auc_score(y_test, y_proba))

# 9. 시각화
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix (RandomForest + SMOTE)")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
#  Confusion Matrix:
#  [[1747   18]
#  [  17   68]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.9904    0.9898    0.9901      1765
#            1     0.7907    0.8000    0.7953        85
#
#     accuracy                         0.9811      1850
#    macro avg     0.8905    0.8949    0.8927      1850
# weighted avg     0.9812    0.9811    0.9811      1850
#
#
#  ROC AUC Score: 0.9842959506748875

# %% [markdown]
# # 모델 저장하기 및 불러오기

# %%
import joblib
import os

# 모델 저장
os.makedirs("models", exist_ok=True)
joblib.dump(model, "models/randomforest_smote_model.pkl")
print("모델 저장 완료: models/randomforest_smote_model.pkl")
# Out:
# 모델 저장 완료: models/randomforest_smote_model.pkl

# %%
# 불러오기
model = joblib.load("models/randomforest_smote_model.pkl")

# %% [markdown]
# # Confusion Matrix 시각화 저장

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("RandomForest + SMOTE Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.savefig("confusion_matrix_rf_smote.png")
plt.show()

# %% [markdown]
# # ROC Curve 시각화 저장

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, thresholds = roc_curve(y_test, y_proba)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
plt.plot([0, 1], [0, 1], 'k--')
plt.title("RandomForest + SMOTE ROC Curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.tight_layout()
plt.savefig("roc_curve_rf_smote.png")
plt.show()
