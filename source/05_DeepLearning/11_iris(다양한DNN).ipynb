# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:98% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:20pt;}
div.text_cell_render.rendered_html{font-size:18pt;}
div.text_cell_render.rendered_html{font-size:15pt;}
div.output {font-size:18pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:18pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:18pt;padding:5px;}
table.dataframe{font-size:18px;}
</style>
"""))
# Out:
# <style>
# div.container{width:98% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:20pt;}
# div.text_cell_render.rendered_html{font-size:18pt;}
# div.text_cell_render.rendered_html{font-size:15pt;}
# div.output {font-size:18pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:18pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:18pt;padding:5px;}
# table.dataframe{font-size:18px;}
# </style>

# %%
# import
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split # 데이터 분할(층화추출로)
from tensorflow.keras.models import Sequential, load_model, save_model
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt # 학습과정 시각화

# %%
# 데이터 생성 및 전처리(라벨인코딩만 하고, 원핫인코딩x)

# %%
from sklearn import datasets
iris = datasets.load_iris()
# iris.keys()
iris_X = iris.data
iris_y = iris.target
iris_X.shape, iris_y.shape
train_X, test_X, train_y, test_y = train_test_split(iris_X, iris_y,
                                                   test_size=0.1,
                                                   stratify=iris_y,
                                                   random_state=4)
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((135, 4), (135,), (15, 4), (15,))

# %% [markdown]
# # 1. 기본적인 DNN(원핫인코딩X)

# %%
# model = Sequential()
# model.add(Input(4,))
# model.add(Dense(units=50, activation='relu'))
# model.add(Dense(units=30, activation='relu'))
# model.add(Dense(units=3, activation='softmax'))
model = Sequential([
    Input(4,),
    Dense(units=50, activation='relu'),
    Dense(units=30, activation='relu'),
    Dense(units=3, activation='softmax')
])
model.summary() # 250-1530+93 = 1873개 파라미터
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                250
#
#  dense_1 (Dense)             (None, 30)                1530
#
#  dense_2 (Dense)             (None, 3)                 93
#
# =================================================================
# Total params: 1,873
# Trainable params: 1,873
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 학습설정
model.compile(loss='sparse_categorical_crossentropy', # 라벨인코딩만 되어 있는 경우
             optimizer='adam',
             metrics=['accuracy'])
# 학습
earlyStropping = EarlyStopping(patience=50)
hist = model.fit(train_X, train_y, epochs=1000,
                validation_split=0.2,
                callbacks=[earlyStropping])
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 1s 62ms/step - loss: 0.9906 - accuracy: 0.5833 - val_loss: 0.9750 - val_accuracy: 0.5556
# Epoch 2/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.9466 - accuracy: 0.5741 - val_loss: 0.9852 - val_accuracy: 0.5926
# Epoch 3/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.9051 - accuracy: 0.6296 - val_loss: 0.9107 - val_accuracy: 0.7037
# Epoch 4/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8574 - accuracy: 0.6574 - val_loss: 0.8407 - val_accuracy: 0.7037
# Epoch 5/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.8253 - accuracy: 0.6944 - val_loss: 0.7938 - val_accuracy: 0.7407
# Epoch 6/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7983 - accuracy: 0.7870 - val_loss: 0.7545 - val_accuracy: 0.8519
# Epoch 7/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7668 - accuracy: 0.7685 - val_loss: 0.7255 - val_accuracy: 0.7037
# Epoch 8/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7339 - accuracy: 0.7222 - val_loss: 0.6941 - val_accuracy: 0.7037
# Epoch 9/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7077 - accuracy: 0.6944 - val_loss: 0.6776 - val_accuracy: 0.7037
# Epoch 10/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6827 - accuracy: 0.6667 - val_loss: 0.6454 - val_accuracy: 0.7037
# Epoch 11/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6560 - accuracy: 0.6852 - val_loss: 0.5995 - val_accuracy: 0.7407
# Epoch 12/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6315 - accuracy: 0.7778 - val_loss: 0.5709 - val_accuracy: 0.8519
# Epoch 13/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6076 - accuracy: 0.8241 - val_loss: 0.5576 - val_accuracy: 0.7407
# Epoch 14/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5860 - accuracy: 0.7870 - val_loss: 0.5337 - val_accuracy: 0.7407
# Epoch 15/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5657 - accuracy: 0.8333 - val_loss: 0.5001 - val_accuracy: 0.8889
# Epoch 16/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5457 - accuracy: 0.8981 - val_loss: 0.4784 - val_accuracy: 0.8889
# Epoch 17/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5278 - accuracy: 0.8426 - val_loss: 0.4683 - val_accuracy: 0.7407
# Epoch 18/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5110 - accuracy: 0.7963 - val_loss: 0.4568 - val_accuracy: 0.7407
# Epoch 19/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4905 - accuracy: 0.8241 - val_loss: 0.4293 - val_accuracy: 0.8889
# Epoch 20/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4719 - accuracy: 0.9167 - val_loss: 0.4059 - val_accuracy: 0.9630
# Epoch 21/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4600 - accuracy: 0.9630 - val_loss: 0.3910 - val_accuracy: 0.9630
# Epoch 22/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4463 - accuracy: 0.9630 - val_loss: 0.3834 - val_accuracy: 0.9630
# Epoch 23/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4330 - accuracy: 0.9537 - val_loss: 0.3764 - val_accuracy: 0.9259
# Epoch 24/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4180 - accuracy: 0.9537 - val_loss: 0.3556 - val_accuracy: 0.9630
# Epoch 25/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4077 - accuracy: 0.9259 - val_loss: 0.3517 - val_accuracy: 0.9259
# Epoch 26/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3857 - accuracy: 0.9352 - val_loss: 0.3306 - val_accuracy: 0.9630
# Epoch 27/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3731 - accuracy: 0.9537 - val_loss: 0.3173 - val_accuracy: 0.9630
# Epoch 28/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3619 - accuracy: 0.9630 - val_loss: 0.3081 - val_accuracy: 0.9630
# Epoch 29/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3504 - accuracy: 0.9537 - val_loss: 0.3008 - val_accuracy: 0.9630
# Epoch 30/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3406 - accuracy: 0.9444 - val_loss: 0.2979 - val_accuracy: 0.9259
# Epoch 31/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3280 - accuracy: 0.9630 - val_loss: 0.2812 - val_accuracy: 0.9630
# Epoch 32/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3193 - accuracy: 0.9722 - val_loss: 0.2696 - val_accuracy: 0.9630
# Epoch 33/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3118 - accuracy: 0.9815 - val_loss: 0.2635 - val_accuracy: 0.9630
# Epoch 34/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3022 - accuracy: 0.9722 - val_loss: 0.2610 - val_accuracy: 0.9630
# Epoch 35/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2910 - accuracy: 0.9722 - val_loss: 0.2520 - val_accuracy: 0.9630
# Epoch 36/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2853 - accuracy: 0.9630 - val_loss: 0.2508 - val_accuracy: 0.9630
# Epoch 37/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2753 - accuracy: 0.9630 - val_loss: 0.2345 - val_accuracy: 0.9630
# Epoch 38/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2679 - accuracy: 0.9722 - val_loss: 0.2294 - val_accuracy: 0.9630
# Epoch 39/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2593 - accuracy: 0.9722 - val_loss: 0.2237 - val_accuracy: 0.9630
# Epoch 40/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2513 - accuracy: 0.9722 - val_loss: 0.2232 - val_accuracy: 0.9630
# Epoch 41/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2450 - accuracy: 0.9722 - val_loss: 0.2224 - val_accuracy: 0.9630
# Epoch 42/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2385 - accuracy: 0.9722 - val_loss: 0.2162 - val_accuracy: 0.9630
# Epoch 43/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2312 - accuracy: 0.9722 - val_loss: 0.2067 - val_accuracy: 0.9630
# Epoch 44/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2248 - accuracy: 0.9722 - val_loss: 0.2002 - val_accuracy: 0.9630
# Epoch 45/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2194 - accuracy: 0.9722 - val_loss: 0.1985 - val_accuracy: 0.9630
# Epoch 46/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2121 - accuracy: 0.9722 - val_loss: 0.2007 - val_accuracy: 0.9630
# Epoch 47/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2092 - accuracy: 0.9722 - val_loss: 0.1918 - val_accuracy: 0.9630
# Epoch 48/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2044 - accuracy: 0.9815 - val_loss: 0.1773 - val_accuracy: 0.9630
# Epoch 49/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2007 - accuracy: 0.9815 - val_loss: 0.1752 - val_accuracy: 0.9630
# Epoch 50/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1923 - accuracy: 0.9815 - val_loss: 0.1759 - val_accuracy: 0.9630
# Epoch 51/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1868 - accuracy: 0.9815 - val_loss: 0.1767 - val_accuracy: 0.9630
# Epoch 52/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1844 - accuracy: 0.9722 - val_loss: 0.1763 - val_accuracy: 0.9630
# Epoch 53/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1793 - accuracy: 0.9722 - val_loss: 0.1663 - val_accuracy: 0.9630
# Epoch 54/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1741 - accuracy: 0.9815 - val_loss: 0.1614 - val_accuracy: 0.9630
# Epoch 55/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1714 - accuracy: 0.9815 - val_loss: 0.1575 - val_accuracy: 0.9630
# Epoch 56/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1677 - accuracy: 0.9815 - val_loss: 0.1555 - val_accuracy: 0.9630
# Epoch 57/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1623 - accuracy: 0.9815 - val_loss: 0.1554 - val_accuracy: 0.9630
# Epoch 58/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1614 - accuracy: 0.9722 - val_loss: 0.1524 - val_accuracy: 0.9630
# Epoch 59/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1616 - accuracy: 0.9815 - val_loss: 0.1435 - val_accuracy: 0.9259
# Epoch 60/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1537 - accuracy: 0.9907 - val_loss: 0.1495 - val_accuracy: 0.9630
# Epoch 61/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1520 - accuracy: 0.9722 - val_loss: 0.1619 - val_accuracy: 0.9630
# Epoch 62/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1533 - accuracy: 0.9722 - val_loss: 0.1447 - val_accuracy: 0.9630
# Epoch 63/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1467 - accuracy: 0.9815 - val_loss: 0.1352 - val_accuracy: 0.9259
# Epoch 64/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1492 - accuracy: 0.9907 - val_loss: 0.1343 - val_accuracy: 0.9630
# Epoch 65/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1391 - accuracy: 0.9815 - val_loss: 0.1441 - val_accuracy: 0.9630
# Epoch 66/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1390 - accuracy: 0.9722 - val_loss: 0.1477 - val_accuracy: 0.9630
# Epoch 67/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1382 - accuracy: 0.9722 - val_loss: 0.1354 - val_accuracy: 0.9630
# Epoch 68/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1319 - accuracy: 0.9815 - val_loss: 0.1281 - val_accuracy: 0.9630
# Epoch 69/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1321 - accuracy: 0.9815 - val_loss: 0.1282 - val_accuracy: 0.9630
# Epoch 70/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1287 - accuracy: 0.9815 - val_loss: 0.1249 - val_accuracy: 0.9630
# Epoch 71/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1271 - accuracy: 0.9815 - val_loss: 0.1270 - val_accuracy: 0.9630
# Epoch 72/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1243 - accuracy: 0.9815 - val_loss: 0.1238 - val_accuracy: 0.9630
# Epoch 73/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1228 - accuracy: 0.9815 - val_loss: 0.1244 - val_accuracy: 0.9630
# Epoch 74/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1201 - accuracy: 0.9815 - val_loss: 0.1211 - val_accuracy: 0.9630
# Epoch 75/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1188 - accuracy: 0.9815 - val_loss: 0.1185 - val_accuracy: 0.9630
# Epoch 76/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1181 - accuracy: 0.9907 - val_loss: 0.1171 - val_accuracy: 0.9630
# Epoch 77/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1171 - accuracy: 0.9815 - val_loss: 0.1184 - val_accuracy: 0.9630
# Epoch 78/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1144 - accuracy: 0.9815 - val_loss: 0.1183 - val_accuracy: 0.9630
# Epoch 79/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1147 - accuracy: 0.9815 - val_loss: 0.1134 - val_accuracy: 0.9259
# Epoch 80/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1125 - accuracy: 0.9907 - val_loss: 0.1135 - val_accuracy: 0.9630
# Epoch 81/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1106 - accuracy: 0.9815 - val_loss: 0.1192 - val_accuracy: 0.9630
# Epoch 82/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1093 - accuracy: 0.9815 - val_loss: 0.1151 - val_accuracy: 0.9630
# Epoch 83/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1065 - accuracy: 0.9815 - val_loss: 0.1107 - val_accuracy: 0.9630
# Epoch 84/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1101 - accuracy: 0.9907 - val_loss: 0.1087 - val_accuracy: 0.9259
# Epoch 85/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1076 - accuracy: 0.9815 - val_loss: 0.1117 - val_accuracy: 0.9630
# Epoch 86/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1027 - accuracy: 0.9815 - val_loss: 0.1153 - val_accuracy: 0.9630
# Epoch 87/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1041 - accuracy: 0.9815 - val_loss: 0.1139 - val_accuracy: 0.9630
# Epoch 88/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1009 - accuracy: 0.9815 - val_loss: 0.1066 - val_accuracy: 0.9630
# Epoch 89/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1035 - accuracy: 0.9815 - val_loss: 0.1050 - val_accuracy: 0.9259
# Epoch 90/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1033 - accuracy: 0.9815 - val_loss: 0.1131 - val_accuracy: 0.9630
# Epoch 91/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0994 - accuracy: 0.9815 - val_loss: 0.1080 - val_accuracy: 0.9630
# Epoch 92/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0996 - accuracy: 0.9815 - val_loss: 0.1046 - val_accuracy: 0.9630
# Epoch 93/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0968 - accuracy: 0.9815 - val_loss: 0.1084 - val_accuracy: 0.9630
# Epoch 94/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0957 - accuracy: 0.9815 - val_loss: 0.1062 - val_accuracy: 0.9630
# Epoch 95/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0954 - accuracy: 0.9815 - val_loss: 0.1025 - val_accuracy: 0.9630
# Epoch 96/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0948 - accuracy: 0.9815 - val_loss: 0.1033 - val_accuracy: 0.9630
# Epoch 97/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0940 - accuracy: 0.9907 - val_loss: 0.1001 - val_accuracy: 0.9259
# Epoch 98/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0932 - accuracy: 0.9907 - val_loss: 0.1011 - val_accuracy: 0.9630
# Epoch 99/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0916 - accuracy: 0.9907 - val_loss: 0.1047 - val_accuracy: 0.9630
# Epoch 100/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0919 - accuracy: 0.9815 - val_loss: 0.1018 - val_accuracy: 0.9630
# Epoch 101/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0933 - accuracy: 0.9815 - val_loss: 0.1048 - val_accuracy: 0.9630
# Epoch 102/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0948 - accuracy: 0.9815 - val_loss: 0.0979 - val_accuracy: 0.9259
# Epoch 103/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0884 - accuracy: 0.9907 - val_loss: 0.0999 - val_accuracy: 0.9630
# Epoch 104/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0898 - accuracy: 0.9815 - val_loss: 0.1057 - val_accuracy: 0.9630
# Epoch 105/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0901 - accuracy: 0.9815 - val_loss: 0.0980 - val_accuracy: 0.9630
# Epoch 106/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0860 - accuracy: 0.9815 - val_loss: 0.0996 - val_accuracy: 0.9630
# Epoch 107/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0868 - accuracy: 0.9815 - val_loss: 0.0982 - val_accuracy: 0.9630
# Epoch 108/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0859 - accuracy: 0.9815 - val_loss: 0.1042 - val_accuracy: 0.9630
# Epoch 109/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0864 - accuracy: 0.9815 - val_loss: 0.0981 - val_accuracy: 0.9630
# Epoch 110/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0818 - accuracy: 0.9907 - val_loss: 0.0943 - val_accuracy: 0.9259
# Epoch 111/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0854 - accuracy: 0.9815 - val_loss: 0.0940 - val_accuracy: 0.9259
# Epoch 112/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0861 - accuracy: 0.9815 - val_loss: 0.0956 - val_accuracy: 0.9630
# Epoch 113/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0819 - accuracy: 0.9907 - val_loss: 0.0940 - val_accuracy: 0.9259
# Epoch 114/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0812 - accuracy: 0.9907 - val_loss: 0.0953 - val_accuracy: 0.9630
# Epoch 115/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0827 - accuracy: 0.9815 - val_loss: 0.0942 - val_accuracy: 0.9630
# Epoch 116/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0820 - accuracy: 0.9815 - val_loss: 0.0931 - val_accuracy: 0.9259
# Epoch 117/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0851 - accuracy: 0.9815 - val_loss: 0.0921 - val_accuracy: 0.9259
# Epoch 118/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0785 - accuracy: 0.9907 - val_loss: 0.0957 - val_accuracy: 0.9630
# Epoch 119/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0792 - accuracy: 0.9815 - val_loss: 0.0979 - val_accuracy: 0.9630
# Epoch 120/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0796 - accuracy: 0.9815 - val_loss: 0.0941 - val_accuracy: 0.9630
# Epoch 121/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0781 - accuracy: 0.9907 - val_loss: 0.0914 - val_accuracy: 0.9259
# Epoch 122/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0776 - accuracy: 0.9907 - val_loss: 0.0910 - val_accuracy: 0.9259
# Epoch 123/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0799 - accuracy: 0.9815 - val_loss: 0.0935 - val_accuracy: 0.9630
# Epoch 124/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0762 - accuracy: 0.9907 - val_loss: 0.0901 - val_accuracy: 0.9259
# Epoch 125/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0771 - accuracy: 0.9815 - val_loss: 0.0899 - val_accuracy: 0.9259
# Epoch 126/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0796 - accuracy: 0.9815 - val_loss: 0.0894 - val_accuracy: 0.9259
# Epoch 127/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0764 - accuracy: 0.9907 - val_loss: 0.0931 - val_accuracy: 0.9630
# Epoch 128/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0798 - accuracy: 0.9815 - val_loss: 0.0936 - val_accuracy: 0.9630
# Epoch 129/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0767 - accuracy: 0.9815 - val_loss: 0.0895 - val_accuracy: 0.9259
# Epoch 130/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0781 - accuracy: 0.9815 - val_loss: 0.0900 - val_accuracy: 0.9630
# Epoch 131/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0736 - accuracy: 0.9907 - val_loss: 0.0947 - val_accuracy: 0.9630
# Epoch 132/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0751 - accuracy: 0.9815 - val_loss: 0.0956 - val_accuracy: 0.9630
# Epoch 133/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0756 - accuracy: 0.9815 - val_loss: 0.0909 - val_accuracy: 0.9630
# Epoch 134/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0726 - accuracy: 0.9907 - val_loss: 0.0886 - val_accuracy: 0.9259
# Epoch 135/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0724 - accuracy: 0.9907 - val_loss: 0.0886 - val_accuracy: 0.9259
# Epoch 136/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0727 - accuracy: 0.9907 - val_loss: 0.0912 - val_accuracy: 0.9630
# Epoch 137/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0724 - accuracy: 0.9907 - val_loss: 0.0890 - val_accuracy: 0.9630
# Epoch 138/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0713 - accuracy: 0.9907 - val_loss: 0.0889 - val_accuracy: 0.9630
# Epoch 139/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0716 - accuracy: 0.9907 - val_loss: 0.0898 - val_accuracy: 0.9630
# Epoch 140/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0714 - accuracy: 0.9907 - val_loss: 0.0886 - val_accuracy: 0.9630
# Epoch 141/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0699 - accuracy: 0.9907 - val_loss: 0.0898 - val_accuracy: 0.9630
# Epoch 142/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0709 - accuracy: 0.9907 - val_loss: 0.0892 - val_accuracy: 0.9630
# Epoch 143/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0710 - accuracy: 0.9907 - val_loss: 0.0894 - val_accuracy: 0.9630
# Epoch 144/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0701 - accuracy: 0.9907 - val_loss: 0.0875 - val_accuracy: 0.9630
# Epoch 145/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0694 - accuracy: 0.9907 - val_loss: 0.0877 - val_accuracy: 0.9630
# Epoch 146/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0698 - accuracy: 0.9907 - val_loss: 0.0869 - val_accuracy: 0.9259
# Epoch 147/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0700 - accuracy: 0.9815 - val_loss: 0.0870 - val_accuracy: 0.9259
# Epoch 148/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0747 - accuracy: 0.9815 - val_loss: 0.0857 - val_accuracy: 0.9259
# Epoch 149/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0709 - accuracy: 0.9815 - val_loss: 0.0857 - val_accuracy: 0.9259
# Epoch 150/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0727 - accuracy: 0.9815 - val_loss: 0.0928 - val_accuracy: 0.9630
# Epoch 151/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0699 - accuracy: 0.9815 - val_loss: 0.0860 - val_accuracy: 0.9259
# Epoch 152/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0677 - accuracy: 0.9907 - val_loss: 0.0858 - val_accuracy: 0.9259
# Epoch 153/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0689 - accuracy: 0.9907 - val_loss: 0.0850 - val_accuracy: 0.9259
# Epoch 154/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0668 - accuracy: 0.9907 - val_loss: 0.0866 - val_accuracy: 0.9630
# Epoch 155/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0670 - accuracy: 0.9907 - val_loss: 0.0882 - val_accuracy: 0.9630
# Epoch 156/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0671 - accuracy: 0.9907 - val_loss: 0.0864 - val_accuracy: 0.9630
# Epoch 157/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0660 - accuracy: 0.9907 - val_loss: 0.0865 - val_accuracy: 0.9630
# Epoch 158/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0658 - accuracy: 0.9907 - val_loss: 0.0875 - val_accuracy: 0.9630
# Epoch 159/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0663 - accuracy: 0.9907 - val_loss: 0.0868 - val_accuracy: 0.9630
# Epoch 160/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0657 - accuracy: 0.9907 - val_loss: 0.0849 - val_accuracy: 0.9259
# Epoch 161/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0641 - accuracy: 0.9907 - val_loss: 0.0852 - val_accuracy: 0.9259
# Epoch 162/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0682 - accuracy: 0.9815 - val_loss: 0.0844 - val_accuracy: 0.9259
# Epoch 163/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0650 - accuracy: 0.9907 - val_loss: 0.0866 - val_accuracy: 0.9630
# Epoch 164/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0650 - accuracy: 0.9907 - val_loss: 0.0884 - val_accuracy: 0.9630
# Epoch 165/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0661 - accuracy: 0.9907 - val_loss: 0.0872 - val_accuracy: 0.9630
# Epoch 166/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0643 - accuracy: 0.9907 - val_loss: 0.0856 - val_accuracy: 0.9259
# Epoch 167/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0656 - accuracy: 0.9907 - val_loss: 0.0847 - val_accuracy: 0.9259
# Epoch 168/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0651 - accuracy: 0.9907 - val_loss: 0.0867 - val_accuracy: 0.9630
# Epoch 169/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0637 - accuracy: 0.9907 - val_loss: 0.0844 - val_accuracy: 0.9259
# Epoch 170/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0699 - accuracy: 0.9815 - val_loss: 0.0850 - val_accuracy: 0.9259
# Epoch 171/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0662 - accuracy: 0.9815 - val_loss: 0.0874 - val_accuracy: 0.9630
# Epoch 172/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0637 - accuracy: 0.9907 - val_loss: 0.0871 - val_accuracy: 0.9630
# Epoch 173/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0636 - accuracy: 0.9907 - val_loss: 0.0857 - val_accuracy: 0.9630
# Epoch 174/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0628 - accuracy: 0.9907 - val_loss: 0.0855 - val_accuracy: 0.9259
# Epoch 175/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0625 - accuracy: 0.9907 - val_loss: 0.0845 - val_accuracy: 0.9259
# Epoch 176/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0638 - accuracy: 0.9907 - val_loss: 0.0871 - val_accuracy: 0.9630
# Epoch 177/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0628 - accuracy: 0.9907 - val_loss: 0.0886 - val_accuracy: 0.9630
# Epoch 178/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0635 - accuracy: 0.9907 - val_loss: 0.0884 - val_accuracy: 0.9630
# Epoch 179/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0639 - accuracy: 0.9907 - val_loss: 0.0871 - val_accuracy: 0.9630
# Epoch 180/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0619 - accuracy: 0.9907 - val_loss: 0.0836 - val_accuracy: 0.9259
# Epoch 181/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0625 - accuracy: 0.9907 - val_loss: 0.0836 - val_accuracy: 0.9259
# Epoch 182/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0621 - accuracy: 0.9907 - val_loss: 0.0871 - val_accuracy: 0.9630
# Epoch 183/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0629 - accuracy: 0.9907 - val_loss: 0.0864 - val_accuracy: 0.9630
# Epoch 184/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0621 - accuracy: 0.9907 - val_loss: 0.0873 - val_accuracy: 0.9630
# Epoch 185/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0623 - accuracy: 0.9907 - val_loss: 0.0854 - val_accuracy: 0.9630
# Epoch 186/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0612 - accuracy: 0.9907 - val_loss: 0.0851 - val_accuracy: 0.9630
# Epoch 187/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0643 - accuracy: 0.9907 - val_loss: 0.0860 - val_accuracy: 0.9630
# Epoch 188/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0647 - accuracy: 0.9815 - val_loss: 0.0833 - val_accuracy: 0.9259
# Epoch 189/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0598 - accuracy: 0.9907 - val_loss: 0.0849 - val_accuracy: 0.9630
# Epoch 190/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0596 - accuracy: 0.9907 - val_loss: 0.0915 - val_accuracy: 0.9630
# Epoch 191/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0639 - accuracy: 0.9907 - val_loss: 0.0860 - val_accuracy: 0.9630
# Epoch 192/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0586 - accuracy: 0.9907 - val_loss: 0.0831 - val_accuracy: 0.9259
# Epoch 193/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0629 - accuracy: 0.9815 - val_loss: 0.0831 - val_accuracy: 0.9259
# Epoch 194/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0648 - accuracy: 0.9815 - val_loss: 0.0843 - val_accuracy: 0.9630
# Epoch 195/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0596 - accuracy: 0.9907 - val_loss: 0.0826 - val_accuracy: 0.9259
# Epoch 196/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0608 - accuracy: 0.9907 - val_loss: 0.0826 - val_accuracy: 0.9259
# Epoch 197/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0618 - accuracy: 0.9907 - val_loss: 0.0827 - val_accuracy: 0.9259
# Epoch 198/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0665 - accuracy: 0.9815 - val_loss: 0.0830 - val_accuracy: 0.9259
# Epoch 199/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0646 - accuracy: 0.9815 - val_loss: 0.0856 - val_accuracy: 0.9630
# Epoch 200/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0604 - accuracy: 0.9907 - val_loss: 0.0827 - val_accuracy: 0.9259
# Epoch 201/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0619 - accuracy: 0.9815 - val_loss: 0.0827 - val_accuracy: 0.9259
# Epoch 202/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0588 - accuracy: 0.9815 - val_loss: 0.0833 - val_accuracy: 0.9259
# Epoch 203/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0625 - accuracy: 0.9907 - val_loss: 0.0893 - val_accuracy: 0.9630
# Epoch 204/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0613 - accuracy: 0.9907 - val_loss: 0.0839 - val_accuracy: 0.9259
# Epoch 205/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0584 - accuracy: 0.9907 - val_loss: 0.0823 - val_accuracy: 0.9259
# Epoch 206/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0596 - accuracy: 0.9815 - val_loss: 0.0822 - val_accuracy: 0.9259
# Epoch 207/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0570 - accuracy: 0.9907 - val_loss: 0.0845 - val_accuracy: 0.9630
# Epoch 208/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0582 - accuracy: 0.9907 - val_loss: 0.0868 - val_accuracy: 0.9630
# Epoch 209/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0619 - accuracy: 0.9907 - val_loss: 0.0842 - val_accuracy: 0.9630
# Epoch 210/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0644 - accuracy: 0.9815 - val_loss: 0.0898 - val_accuracy: 0.9630
# Epoch 211/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0728 - accuracy: 0.9815 - val_loss: 0.0842 - val_accuracy: 0.9259
# Epoch 212/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0543 - accuracy: 0.9907 - val_loss: 0.0892 - val_accuracy: 0.9630
# Epoch 213/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0768 - accuracy: 0.9815 - val_loss: 0.1074 - val_accuracy: 0.9630
# Epoch 214/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0688 - accuracy: 0.9907 - val_loss: 0.0846 - val_accuracy: 0.9630
# Epoch 215/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0579 - accuracy: 0.9907 - val_loss: 0.0890 - val_accuracy: 0.9630
# Epoch 216/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0687 - accuracy: 0.9815 - val_loss: 0.0833 - val_accuracy: 0.9259
# Epoch 217/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0561 - accuracy: 0.9907 - val_loss: 0.0884 - val_accuracy: 0.9630
# Epoch 218/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0678 - accuracy: 0.9815 - val_loss: 0.1003 - val_accuracy: 0.9630
# Epoch 219/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0661 - accuracy: 0.9815 - val_loss: 0.0845 - val_accuracy: 0.9630
# Epoch 220/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0555 - accuracy: 0.9907 - val_loss: 0.0973 - val_accuracy: 0.9630
# Epoch 221/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0833 - accuracy: 0.9537 - val_loss: 0.0845 - val_accuracy: 0.9259
# Epoch 222/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0545 - accuracy: 0.9907 - val_loss: 0.0888 - val_accuracy: 0.9630
# Epoch 223/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0682 - accuracy: 0.9907 - val_loss: 0.0988 - val_accuracy: 0.9630
# Epoch 224/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0613 - accuracy: 0.9815 - val_loss: 0.0823 - val_accuracy: 0.9259
# Epoch 225/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0697 - accuracy: 0.9815 - val_loss: 0.0856 - val_accuracy: 0.9259
# Epoch 226/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0573 - accuracy: 0.9907 - val_loss: 0.0854 - val_accuracy: 0.9630
# Epoch 227/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0572 - accuracy: 0.9907 - val_loss: 0.0878 - val_accuracy: 0.9630
# Epoch 228/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0601 - accuracy: 0.9907 - val_loss: 0.0838 - val_accuracy: 0.9259
# Epoch 229/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0583 - accuracy: 0.9907 - val_loss: 0.0837 - val_accuracy: 0.9259
# Epoch 230/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0544 - accuracy: 0.9907 - val_loss: 0.0839 - val_accuracy: 0.9259
# Epoch 231/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0594 - accuracy: 0.9815 - val_loss: 0.0832 - val_accuracy: 0.9259
# Epoch 232/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0566 - accuracy: 0.9815 - val_loss: 0.0830 - val_accuracy: 0.9259
# Epoch 233/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0548 - accuracy: 0.9907 - val_loss: 0.0852 - val_accuracy: 0.9630
# Epoch 234/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0602 - accuracy: 0.9907 - val_loss: 0.0865 - val_accuracy: 0.9630
# Epoch 235/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0627 - accuracy: 0.9815 - val_loss: 0.0840 - val_accuracy: 0.9259
# Epoch 236/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0601 - accuracy: 0.9815 - val_loss: 0.0832 - val_accuracy: 0.9259
# Epoch 237/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0578 - accuracy: 0.9815 - val_loss: 0.0846 - val_accuracy: 0.9630
# Epoch 238/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0554 - accuracy: 0.9907 - val_loss: 0.0868 - val_accuracy: 0.9630
# Epoch 239/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0577 - accuracy: 0.9907 - val_loss: 0.0860 - val_accuracy: 0.9630
# Epoch 240/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0568 - accuracy: 0.9907 - val_loss: 0.0845 - val_accuracy: 0.9259
# Epoch 241/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0545 - accuracy: 0.9907 - val_loss: 0.0828 - val_accuracy: 0.9259
# Epoch 242/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0559 - accuracy: 0.9815 - val_loss: 0.0835 - val_accuracy: 0.9259
# Epoch 243/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0564 - accuracy: 0.9815 - val_loss: 0.0829 - val_accuracy: 0.9259
# Epoch 244/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0533 - accuracy: 0.9907 - val_loss: 0.0864 - val_accuracy: 0.9630
# Epoch 245/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0562 - accuracy: 0.9907 - val_loss: 0.0907 - val_accuracy: 0.9630
# Epoch 246/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0583 - accuracy: 0.9907 - val_loss: 0.0852 - val_accuracy: 0.9630
# Epoch 247/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0550 - accuracy: 0.9907 - val_loss: 0.0828 - val_accuracy: 0.9259
# Epoch 248/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0555 - accuracy: 0.9815 - val_loss: 0.0828 - val_accuracy: 0.9259
# Epoch 249/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0547 - accuracy: 0.9907 - val_loss: 0.0828 - val_accuracy: 0.9259
# Epoch 250/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0545 - accuracy: 0.9907 - val_loss: 0.0834 - val_accuracy: 0.9259
# Epoch 251/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0543 - accuracy: 0.9907 - val_loss: 0.0828 - val_accuracy: 0.9259
# Epoch 252/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0613 - accuracy: 0.9815 - val_loss: 0.0849 - val_accuracy: 0.9259
# Epoch 253/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0580 - accuracy: 0.9815 - val_loss: 0.0863 - val_accuracy: 0.9630
# Epoch 254/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0575 - accuracy: 0.9907 - val_loss: 0.0908 - val_accuracy: 0.9630
# Epoch 255/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0574 - accuracy: 0.9907 - val_loss: 0.0850 - val_accuracy: 0.9259
# Epoch 256/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0561 - accuracy: 0.9907 - val_loss: 0.0849 - val_accuracy: 0.9259

# %%
# 모델 학습과정 시각화
fig, loss_ax = plt.subplots(figsize=(12,6))
loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='train accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'b', label='val accuracy')
loss_ax.set_xlabel('epochs')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')
loss_ax.legend(loc='center right')
acc_ax.legend()
plt.show()

# %% [markdown]
# # 2. sklearn 이용
# - 원핫인코딩을 하지 않고 라벨인코딩까지만 해야 작동. numpy배열

# %%
from sklearn.neural_network import MLPClassifier

# %%
# 머신러닝 3장 교안 43page
mlp_model = MLPClassifier(hidden_layer_sizes=(50, 30),
                     activation='relu',
                     solver='adam',
                     alpha=0.0001, # 과적합 방지 강도
                     batch_size=40,
                     max_iter=1000, # epoch
                     early_stopping=True, # 조기 종료 활성화(val_loss)
                     n_iter_no_change=50, # patience
                     warm_start=False, # True일 경우 이전학습에 이어서 학습
                     validation_fraction=0.1) # 검증셋 비율

# %%
mlp_model.fit(train_X, train_y)
# Out:
# MLPClassifier(batch_size=40, early_stopping=True, hidden_layer_sizes=(50, 30),
#               max_iter=1000, n_iter_no_change=50)

# %%
# 모델 평가 : accuracy(test_X, test_y), recall, precision(test_y, yhat)
from sklearn.metrics import recall_score, precision_score
accuracy = mlp_model.score(test_X, test_y)
yhat = mlp_model.predict(test_X)
recall = recall_score(test_y, yhat, average='weighted')
precision = precision_score(test_y, yhat, average='weighted')
print('정확도 :', accuracy)
print('재현율 :', recall)
print('정밀도 :', precision)
print('교차표\n', pd.crosstab(test_y, yhat,
                          rownames=['실제'],
                          colnames=['예측']))
# Out:
# 정확도 : 1.0
# 재현율 : 1.0
# 정밀도 : 1.0
# 교차표
#  예측  0  1  2
# 실제
# 0   5  0  0
# 1   0  5  0
# 2   0  0  5

# %% [markdown]
# # 3. 클래스 이용

# %%
class DNNClassifier:
    @staticmethod
    def build(input_dim=4, activation='relu', optimizer='adam'):
        # 모델 구성
#         model = Sequential()
#         model.add(Input(input_dim,))
#         model.add(Dense(50, activation=activation))
#         model.add(Dense(30, activation=activation))
#         model.add(Dense(3, activation='softmax'))
        model = Sequential([
            Input(input_dim,) ,
            Dense(50, activation=activation),
            Dense(30, activation=activation),
            Dense(3, activation='softmax')
        ])
        # 모델 학습 설정
        model.compile(loss='sparse_categorical_crossentropy',
                     optimizer=optimizer,
                     metrics=['accuracy'])
        return model

# %%
# %%time
# 모델
model = DNNClassifier.build(input_dim=4, activation='relu')
model.summary()
# 모델 학습
hist = model.fit(train_X, train_y,
                epochs=500,
                validation_split=0.2,
                verbose=0)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 50)                250
#
#  dense_13 (Dense)            (None, 30)                1530
#
#  dense_14 (Dense)            (None, 3)                 93
#
# =================================================================
# Total params: 1,873
# Trainable params: 1,873
# Non-trainable params: 0
# _________________________________________________________________
# CPU times: total: 17.4 s
# Wall time: 14.9 s

# %%
loss, accuracy = model.evaluate(test_X, test_y)
loss, accuracy
# Out:
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0246 - accuracy: 1.0000
# (0.024607334285974503, 1.0)

# %% [markdown]
# # 4. 함수형 API이용하기
# - 병렬처리 : 속도 높이려고
# - 레지듀얼블록(Residual block) : 모델의 성능을 높이려고(자연어처리,이미지처리)

# %%
# import
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split # 데이터 분할(층화추출로)
from tensorflow.keras import Model # 모델 생성(입력층과 출력층을 이용)
from tensorflow.keras.layers import Dense, Input, add # 레지듀얼블록
from tensorflow.keras. layers import concatenate # 병렬처리시

# %%
from sklearn import datasets
iris = datasets.load_iris()
# iris.keys()
iris_X = iris.data
iris_y = iris.target # 라벨인코딩이 되어 있음
iris_X.shape, iris_y.shape
train_X, test_X, train_y, test_y = train_test_split(iris_X, iris_y,
                                                   test_size=0.1,
                                                   stratify=iris_y,
                                                   random_state=4)
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((135, 4), (135,), (15, 4), (15,))

# %%
# 기존의 model 스타일 4 -> 50 -> 30 -> 3
input_ = Input(shape=(4,))
dense1 = Dense(units=50, activation='relu')(input_)
dense2 = Dense(units=30, activation='relu')(dense1)
dense3 = Dense(units=3, activation='softmax')(dense2)
model = Model(inputs=input_, outputs=dense3)
model. summary()
model.compile(loss='sparse_categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
model.fit(train_X, train_y, epochs=20,
         validation_split=0.2)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 4)]               0
#
#  dense_18 (Dense)            (None, 50)                250
#
#  dense_19 (Dense)            (None, 30)                1530
#
#  dense_20 (Dense)            (None, 3)                 93
#
# =================================================================
# Total params: 1,873
# Trainable params: 1,873
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 4/4 [==============================] - 0s 47ms/step - loss: 1.1869 - accuracy: 0.3611 - val_loss: 1.2630 - val_accuracy: 0.2222
# Epoch 2/20
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0929 - accuracy: 0.3611 - val_loss: 1.1750 - val_accuracy: 0.2222
# Epoch 3/20
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0162 - accuracy: 0.3611 - val_loss: 1.0800 - val_accuracy: 0.2222
# Epoch 4/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.9529 - accuracy: 0.3611 - val_loss: 0.9907 - val_accuracy: 0.2222
# Epoch 5/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.8943 - accuracy: 0.3611 - val_loss: 0.9199 - val_accuracy: 0.5185
# Epoch 6/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.8494 - accuracy: 0.6111 - val_loss: 0.8515 - val_accuracy: 0.7037
# Epoch 7/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.8081 - accuracy: 0.6574 - val_loss: 0.7918 - val_accuracy: 0.7037
# Epoch 8/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7763 - accuracy: 0.6759 - val_loss: 0.7386 - val_accuracy: 0.7037
# Epoch 9/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7473 - accuracy: 0.7130 - val_loss: 0.6972 - val_accuracy: 0.7037
# Epoch 10/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7179 - accuracy: 0.7500 - val_loss: 0.6665 - val_accuracy: 0.7407
# Epoch 11/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6928 - accuracy: 0.6852 - val_loss: 0.6416 - val_accuracy: 0.7037
# Epoch 12/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6669 - accuracy: 0.6574 - val_loss: 0.6187 - val_accuracy: 0.7037
# Epoch 13/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6453 - accuracy: 0.6574 - val_loss: 0.5943 - val_accuracy: 0.7037
# Epoch 14/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6248 - accuracy: 0.6574 - val_loss: 0.5686 - val_accuracy: 0.7037
# Epoch 15/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6040 - accuracy: 0.6759 - val_loss: 0.5451 - val_accuracy: 0.7407
# Epoch 16/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5852 - accuracy: 0.7870 - val_loss: 0.5228 - val_accuracy: 0.7778
# Epoch 17/20
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5698 - accuracy: 0.8611 - val_loss: 0.5024 - val_accuracy: 0.8889
# Epoch 18/20
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5541 - accuracy: 0.8981 - val_loss: 0.4829 - val_accuracy: 0.8889
# Epoch 19/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5381 - accuracy: 0.8704 - val_loss: 0.4696 - val_accuracy: 0.7778
# Epoch 20/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5260 - accuracy: 0.7963 - val_loss: 0.4625 - val_accuracy: 0.7407

# %%
# 병렬처리
# 4 -> 160(50,80,30로 병렬처리) -> 32 -> 3
input_ = Input(shape=(4,))
dense1 = Dense(units=50, activation='relu')(input_)
dense2 = Dense(units=80, activation='relu')(input_)
dense3 = Dense(units=30, activation='relu')(input_)
x = concatenate([dense1, dense2, dense3])
# x = Dense(160, activation+'relu')(input_)의 병렬처리
dense4 = Dense(32, activation='relu')(x)
output = Dense(3, activation='relu')(dense4)
model = Model(inputs=input_, outputs=output)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 4)]          0           []
#
#  dense_22 (Dense)               (None, 50)           250         ['input_9[0][0]']
#
#  dense_23 (Dense)               (None, 80)           400         ['input_9[0][0]']
#
#  dense_24 (Dense)               (None, 30)           150         ['input_9[0][0]']
#
#  concatenate (Concatenate)      (None, 160)          0           ['dense_22[0][0]',
#                                                                   'dense_23[0][0]',
#                                                                   'dense_24[0][0]']
#
#  dense_25 (Dense)               (None, 32)           5152        ['concatenate[0][0]']
#
#  dense_26 (Dense)               (None, 3)            99          ['dense_25[0][0]']
#
# ==================================================================================================
# Total params: 6,051
# Trainable params: 6,051
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# %%time
# 레지듀얼블록(Residual Block):딥러닝에서 딥한 네트워크가 학습이 잘 되지 않을 때
# 4 -> 50 -> 50 ->(레지듀얼)-> 3
input_ = Input(shape=(4,))
dense1 = Dense(50, activation='relu')(input_)
dense2 = Dense(50, activation='relu')(dense1)
dense3 = add([dense1, dense2])
output = Dense(3, activation='softmax')(dense3)
model = Model(inputs=input_, outputs=output)
model.summary()
model.compile(loss='sparse_categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
model.fit(train_X, train_y, epochs=500,
         validation_split=0.2, verbose=0)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_10 (InputLayer)          [(None, 4)]          0           []
#
#  dense_27 (Dense)               (None, 50)           250         ['input_10[0][0]']
#
#  dense_28 (Dense)               (None, 50)           2550        ['dense_27[0][0]']
#
#  add (Add)                      (None, 50)           0           ['dense_27[0][0]',
#                                                                   'dense_28[0][0]']
#
#  dense_29 (Dense)               (None, 3)            153         ['add[0][0]']
#
# ==================================================================================================
# Total params: 2,953
# Trainable params: 2,953
# Non-trainable params: 0
# __________________________________________________________________________________________________
# CPU times: total: 21.2 s
# Wall time: 17 s

# %%
model.evaluate(test_X, test_y)
# Out:
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0413 - accuracy: 1.0000
# [0.041261814534664154, 1.0]
