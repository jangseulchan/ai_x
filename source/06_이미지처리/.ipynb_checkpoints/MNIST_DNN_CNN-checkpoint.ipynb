# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:98% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:20pt;}
div.text_cell_render.rendered_html{font-size:18pt;}
div.text_cell_render.rendered_html{font-size:15pt;}
div.output {font-size:18pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:18pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:18pt;padding:5px;}
table.dataframe{font-size:18px;}
</style>
"""))
# Out:
# <style>
# div.container{width:98% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:20pt;}
# div.text_cell_render.rendered_html{font-size:18pt;}
# div.text_cell_render.rendered_html{font-size:15pt;}
# div.output {font-size:18pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:18pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:18pt;padding:5px;}
# table.dataframe{font-size:18px;}
# </style>

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.datasets import mnist # mnist 훈련셋과 테스트셋
from tensorflow.keras.utils import to_categorical # 원핫인코딩
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout
from matplotlib import pyplot as plt # 학습과정 loss와 acc 시각화

# %%
# 1. 데이터 셋
width = 28; height=28
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
plt_row = 3
plt_col = 10
# plt.figure(figsize=(plt_col, plt_row))
plt.rcParams['figure.figsize'] = [plt_col, plt_row]
plt.rc("font", family="Malgun Gothic") # window에서 한글 시각화
# plt.rc("font", family="NanumBarunGothic") # 코랩에서 한글 시각화
fig, axes = plt.subplots(plt_row, plt_col)
# axes[0, 0].imshow(X_test[0].reshape(width, height))
# axes[0, 0].axis('off')
# title = "실제:{}".format(y_test[0])
# axes[0, 0].set_title(title)
plt. subplots_adjust(hspace=0.4, wspace=0.3)
for i in range(plt_row*plt_col):
    subax = axes[i//plt_col, i%plt_col] # //:몫연산자  %:나머지연산자
    subax.imshow(X_test[i].reshape(width, height))
    subax.axis('off')
    title = "실제:{}".format(y_test[i])
    subax.set_title(title)
# plt.tight_layout()

# %% [markdown]
# # 1. DNN

# %%
# %%time
# 1. 데이터 생성 및 전처리
width=28; height=28
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_val = X_train[50000:]
y_val = y_train[50000:]
X_train = X_train[:50000]
y_train = y_train[:50000]
# 독립변수 (28,28) => 784 1차원 -> 실수형변환 -> 스케일조정
X_train = X_train.reshape(-1, width*height).astype('float32')/255.0
X_val = X_val.reshape(-1, width*height).astype('float32')/255.0
X_test = X_test.reshape(-1, width*height).astype('float32')/255.0
# 타겟변수 원핫인코딩
Y_train = to_categorical(y_train)
Y_val = to_categorical(y_val)
Y_test = to_categorical(y_test)

X_train.shape, Y_train.shape, X_val.shape, Y_val.shape, X_test.shape, Y_test.shape

# 2. 모델 구성
model = Sequential([
    Input(shape=(width*height,)),
    Dense(1024, activation='relu'),
    Dropout(0.3),
    Dense(512, activation='relu'),
    Dropout(0.3),
    Dense(256, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax'),
])
# model.summary()
# 3. 학습설정
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# 4. 학습
model.fit(X_train, Y_train,
         epochs=50,
         validation_data=(X_val, Y_val),
         verbose=1)
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.2708 - accuracy: 0.9162 - val_loss: 0.1097 - val_accuracy: 0.9660
# Epoch 2/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.1364 - accuracy: 0.9594 - val_loss: 0.1189 - val_accuracy: 0.9644
# Epoch 3/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.1122 - accuracy: 0.9670 - val_loss: 0.1013 - val_accuracy: 0.9714
# Epoch 4/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0907 - accuracy: 0.9736 - val_loss: 0.0904 - val_accuracy: 0.9760
# Epoch 5/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0851 - accuracy: 0.9757 - val_loss: 0.0876 - val_accuracy: 0.9773
# Epoch 6/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0742 - accuracy: 0.9779 - val_loss: 0.0869 - val_accuracy: 0.9762
# Epoch 7/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0702 - accuracy: 0.9806 - val_loss: 0.0833 - val_accuracy: 0.9795
# Epoch 8/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0620 - accuracy: 0.9822 - val_loss: 0.0986 - val_accuracy: 0.9758
# Epoch 9/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0601 - accuracy: 0.9825 - val_loss: 0.0925 - val_accuracy: 0.9790
# Epoch 10/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0596 - accuracy: 0.9832 - val_loss: 0.1043 - val_accuracy: 0.9773
# Epoch 11/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0528 - accuracy: 0.9847 - val_loss: 0.0873 - val_accuracy: 0.9808
# Epoch 12/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0528 - accuracy: 0.9854 - val_loss: 0.0947 - val_accuracy: 0.9805
# Epoch 13/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0529 - accuracy: 0.9856 - val_loss: 0.0883 - val_accuracy: 0.9819
# Epoch 14/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0456 - accuracy: 0.9872 - val_loss: 0.0999 - val_accuracy: 0.9798
# Epoch 15/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0480 - accuracy: 0.9870 - val_loss: 0.1041 - val_accuracy: 0.9809
# Epoch 16/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0460 - accuracy: 0.9867 - val_loss: 0.1087 - val_accuracy: 0.9798
# Epoch 17/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0443 - accuracy: 0.9885 - val_loss: 0.1079 - val_accuracy: 0.9813
# Epoch 18/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0466 - accuracy: 0.9879 - val_loss: 0.0820 - val_accuracy: 0.9841
# Epoch 19/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0381 - accuracy: 0.9901 - val_loss: 0.1085 - val_accuracy: 0.9814
# Epoch 20/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0414 - accuracy: 0.9897 - val_loss: 0.1043 - val_accuracy: 0.9807
# Epoch 21/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0403 - accuracy: 0.9900 - val_loss: 0.1305 - val_accuracy: 0.9792
# Epoch 22/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0400 - accuracy: 0.9893 - val_loss: 0.1142 - val_accuracy: 0.9810
# Epoch 23/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0428 - accuracy: 0.9894 - val_loss: 0.0936 - val_accuracy: 0.9831
# Epoch 24/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0339 - accuracy: 0.9914 - val_loss: 0.1270 - val_accuracy: 0.9827
# Epoch 25/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0399 - accuracy: 0.9900 - val_loss: 0.1147 - val_accuracy: 0.9831
# Epoch 26/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0347 - accuracy: 0.9916 - val_loss: 0.1387 - val_accuracy: 0.9808
# Epoch 27/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0364 - accuracy: 0.9904 - val_loss: 0.1110 - val_accuracy: 0.9818
# Epoch 28/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0381 - accuracy: 0.9913 - val_loss: 0.1258 - val_accuracy: 0.9828
# Epoch 29/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0378 - accuracy: 0.9913 - val_loss: 0.1596 - val_accuracy: 0.9800
# Epoch 30/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0387 - accuracy: 0.9909 - val_loss: 0.1169 - val_accuracy: 0.9810
# Epoch 31/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0304 - accuracy: 0.9922 - val_loss: 0.1425 - val_accuracy: 0.9821
# Epoch 32/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0394 - accuracy: 0.9912 - val_loss: 0.1266 - val_accuracy: 0.9834
# Epoch 33/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0373 - accuracy: 0.9913 - val_loss: 0.1277 - val_accuracy: 0.9826
# Epoch 34/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0333 - accuracy: 0.9922 - val_loss: 0.1564 - val_accuracy: 0.9805
# Epoch 35/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0367 - accuracy: 0.9914 - val_loss: 0.1383 - val_accuracy: 0.9812
# Epoch 36/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0309 - accuracy: 0.9928 - val_loss: 0.1276 - val_accuracy: 0.9838
# Epoch 37/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0316 - accuracy: 0.9926 - val_loss: 0.1673 - val_accuracy: 0.9825
# Epoch 38/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0382 - accuracy: 0.9919 - val_loss: 0.1403 - val_accuracy: 0.9813
# Epoch 39/50
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.0316 - accuracy: 0.9928 - val_loss: 0.1300 - val_accuracy: 0.9849
# Epoch 40/50
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.0361 - accuracy: 0.9921 - val_loss: 0.1311 - val_accuracy: 0.9841
# Epoch 41/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0369 - accuracy: 0.9922 - val_loss: 0.1363 - val_accuracy: 0.9858
# Epoch 42/50
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.0338 - accuracy: 0.9927 - val_loss: 0.1397 - val_accuracy: 0.9831
# Epoch 43/50
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.0333 - accuracy: 0.9928 - val_loss: 0.1191 - val_accuracy: 0.9852
# Epoch 44/50
# 1563/1563 [==============================] - 29s 18ms/step - loss: 0.0346 - accuracy: 0.9939 - val_loss: 0.1833 - val_accuracy: 0.9813
# Epoch 45/50
# 1563/1563 [==============================] - 29s 18ms/step - loss: 0.0319 - accuracy: 0.9933 - val_loss: 0.1907 - val_accuracy: 0.9813
# Epoch 46/50
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.0343 - accuracy: 0.9934 - val_loss: 0.1494 - val_accuracy: 0.9845
# Epoch 47/50
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.0358 - accuracy: 0.9931 - val_loss: 0.1404 - val_accuracy: 0.9847
# Epoch 48/50
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.0268 - accuracy: 0.9940 - val_loss: 0.1699 - val_accuracy: 0.9838
# Epoch 49/50
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.0343 - accuracy: 0.9937 - val_loss: 0.1667 - val_accuracy: 0.9833
# Epoch 50/50
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.0354 - accuracy: 0.9932 - val_loss: 0.2104 - val_accuracy: 0.9808
# CPU times: total: 1h 12min 26s
# Wall time: 17min 6s

# %%
model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.1930 - accuracy: 0.9811
# [0.19304078817367554, 0.9811000227928162]

# %%
model.save('mnist_dnn.h5')

# %%
# 혼동행렬
from sklearn.metrics import confusion_matrix
print('실제값 :', y_test)
print('실제값 :', np.argmax(Y_test, axis=1))
yhat = model.predict(X_test).argmax(axis=1)
cmatrix = confusion_matrix(y_test, yhat)
cmatrix
# Out:
# 실제값 : [7 2 1 ... 4 5 6]
# 실제값 : [7 2 1 ... 4 5 6]
# 313/313 [==============================] - 1s 4ms/step
# array([[ 969,    1,    0,    0,    0,    2,    3,    1,    3,    1],
#        [   0, 1128,    2,    1,    0,    1,    0,    1,    2,    0],
#        [   1,    3, 1006,    7,    2,    1,    1,    6,    5,    0],
#        [   0,    0,    3,  990,    0,    5,    0,    5,    7,    0],
#        [   3,    2,    1,    0,  951,    0,    5,    1,    2,   17],
#        [   2,    0,    0,    6,    1,  873,    4,    0,    5,    1],
#        [   3,    2,    0,    1,    2,    1,  947,    0,    2,    0],
#        [   1,    4,    6,    2,    0,    0,    0, 1002,    5,    8],
#        [   0,    0,    1,    2,    1,    0,    1,    7,  959,    3],
#        [   0,    4,    0,    4,    6,    2,    0,    2,    5,  986]],
#       dtype=int64)

# %%
# 실제값과 예측값이 다른 갯수(방법1)
cnt = 0
for i, row in enumerate(cmatrix):
    for j, data in enumerate(row):
        if i!=j:
            cnt += data
print('예측이 틀린 갯수 :', cnt)
# Out:
# 예측이 틀린 갯수 : 189

# %%
# 실제값과 예측값이 다른 갯수(방법2)
cnt = 0
for y, h in zip(y_test, yhat):
    if y!=h:
        cnt += 1
print('예측이 틀린 갯수 : ', cnt)
# Out:
# 예측이 틀린 갯수 :  189

# %%
# CNN을 사용하여 예측이 틀린 데이터 출력(yhat과 y_test가 다른 것들 189개)
plt_row = 19
plt_col = 10
plt.rcParams['figure.figsize'] = [plt_col, plt_row]
plt.rc("font", family="Malgun Gothic") # window에서 한글 시각화
# plt.rc("font", family="NanumBarunGothic") # 코랩에서 한글 시각화
fig, axes = plt.subplots(plt_row, plt_col)
plt. subplots_adjust(hspace=0.4, wspace=0.5)

i=0 # yhat과 y_test의 index => yhat[i], y_test[i]를 비교.
cnt=0 # 이미지 출력횟수

while (i<len(y_test)) & (cnt < plt_row*plt_col):
    if yhat[i] == y_test[i]:
        i += 1
        continue
    subax = axes[cnt//plt_col, cnt%plt_col] # //:몫연산자  %:나머지연산자
    subax.imshow(X_test[i].reshape(width, height))
    subax.axis('off')
    title = "y:{},h:{}({})".format(y_test[i], yhat[i],i)
    subax.set_title(title)
    cnt += 1 # 이미지 출력 번호 증가
    i += 1 # index 증가
# plt.tight_layout()

# %% [markdown]
# # CNN(컨볼루션 레이어 포함) - 교안 31page

# %%
# 1. 데이터 생성 및 전처리
width=28; height=28
(X_train, y_train), (X_test, y_test)= mnist.load_data()
X_val = X_train[50000:]
y_val = y_train[50000:]
X_train = X_train[:50000]
y_train = y_train[:50000]
# 독립변수 (28,28) => 784 1차원 -> 실수형변환 -> 스케일조정
X_train = X_train.reshape(-1, width*height).astype('float32')/255.0
X_val = X_val.reshape(-1, width*height).astype('float32')/255.0
X_test = X_test.reshape(-1, width*height).astype('float32')/255.0
# 타겟변수 원핫인코딩
Y_train = to_categorical(y_train)
Y_val = to_categorical(y_val)
Y_test = to_categorical(y_test)

X_train.shape, Y_train.shape, X_val.shape, Y_val.shape, X_test.shape, Y_test.shape
# Out:
# ((50000, 784),
#  (50000, 10),
#  (10000, 784),
#  (10000, 10),
#  (10000, 784),
#  (10000, 10))

# %%
# 2. 모델생성
