# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:98% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:20pt;}
div.text_cell_render.rendered_html{font-size:18pt;}
div.text_cell_render.rendered_html{font-size:15pt;}
div.output {font-size:18pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:18pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:18pt;padding:5px;}
table.dataframe{font-size:18px;}
</style>
"""))
# Out:
# <style>
# div.container{width:98% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:20pt;}
# div.text_cell_render.rendered_html{font-size:18pt;}
# div.text_cell_render.rendered_html{font-size:15pt;}
# div.output {font-size:18pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:18pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:18pt;padding:5px;}
# table.dataframe{font-size:18px;}
# </style>

# %% [markdown]
# # ※ ①naver open API를 활용하여 네이버지식인 "전주여행"과 "경주여행"을 검색(re ? )후 백업 -> ②품사태깅 백업 -> ③명사만 추출 -> ④빈도분석(DataFrame) 후 백업 -> ⑤빈도 시각화(워드클라우드, Text) -> ⑥word2Vec
#
# # 1. 네이버 open API를 활용하여 검색 추출
# - 검색어, no, title, link, description, title+ ' ' + description(total_text)

# %%
# pip install python-dotenv
# pip install python-decouple
import os
os.getcwd() # 현재 작업디렉토리
# Out:
# 'C:\\ai_x\\source\\07_자연어처리'

# %%
# %ls .env
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 3664-591E
#
#  C:\ai_x\source\07_자연어처리 디렉터리
#
# 2025-06-18  오후 05:49                56 .env
#                1개 파일                  56 바이트
#                0개 디렉터리  131,978,850,304 바이트 남음

# %%
from dotenv import load_dotenv
load_dotenv()

# print(os.getenv('Client_ID'))
# print(os.getenv('Client_Secret'))
# Out:
# True

# %%
from decouple import config
# print(config('Client_ID'))
# print(config('Client_Secret'))

# %%
# 네이버 개발자 센터 document에 있는 내용 그냥 그대로 가져와 봄
import os
import sys
import urllib.request
client_id = os.getenv('Client_ID')
client_secret = os.getenv('Client_Secret')
encText = urllib.parse.quote("경주 여행")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8')[:500])
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Thu, 19 Jun 2025 14:35:56 +0900",
# 	"total":931188,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>경주 여행<\/b>코스 루지월드 해방감을 느꼈어요",
# 			"link":"https:\/\/blog.naver.com\/sangil00\/223903211939",
# 			"description":"오랜만에 활기차고 건강하게 하루를 보낼 수 있었고요. 날씨 좋은 계절에 경주를 방문하신다면 루지월드를 꼭 <b>경주 여행<\/b>코스에 넣어보시길 바라요. 정말 후회 없는 경험이 될 거예요. #<b>경주여행<\/b>코스 #루지월드",
# 			"bloggername":"길을 찾는 즐거움_거칠부",
# 			"bloggerlink":"blog.naver.com\/sangil00",
# 			"postdate":"20250618"
# 		},
# 		{
# 			"title":"당일치기 <

# %%
# 패키지 import
import requests
import time
import os
import json # response 텍스트를 json 딕셔너리로
from html import unescape # description에 있는 &lt;(특수문자)을 <으로 변경, &gt;-> >
import pandas as pd
import re

# %%
query = "경주 여행"
start = 1
url = f"https://openapi.naver.com/v1/search/kin.json?query={query}&display=100&start={start}"
headers = {"X-Naver-Client-Id":client_id,
           "X-Naver-Client-Secret":client_secret}
response = requests.get(url, headers=headers)
items = json.loads(response.text)['items']
print(len(items))
print(items[51],items[58])
# Out:
# 100
# {'title': '<b>경주 여행</b> 코스 어디가★', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=277365452&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8', 'description': '가족들이랑 <b>경주여행</b>을 가려고 하는데 !! <b>경주 여행</b> 코스를 어떻게 해야할지 모르겟네요!! <b>경주 여행</b> 코스 어디가 좋을까요? 사실 중학교때 가보고 안가봤어요 <b>경주 여행</b>코스 가장 핫플레이스만 가보고 싶어요!! 혹시 <b>경주 여행</b>코스 다들... '} {'title': '<b>경주 여행</b>!! 황리단길 맛집추천', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=901&docId=451834956&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8', 'description': '이번주에 <b>경주여행</b> 가는데 황리단길 근처로 맛집 많이 추천해주세요 ~ 뚜벅이라 거리멀면 힘들어요 ㅠㅠ <b>경주 여행</b>을 위한 황리단길 맛집 추천과 황리단 맛집과 경주 맛집은 매일 많은 분들이 줄을 오랫동안 서서 기다려 먹는 곳과 배달... '}

# %%
item = items[58]
title = item['title']
link = item['link']
description = item['description']
print(title, link, description, sep='\n')
# Out:
# <b>경주 여행</b>!! 황리단길 맛집추천
# https://kin.naver.com/qna/detail.naver?d1id=9&dirId=901&docId=451834956&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8
# 이번주에 <b>경주여행</b> 가는데 황리단길 근처로 맛집 많이 추천해주세요 ~ 뚜벅이라 거리멀면 힘들어요 ㅠㅠ <b>경주 여행</b>을 위한 황리단길 맛집 추천과 황리단 맛집과 경주 맛집은 매일 많은 분들이 줄을 오랫동안 서서 기다려 먹는 곳과 배달...

# %%
# 위의 title의 <b>태그 없애기, description의 <b>태그 없애고 html의 특수문자 없애기
item = items[58]
title = item['title'].replace('<b>', ' ').replace('</b>', ' ')
link = item['link']
description = item['description'].replace('<b>', ' ').replace('</b>', ' ')
description = unescape(description) # html 특수문자 처리(&lt; -> <로 대체)
print(title, link, description, sep='\n')
# Out:
#  경주 여행 !! 황리단길 맛집추천
# https://kin.naver.com/qna/detail.naver?d1id=9&dirId=901&docId=451834956&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8
# 이번주에  경주여행  가는데 황리단길 근처로 맛집 많이 추천해주세요 ~ 뚜벅이라 거리멀면 힘들어요 ㅠㅠ  경주 여행 을 위한 황리단길 맛집 추천과 황리단 맛집과 경주 맛집은 매일 많은 분들이 줄을 오랫동안 서서 기다려 먹는 곳과 배달...

# %%
import re
description = "#추억여행 ####ktx 타고 @짱@ ㅎㅎㅎ ㅠㅠ ㅋㅋ"

# %%
# 네이버 API 계정 정보
from dotenv import load_dotenv
import os
load_dotenv()
client_id = os.getenv('Client_ID')
client_secret = os.getenv('Client_Secret')
queries = ['전주 여행', '경주 여행']
max_start = 5

# %%
def get_search_element_save(query, start):
    headers = {'X-Naver-Client-Id':client_id,
           'X-Naver-Client-Secret':client_secret}
    url = f'https://openapi.naver.com/v1/search/kin.json?query={query}&display=100&start={start+1}'
    response = requests.get(url, headers=headers)
    items = json.loads(response.text)['items']
    for i, item in enumerate(items):
        title = item['title'].replace('<b>', ' ').replace('</b>', ' ')
        link = item['link']
        description = item['description'].replace('<b>', ' ').replace('</b>', ' ')
#         print('수정전 :', description)
        description = unescape(description) # html 특수문자 처리(&lt; -> <로 대체)
        description = re.sub(r'[^a-zA-Z0-9가-힣]', ' ', description)
        description = re.sub('\s+', ' ', description)
#         print('수정후 :', description)
        # print(query, (start*100+i+1), title, link, description, title+' ' +description)
        with open(file_name, 'a', encoding='utf-8') as file:
            file.write('{}\t{}\t{}\t{}\t{}\t{}\n'.format(query, 
                                                         start*100+i+1,
                                                         title,
                                                         link,
                                                         description, 
                                                         title + ' ' +description))

# %%
# 데이터를 저장할 파일 생성 (naver_kin.txt)하고 title 저장
file_name = 'data/naver_kin.csv'
with open(file_name, 'w', encoding='utf-8') as file:
    file.write('{}\t{}\t{}\t{}\t{}\t{}\n'.format('query', 
                            'no','title','link', 'description', 'total_text'))

# %%
for query in queries:
    for start in range(max_start):
        print(start, query, '읽는 중')
        get_search_element_save(query, start)
        time.sleep(0.5)
# Out:
# 0 전주 여행 읽는 중
# 1 전주 여행 읽는 중
# 2 전주 여행 읽는 중
# 3 전주 여행 읽는 중
# 4 전주 여행 읽는 중
# 0 경주 여행 읽는 중
# 1 경주 여행 읽는 중
# 2 경주 여행 읽는 중
# 3 경주 여행 읽는 중
# 4 경주 여행 읽는 중

# %%
def get_search_element_return(query, start):
    headers = {'X-Naver-Client-Id':client_id,
           'X-Naver-Client-Secret':client_secret}
    url = f'https://openapi.naver.com/v1/search/kin.json?query={query}&display=100&start={start+1}'
    response = requests.get(url, headers=headers)
    items = json.loads(response.text)['items']
    result = []
    for i, item in enumerate(items):
        title = item['title'].replace('<b>', ' ').replace('</b>', ' ')
        link = item['link']
        description = item['description'].replace('<b>', ' ').replace('</b>', ' ')
#         print('수정전 :', description)
        description = unescape(description) # html 특수문자 처리(&lt; -> <로 대체)
        description = re.sub(r'[^a-zA-Z0-9가-힣]', ' ', description)
        description = re.sub('\s+', ' ', description)
#         print('수정후 :', description)
        # print(query, (start*100+i+1), title, link, description, title+' ' +description)
        result.append({'query':query,
                      'no':start*100+i+1,
                      'title':title,
                      'link':link,
                      'description':description,
                      'total_text':title+ ' ' + description})
    return result

# %%
result = []
for query in queries:
    for start in range(1, max_start):
        print(start, query, '읽는 중')
        result.extend(get_search_element_return(query, start))
        time.sleep(0.5)
df = pd.DataFrame(result)
df.to_csv('data/naver_kin.csv', index=False, sep='\t')
# Out:
# 1 전주 여행 읽는 중
# 2 전주 여행 읽는 중
# 3 전주 여행 읽는 중
# 4 전주 여행 읽는 중
# 1 경주 여행 읽는 중
# 2 경주 여행 읽는 중
# 3 경주 여행 읽는 중
# 4 경주 여행 읽는 중

# %% [markdown]
# # 2. 품사 태깅 저장

# %%
import pandas as pd
df = pd.read_csv('data/naver_kin.csv', sep='\t')
df.head(2)
# Out:
#    query   no                   title  \
# 0  전주 여행  101           전주여행 갈려고하는데요!
# 1  전주 여행  102   전주  1박 2일  여행  관련 질문~
#
#                                                 link  \
# 0  https://kin.naver.com/qna/detail.naver?d1id=9&...
# 1  https://kin.naver.com/qna/detail.naver?d1id=9&...
#
#                                          description  \
# 0   전주여행 을 갈려고하는데요 아는사람과 갈려고하는데 호텔은 좋은가격에 정했고 음 2...
# 1   전주 여행 을 계획하고 계시다니 정말 좋은 선택을 하셨네요 전주는 한옥마을과 함께...
#
#                                           total_text
# 0   전주여행 갈려고하는데요!  전주여행 을 갈려고하는데요 아는사람과 갈려고하는데 호텔...
# 1   전주  1박 2일  여행  관련 질문~  전주 여행 을 계획하고 계시다니 정말 좋...

# %%
df_list = df[['query','no','total_text']].values.tolist()
df_list[::500]
# Out:
# [['전주 여행',
#   101,
#   ' 전주여행 갈려고하는데요!  전주여행 을 갈려고하는데요 아는사람과 갈려고하는데 호텔은 좋은가격에 정했고 음 2박3일여행인데 얼마정도갖고가면좋을까요 그리고 맛집같은거 카페같은거 추천해주세요 안녕하세요 전주 여행 계획 중이시네요 한옥마을 근처 '],
#  ['경주 여행',
#   201,
#   '어머니랑 1박2일  경주여행  이제 5월달 어버이날을 위해 어머니랑 경주 여행 을 할려고합니다 놀러갈데는 다 정했는데 펜션을 안녕하세요 어버이날을 맞아 어머니와 함께 경주 여행 을 계획 중이시군요 특별한 시간을 보내시려는 마음이 느껴져서 더욱 ']]

# %%
from konlpy.tag import Komoran, Kkma, Hannanum, Okt
from mecab import MeCab
analyzer = MeCab()
stopwords = ['전주','경주','여행']
select_pos = ['NNG', 'NNP']

# %%
postagged_lst = []
for i, row in enumerate(df_list):
    query = row[0]
    no = row[1]
    text = row[2]
    text_pos = analyzer.pos(text)
    # analyzer가 MeCab이 아닐 경우 시간이 좀 걸려서 250개마다 로그 출력
#     if i%250==0:
#         print("{}의 {}번째 품사태깅 결과 {}개 저장중".format(query, 
#                                                 no, 
#                                                 len(text_pos), end='\n\n'))
    for token, pos in text_pos:
        # if token not in stopwords and pos in select_pos: 라고 하면 명사만 추출
        if token not in stopwords and len(token)>1: # 모든 품사를 우선 다 넣고 나중에 빼려면
            postagged_lst.append({'query':query,
                                 'no':no,
                                 'token':token,
                                 'pos':pos})
df_postagged = pd.DataFrame(postagged_lst)
df_postagged
# Out:
#        query   no token    pos
# 0      전주 여행  101   갈려고  VV+EC
# 1      전주 여행  101   는데요     EF
# 2      전주 여행  101   갈려고  VV+EC
# 3      전주 여행  101   는데요     EC
# 4      전주 여행  101    사람    NNG
# ...      ...  ...   ...    ...
# 19361  경주 여행  500    참고    NNG
# 19362  경주 여행  500    쭈니    NNP
# 19363  경주 여행  500    아빠    NNG
# 19364  경주 여행  500   블로그    NNG
# 19365  경주 여행  500    방문    NNG
#
# [19366 rows x 4 columns]

# %%
df_postagged.to_csv('data/naver_kin_pos.csv', index=False, sep='\t')

# %% [markdown]
# # 3. 명사만 추출

# %%
df_postagged = pd.read_csv('data/naver_kin_pos.csv', sep='\t')

# %%
df_nouns = df_postagged.loc[df_postagged['pos'].isin(['NNP', 'NNG']),
                            ['query', 'token','pos']]
df_nouns.head()
# Out:
#     query token  pos
# 4   전주 여행    사람  NNG
# 7   전주 여행    호텔  NNG
# 8   전주 여행    가격  NNG
# 11  전주 여행    얼마  NNG
# 12  전주 여행    정도  NNG

# %%
df_nouns.to_csv('data/naver_kin_pos_nouns.csv', index=False, sep='\t')

# %% [markdown]
# # 4. 빈도분석(DataFrame) 후 백업

# %%
df_nouns = pd.read_csv('data/naver_kin_pos_nouns.csv', sep='\t')
df_nouns.shape
# Out:
# (11275, 3)

# %%
df_nouns.iloc[::5000]
# Out:
#        query token  pos
# 0      전주 여행    사람  NNG
# 5000   전주 여행    호수  NNG
# 10000  경주 여행    카페  NNG

# %%
df_nouns.groupby(['query','token'], as_index=False)['pos'].count()
# Out:
#      query token  pos
# 0    경주 여행    가격    8
# 1    경주 여행    가능   19
# 2    경주 여행   가본적    4
# 3    경주 여행    가성    4
# 4    경주 여행    가시    4
# ..     ...   ...  ...
# 863  전주 여행    환급    4
# 864  전주 여행    회관    4
# 865  전주 여행    휴가    4
# 866  전주 여행    휴무    4
# 867  전주 여행    흐노    4
#
# [868 rows x 3 columns]

# %%
df_token_grp = df_nouns.groupby('query')['token'].value_counts()
df_token_grp
# Out:
# query  token
# 경주 여행  코스       358
#        추천       321
#        계획       125
#        숙소       112
#        맛집        96
#                ...
# 전주 여행  동네         2
#        모주         2
#        선택         2
#        자연         2
#        찜질방        1
# Name: token, Length: 868, dtype: int64

# %%
df_token_grp = df_token_grp.reset_index(name='token_count')
df_token_grp.head()
# Out:
#    query token  token_count
# 0  경주 여행    코스          358
# 1  경주 여행    추천          321
# 2  경주 여행    계획          125
# 3  경주 여행    숙소          112
# 4  경주 여행    맛집           96

# %%
# 전주 여행과 경우 여행 여행 빈도 추출
import numpy as np
a = pd.DataFrame([['단어1', 90],
                 ['단어2',80]], columns=['단어','경주빈도'])
b = pd.DataFrame([['단어1', 99],
                 ['단어3',81]], columns=['단어','전주빈도'])
display(a)
display(b)
ab = pd.merge(a, b, 
         how='outer', # inner(공통), left, right, outer
         on='단어')   # 두 프레임을 어떤 열 기준으로 합칠지 지정
#pd.concat([a, b], axis=1)
ab.fillna(0, inplace=True)
ab['경주빈도'] = ab['경주빈도'].astype(np.int16)
ab['전주빈도'] = ab['전주빈도'].astype('int')
ab.info()
# Out:
#     단어  경주빈도
# 0  단어1    90
# 1  단어2    80
#     단어  전주빈도
# 0  단어1    99
# 1  단어3    81
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   단어      3 non-null      object
#  1   경주빈도    3 non-null      int16
#  2   전주빈도    3 non-null      int32
# dtypes: int16(1), int32(1), object(1)
# memory usage: 66.0+ bytes

# %%
df_gj = df_token_grp.loc[df_token_grp['query']=='경주 여행', ['token','token_count']]
df_jj = df_token_grp.loc[df_token_grp['query']=='전주 여행', ['token','token_count']]
df_gj.shape, df_jj.shape
# Out:
# ((456, 2), (412, 2))

# %%
df_gj.head()
# Out:
#   token  token_count
# 0    코스          358
# 1    추천          321
# 2    계획          125
# 3    숙소          112
# 4    맛집           96

# %%
df_jj.head()
# Out:
#     token  token_count
# 456    코스          386
# 457    여수          280
# 458    주달          244
# 459    추천          240
# 460    맛집          230

# %%
df_mrg = pd.merge(df_gj, df_jj, how='outer', on='token')
print(df_mrg.shape)
df_mrg
# Out:
# (701, 3)
#     token  token_count_x  token_count_y
# 0      코스          358.0          386.0
# 1      추천          321.0          240.0
# 2      계획          125.0           48.0
# 3      숙소          112.0           48.0
# 4      맛집           96.0          230.0
# ..    ...            ...            ...
# 696    일본            NaN            3.0
# 697    주변            NaN            3.0
# 698    동네            NaN            2.0
# 699    모주            NaN            2.0
# 700   찜질방            NaN            1.0
#
# [701 rows x 3 columns]

# %%
df_mrg.columns = ['token','경주빈도','전주빈도']
df_mrg.fillna(0, inplace=True)
df_mrg['경주빈도'] = df_mrg['경주빈도'].astype('int')
df_mrg['전주빈도'] = df_mrg['전주빈도'].astype(np.int64) # 'int64'
df_mrg
# Out:
#     token  경주빈도  전주빈도
# 0      코스   358   386
# 1      추천   321   240
# 2      계획   125    48
# 3      숙소   112    48
# 4      맛집    96   230
# ..    ...   ...   ...
# 696    일본     0     3
# 697    주변     0     3
# 698    동네     0     2
# 699    모주     0     2
# 700   찜질방     0     1
#
# [701 rows x 3 columns]

# %%
df_mrg['빈도합'] = df_mrg['경주빈도'] + df_mrg['전주빈도']
df_mrg['전주비율'] = df_mrg['전주빈도'] / df_mrg['빈도합']
df_mrg['경주비율'] = df_mrg['경주빈도'] / df_mrg['빈도합']
df_mrg.head(10)
# Out:
#   token  경주빈도  전주빈도  빈도합      전주비율      경주비율
# 0    코스   358   386  744  0.518817  0.481183
# 1    추천   321   240  561  0.427807  0.572193
# 2    계획   125    48  173  0.277457  0.722543
# 3    숙소   112    48  160  0.300000  0.700000
# 4    맛집    96   230  326  0.705521  0.294479
# 5    일정    92    64  156  0.410256  0.589744
# 6    질문    92    62  154  0.402597  0.597403
# 7    답변    84    45  129  0.348837  0.651163
# 8    부탁    84    60  144  0.416667  0.583333
# 9    가족    76    16   92  0.173913  0.826087

# %%
df_mrg_srt = df_mrg.sort_values(by=['빈도합'], ascending=False)
df_mrg_srt
# Out:
#     token  경주빈도  전주빈도  빈도합      전주비율      경주비율
# 0      코스   358   386  744  0.518817  0.481183
# 1      추천   321   240  561  0.427807  0.572193
# 4      맛집    96   230  326  0.705521  0.294479
# 456    여수     0   280  280  1.000000  0.000000
# 457    주달     0   244  244  1.000000  0.000000
# ..    ...   ...   ...  ...       ...       ...
# 698    동네     0     2    2  1.000000  0.000000
# 454   스테이     1     0    1  0.000000  1.000000
# 453    소록     1     0    1  0.000000  1.000000
# 452    권역     1     0    1  0.000000  1.000000
# 700   찜질방     0     1    1  1.000000  0.000000
#
# [701 rows x 6 columns]

# %%
df_mrg_srt['전주비율'] = df_mrg_srt['전주비율'].apply(lambda x : "{:.2%}".format(x))
df_mrg_srt['경주비율'] = df_mrg_srt['경주비율'].apply(lambda x : "{:.2%}".format(x))
df_mrg_srt
# Out:
#     token  경주빈도  전주빈도  빈도합     전주비율     경주비율
# 0      코스   358   386  744   51.88%   48.12%
# 1      추천   321   240  561   42.78%   57.22%
# 4      맛집    96   230  326   70.55%   29.45%
# 456    여수     0   280  280  100.00%    0.00%
# 457    주달     0   244  244  100.00%    0.00%
# ..    ...   ...   ...  ...      ...      ...
# 698    동네     0     2    2  100.00%    0.00%
# 454   스테이     1     0    1    0.00%  100.00%
# 453    소록     1     0    1    0.00%  100.00%
# 452    권역     1     0    1    0.00%  100.00%
# 700   찜질방     0     1    1  100.00%    0.00%
#
# [701 rows x 6 columns]

# %%
df_mrg_srt.reset_index(drop=True, inplace=True)
df_mrg_srt
# Out:
#     token  경주빈도  전주빈도  빈도합     전주비율     경주비율
# 0      코스   358   386  744   51.88%   48.12%
# 1      추천   321   240  561   42.78%   57.22%
# 2      맛집    96   230  326   70.55%   29.45%
# 3      여수     0   280  280  100.00%    0.00%
# 4      주달     0   244  244  100.00%    0.00%
# ..    ...   ...   ...  ...      ...      ...
# 696    동네     0     2    2  100.00%    0.00%
# 697   스테이     1     0    1    0.00%  100.00%
# 698    소록     1     0    1    0.00%  100.00%
# 699    권역     1     0    1    0.00%  100.00%
# 700   찜질방     0     1    1  100.00%    0.00%
#
# [701 rows x 6 columns]

# %%
df_mrg_srt.to_csv('data/naver_kin_pos_nouns_count.txt', sep='\t')

# %% [markdown]
# # 5. 빈도 시각화(워드클라우드, Text)

# %%
df_nouns = pd.read_csv('data/naver_kin_pos_nouns.csv', sep='\t')
print(df_nouns.shape)
df_nouns.iloc[::3000]
# Out:
# (11275, 3)
#       query token  pos
# 0     전주 여행    사람  NNG
# 3000  전주 여행   덕진구  NNP
# 6000  경주 여행  어버이날  NNP
# 9000  경주 여행    학생  NNG

# %%
df_nouns['pos'].unique()
# Out:
# array(['NNG', 'NNP'], dtype=object)

# %%
df_gj_noun = df_nouns.loc[df_nouns['query']=='경주 여행','token'].to_list()
df_jj_noun = df_nouns.loc[df_nouns['query']=='전주 여행','token'].to_list()
print(df_gj_noun[:5])
print(df_jj_noun[:5])
gj = ' '.join(df_gj_noun)
jj = ' '.join(df_jj_noun)
print(gj[:10])
print(jj[:10])
# Out:
# ['일정', '일정', '문자', '계획', '소록']
# ['사람', '호텔', '가격', '얼마', '정도']
# 일정 일정 문자 계
# 사람 호텔 가격 얼

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
color_map = "Blues"
font_path = 'data/NanumPenScript-Regular.ttf'

# %%
import numpy as np
from PIL import Image
mask = np.array(Image.open('data/heart.jpg'))
불용어 = set(['여행'])
wordcloud = WordCloud(
    background_color='white',
    colormap=color_map,
    collocations=True, # 특정단어가 자주 같이 나오면 같이 뿌려 ex황리단같은거는 같이
    max_words=200,
    max_font_size=200,
    scale=2, # 이미지 크기의 비율(다운로드시 달라짐)
    random_state=777,
    font_path = font_path,
    stopwords=불용어,
    mask = mask,
    contour_color='blue',
    contour_width=1
).generate(gj)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# 생성된 wordcloud 저장
wordcloud.to_file('data/naver_kin_경주.jpg')

# %%
import numpy as np
from PIL import Image
mask = np.array(Image.open('data/korea-house-black-fill.png'))
불용어 = set(['여행'])
wordcloud = WordCloud(
    background_color='white',
    colormap=color_map,
    collocations=True, # 특정단어가 자주 같이 나오면 같이 뿌려 ex황리단같은거는 같이
    max_words=200,
    max_font_size=100,
    scale=2, # 이미지 크기의 비율(다운로드시 달라짐)
    random_state=777,
    font_path = font_path,
    stopwords=불용어,
    mask = mask,
    contour_color='blue',
    contour_width=1
).generate(jj)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# 생성된 wordcloud 저장
wordcloud.to_file('data/naver_kin_전주.jpg')

# %% [markdown]
# # 6. Word2Vec

# %%
import pandas as pd
df = pd.read_csv('data/naver_kin.csv', sep='\t')
df.sample()
# Out:
#      query   no    title                                               link  \
# 304  전주 여행  405   전주 여행   https://kin.naver.com/qna/detail.naver?d1id=9&...
#
#                                            description  \
# 304  전주로 커플여행 가려고 하는데 추천 좀 해주세요 숙소는 잡았고 놀거리랑 맛집 등등 ...
#
#                                             total_text
# 304   전주 여행  전주로 커플여행 가려고 하는데 추천 좀 해주세요 숙소는 잡았고 놀거리...

# %%
total_text_list = df['total_text'].to_list()
total_text_list[-2:]
# Out:
# ['2박  경주여행  11월 중순에 남편과 경주여행 을 계획하고 있는데요 처음 가보는곳이라 첫날은 황남관한옥호텔 에서 1박하고 이튿날은 청공한옥스테이에서 1박 총 2박3일 계획인데요 여행스케쥴을 어떻게 ',
#  ' 경주 여행 지 추천  2 부산을 벗어난 경주 여행 지 알려주세요 3 당일치기로 경주 여행 코스 밑에 자세하게 권역별로 여행코스를 소개했습니다 경주여행 이 처음이라면 대릉원 첨성대 참고로 쭈니아빠 블로그를 방문하시면 경주여행 ']

# %%
select_pos = ['NNP', 'NNG'] # Komoran, Kkma, MeCab의 일반명사, 고유명사
# select_pos = ['Noun'] # Okt의 일반명사, 고유명사
# select_pos = ['NC', 'NQ']# Hannanum의 보통명사, 고유명사
불용어 = {'여행'}

# %%
# %%time
from konlpy.tag import Komoran, Kkma, Hannanum, Okt
from mecab import MeCab
analyzer = MeCab()
total_noun_list = []
for total_text in total_text_list:
    noun_list = [token for token, tag in analyzer.pos(total_text) 
                     if tag in select_pos and 
                             len(token)>1 and
                             token not in 불용어] # 명사, 2글자이상, 불용어제외
    total_noun_list.append(noun_list)
# Out:
# CPU times: total: 688 ms
# Wall time: 688 ms

# %%
print(total_noun_list[-2:])
# Out:
# [['경주', '중순', '남편', '경주', '계획', '첫날', '황남', '호텔', '이튿날', '청공', '옥스', '테이', '계획'], ['경주', '추천', '부산', '경주', '당일', '경주', '코스', '권역', '코스', '소개', '경주', '처음', '대릉원', '첨성대', '참고', '쭈니', '아빠', '블로그', '방문', '경주']]

# %%
from gensim.models import Word2Vec
model = Word2Vec(total_noun_list, window=10, min_count=2, workers=-1, 
                 sg=1) # 소량데이터에 더 잘 맞음

# %%
model.wv.most_similar('전주')
# Out:
# [('궁원', 0.3641005754470825),
#  ('중요', 0.21867415308952332),
#  ('콘도', 0.21632219851016998),
#  ('관광객', 0.2159893959760666),
#  ('시내', 0.21469099819660187),
#  ('엑스포', 0.2134207934141159),
#  ('걸음', 0.20914912223815918),
#  ('교육', 0.20906010270118713),
#  ('초코파이', 0.2070489227771759),
#  ('새벽', 0.20607852935791016)]

# %%
model.wv.most_similar('경주')
# Out:
# [('다랭이', 0.3595535457134247),
#  ('월지', 0.2897421419620514),
#  ('할머니', 0.275379478931427),
#  ('시외버스', 0.2731468081474304),
#  ('욕조', 0.2580290138721466),
#  ('처음', 0.2295033037662506),
#  ('렌트카', 0.22023281455039978),
#  ('제주', 0.21883943676948547),
#  ('일정', 0.21617142856121063),
#  ('리의', 0.2135322391986847)]

# %%
print('2번이상 나와서 학습된 단어들 : ',list(model.wv.index_to_key))
print(len(model.wv))
# Out:
# 2번이상 나와서 학습된 단어들 :  ['경주', '전주', '코스', '추천', '맛집', '여수', '주달', '계획', '숙소', '일정', '질문', '한옥마을', '부탁', '티비', '국내', '답변', '제주', '전문', '제주도', '봉이', '언서', '한옥', '친구', '마을', '가족', '안녕', '참고', '황리', '당일치기', '관련', '정도', '택시', '이번', '예정', '준비', '공원', '근처', '시간', '버스', '이용', '아이', '엄마', '터미널', '가능', '장소', '날씨', '아래', '문화', '역사', '덕진', '관광지', '추억', '방문', '식당', '이동', '도움', '남자', '시작', '관광', '운전', '혼자', '동선', '갈만', '카페', '당일', '사람', '투어', '주말', '여자', '대중교통', '시장', '렌트', '월지', '동물원', '펜션', '아빠', '첨성대', '도착', '불국사', '비용', '부모', '동궁', '감사', '어머니', '체험', '가격', '기차', '정보', '전라도', '아들', '수목원', '박물관', '플레이스', '거리', '포항', '호텔', '처음', '소개', '가요', '첨부', '학년', '남부', '강아지', '서울', '생각', '명소', '고등학생', '볼거리', '지도', '국립', '루트', '도보', '위주', '도시', '하루', '포함', '야경', '특별', '확인', '얼마', '추석', '산책', '실패', '완산구', '게스트', '하우스', '시절', '교통편', '채택', '한국', '동안', '월드', '초등', '다음', '반려', '필요', '향교', '예약', '경험', '동반', '석굴암', '평일', '렌트카', '요소', '대부분', '경비', '한복', '시내', '마음', '선택', '음식', '부산', '토요일', '대릉원', '블로그', '저녁', '여유', '의견', '가이드', '인근', '구경', '고등학교', '기본', '자동차', '경주역', '빵집', '경기전', '천마총', '점심', '신라', '자차', '남산', '보문', '전통', '벽화', '오전', '리스트', '가을', '할머니', '블로거', '예상', '바닷가', '맞춤', '덕진구', '분위기', '최소한', '진행', '말씀', '빌라', '주요', '검색', '방법', '실내', '교통', '경북', '주신', '교통비', '조언', '바다', '오후', '친정', '고민', '내공', '남편', '예보', '중순', '관람', '정리', '문자', '쭈니', '금요일', '시외버스', '책자', '문제', '자가용', '전시회', '사이트', '방학', '부족', '순서', '입장료', '크리스마스', '가실', '초등학생', '무리', '제시', '엑스포', '교동', '제공', '수단', '요금', '황남빵', '사투리', '생략', '수원', '학생', '호수', '최적', '사월', '숙박', '대상', '복귀', '날짜', '출발', '랜드', '캐리어', '오푸스', '시기', '예산', '대표', '초코파이', '이벤트', '경주로', '정복', '난장', '그때', '어머님', '지난주', '관심', '요번', '이상', '패딩', '쿠지', '연령', '계절', '인원', '고려', '주제', '어사이즈', '최고봉', '관광객', '문화재', '고속버스', '저번', '위치', '캐리', '궁원', '절리', '주상', '어르신', '애인', '시대', '단지', '자만', '보문관광단지', '영화제', '조절', '본인', '양남', '완주', '황동', '여성', '사진', '중앙', '전동성당', '한국도로공사', '생활', '중간', '소리', '비빔', '황성', '대여', '편안', '커플', '현지인', '필수', '다면', '느낌', '미술관', '지역', '아침', '대접', '안내', '현대', '초보', '기간', '상황', '추가', '정교', '운영', '중요', '음식점', '목대', '경관', '자연', '첫날', '여학생', '황남', '기상', '감성', '에서', '천차만별', '흐노', '전망', '케이블카', '대둔산', '그램', '스로', '스타', '허락', '당장', '기관', '교육', '금액', '조선', '건물', '김선용', '요일', '웨이팅', '조정', '휴가', '변호사', '주천', '상담', '방지', '알짜배기', '전주국', '주목적', '공간', '스토리', '해설', '예약금', '일반', '결제', '현장', '상당', '음료', '기프', '환급', '항목', '에도', '법률', '세일', '장단점', '결정', '내부', '정감', '페스타', '교통수단', '보통', '관광공사', '내외', '체증', '여행지', '보리암', '다랭이', '독일', '선착순', '마감', '코로나', '하늘', '공방', '더클래식', '반양', '가운데', '다윈', '동물', '광주', '유명', '팀조', '지방', '변호', '사회', '소속', '지식', '달인', '수학', '경로', '데이트', '인당', '일식', '중식', '양식', '침대', '시설', '술값', '식비', '트레', '테마', '연인', '전통문화', '유적지', '현재', '전주식', '여행객', '건강', '유산', '중학교', '언니', '활동', '월드컵', '평지', '조금', '우양', '최초', '궁터', '왕자', '인기', '종합', '초반', '오랫동안', '매일', '배달', '경기도', '내년', '겨울', '비추', '경치', '마지막', '어른', '독채', '휴식', '군요', '코트', '경량', '용시', '수면', '감상', '작품', '포토', '재미', '공부', '답장', '잔치국수', '법주', '밀면', '움직임', '이틀', '최대한', '구체', '경험담', '예전', '가본적', '지리', '행복', '제외', '테마파크', '대공원', '원릉', '동굴', '봄바람', '객실', '개별', '바베큐', '부부', '먹거리', '구성원', '워터', '파크', '아버지', '폴라로이드', '나드리', '활용', '카테고리', '선배', '학교', '작년', '여름', '가시', '열차', '정서', '출발지', '형편', '시내버스', '자전거', '여동생', '안내소', '새벽', '카메라', '대명', '콘도', '기림사', '분황사', '부처', '무열왕릉', '황룡', '사지', '오릉', '자녀', '기온', '시즌', '신경주역', '고요', '개화', '벚꽃', '어려움', '전남', '구매', '렌터카', '랜드마크', '가여', '입장', '수학여행', '추도', '신상', '신축', '지인', '최근', '천군동', '입실', '그동안', '이맘때', '중학', '해결책', '식사', '황지', '지역민', '취향', '요즘', '경경', '한화', '리조트', '조사', '결과', '바탕', '제안', '의미', '실행', '카카오', '현황', '소요', '태교', '주식', '전일', '슈퍼', '주만', '피큐어', '평점', '한정식', '수구', '전라', '회관', '전주비빔밥', '고궁', '성미', '토종', '명품', '사용', '리의', '기지', '생일', '이동은', '욕조', '려인', '애견', '플랫', '조심', '불편', '문의', '편리', '주문', '요약', '실시간', '왕복', '기차표', '월요일', '휴무', '걱정', '오픈', '군산', '새만금', '기회', '주이', '수정', '부분', '본점', '대옥', '구용', '도로공사', '갤러리', '주박', '물관', '서신동', '대학', '공연', '연극', '억양', '거북', '의외', '전라북도', '전주시', '운송', '통상', '하트', '세염', '간식', '성수기', '시티투어', '연못', '로또',  ...
# 699

# %%
# 유사한 단어 출력
print("입력된 단어와 유사한 단어 10개를 출력합니다.")
key = input()
if key in model.wv:
    print("{}와 유사한 단어:".format(key))
    print(model.wv.most_similar(key, topn=10))
else:
    print("{} 단어가 훈련 데이터에 없음".format(key))
# Out:
# 입력된 단어와 유사한 단어 10개를 출력합니다.
# 한식
# 한식 단어가 훈련 데이터에 없음
