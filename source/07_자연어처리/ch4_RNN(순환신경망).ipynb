# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:98% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:20pt;}
div.text_cell_render.rendered_html{font-size:18pt;}
div.text_cell_render.rendered_html{font-size:15pt;}
div.output {font-size:18pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:18pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:18pt;padding:5px;}
table.dataframe{font-size:18px;}
</style>
"""))
# Out:
# <style>
# div.container{width:98% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:20pt;}
# div.text_cell_render.rendered_html{font-size:18pt;}
# div.text_cell_render.rendered_html{font-size:15pt;}
# div.output {font-size:18pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:18pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:18pt;padding:5px;}
# table.dataframe{font-size:18px;}
# </style>

# %% [markdown]
# **<font size="6" color="red">ch4. RNN(Recurrent Neural Network 순환신경망)</font>**
# # 1. 문맥을 이용하여 모델 만들기

# %%
text = """경마장에 있는 말이 뛰고 있다
그의 말이 법이다
가는 말이 고와야 오는 말이 곱다"""
text1 = "장마철이 오고 있다"

# %%
from keras_preprocessing.text import Tokenizer
t = Tokenizer()
t.fit_on_texts([text, text1])
encoded = t.texts_to_sequences([text, text1])
print(encoded)
print(t.word_index)
# Out:
# [[3, 4, 1, 5, 2, 6, 1, 7, 8, 1, 9, 10, 1, 11], [12, 13, 2]]
# {'말이': 1, '있다': 2, '경마장에': 3, '있는': 4, '뛰고': 5, '그의': 6, '법이다': 7, '가는': 8, '고와야': 9, '오는': 10, '곱다': 11, '장마철이': 12, '오고': 13}

# %%
from keras_preprocessing.text import Tokenizer
t = Tokenizer()
t.fit_on_texts([text])
encoded = t.texts_to_sequences([text])
print(encoded)
print(t.word_index)
# Out:
# [[2, 3, 1, 4, 5, 6, 1, 7, 8, 1, 9, 10, 1, 11]]
# {'말이': 1, '경마장에': 2, '있는': 3, '뛰고': 4, '있다': 5, '그의': 6, '법이다': 7, '가는': 8, '고와야': 9, '오는': 10, '곱다': 11}

# %%
# 문자열 리스트를 인덱스 시퀀스로 변환
print(t.texts_to_sequences(['경마장에 말이 있다', '말이 뛴다']))
print(t.texts_to_sequences(['가는 말이 곱다'])[0])
# Out:
# [[2, 1, 5], [1]]
# [8, 1, 11]

# %%
text = """경마장에 있는 말이 뛰고 있다
그의 말이 법이다
가는 말이 고와야 오는 말이 곱다"""

# %%
for key, value in t.word_index.items():
    print(key, value)
# Out:
# 말이 1
# 경마장에 2
# 있는 3
# 뛰고 4
# 있다 5
# 그의 6
# 법이다 7
# 가는 8
# 고와야 9
# 오는 10
# 곱다 11

# %%
# 학습을 시키기 위해 ['경마장에 있는','경마장에 있는 말이', ...]
sequences = []
for line in text.split('\n'):
    print('원문장 :', line)
    encoded = t.texts_to_sequences([line])[0]
    print('encoded된 문장 :', encoded)
    for i in range(0, len(encoded)-1): # i:시작index
        for j in range(i+2, len(encoded)+1): # j:끝나는 index바로 뒤
            sequences.append(encoded[i:j])
# print(sequences)
print('sequences와 해석 출력')
for sequence in sequences:
    for word_seq in sequence:
        for word, id in t.word_index.items():
            if word_seq==id:
                print("{}:{}".format(word_seq, word), end=' ')
                break
    print()
# Out:
# 원문장 : 경마장에 있는 말이 뛰고 있다
# encoded된 문장 : [2, 3, 1, 4, 5]
# 원문장 : 그의 말이 법이다
# encoded된 문장 : [6, 1, 7]
# 원문장 : 가는 말이 고와야 오는 말이 곱다
# encoded된 문장 : [8, 1, 9, 10, 1, 11]
# sequences와 해석 출력
# 2:경마장에 3:있는
# 2:경마장에 3:있는 1:말이
# 2:경마장에 3:있는 1:말이 4:뛰고
# 2:경마장에 3:있는 1:말이 4:뛰고 5:있다
# 3:있는 1:말이
# 3:있는 1:말이 4:뛰고
# 3:있는 1:말이 4:뛰고 5:있다
# 1:말이 4:뛰고
# 1:말이 4:뛰고 5:있다
# 4:뛰고 5:있다
# 6:그의 1:말이
# 6:그의 1:말이 7:법이다
# 1:말이 7:법이다
# 8:가는 1:말이
# 8:가는 1:말이 9:고와야
# 8:가는 1:말이 9:고와야 10:오는
# 8:가는 1:말이 9:고와야 10:오는 1:말이
# 8:가는 1:말이 9:고와야 10:오는 1:말이 11:곱다
# 1:말이 9:고와야
# 1:말이 9:고와야 10:오는
# 1:말이 9:고와야 10:오는 1:말이
# 1:말이 9:고와야 10:오는 1:말이 11:곱다
# 9:고와야 10:오는
# 9:고와야 10:오는 1:말이
# 9:고와야 10:오는 1:말이 11:곱다
# 10:오는 1:말이
# 10:오는 1:말이 11:곱다
# 1:말이 11:곱다

# %%
print([len(sequence) for sequence in sequences])
my_len = max(len(sequence) for sequence in sequences)
my_len
# Out:
# [2, 3, 4, 5, 2, 3, 4, 2, 3, 2, 2, 3, 2, 2, 3, 4, 5, 6, 2, 3, 4, 5, 2, 3, 4, 2, 3, 2]
# 6

# %%
# sequences를 훈련 가능하도록 모두 6개로 조정
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_sequences = pad_sequences(sequences=sequences,
                                maxlen=my_len,
                                # padding='post',
                                padding='pre')
padded_sequences.shape, type(padded_sequences)
padded_sequences
# Out:
# array([[ 0,  0,  0,  0,  2,  3],
#        [ 0,  0,  0,  2,  3,  1],
#        [ 0,  0,  2,  3,  1,  4],
#        [ 0,  2,  3,  1,  4,  5],
#        [ 0,  0,  0,  0,  3,  1],
#        [ 0,  0,  0,  3,  1,  4],
#        [ 0,  0,  3,  1,  4,  5],
#        [ 0,  0,  0,  0,  1,  4],
#        [ 0,  0,  0,  1,  4,  5],
#        [ 0,  0,  0,  0,  4,  5],
#        [ 0,  0,  0,  0,  6,  1],
#        [ 0,  0,  0,  6,  1,  7],
#        [ 0,  0,  0,  0,  1,  7],
#        [ 0,  0,  0,  0,  8,  1],
#        [ 0,  0,  0,  8,  1,  9],
#        [ 0,  0,  8,  1,  9, 10],
#        [ 0,  8,  1,  9, 10,  1],
#        [ 8,  1,  9, 10,  1, 11],
#        [ 0,  0,  0,  0,  1,  9],
#        [ 0,  0,  0,  1,  9, 10],
#        [ 0,  0,  1,  9, 10,  1],
#        [ 0,  1,  9, 10,  1, 11],
#        [ 0,  0,  0,  0,  9, 10],
#        [ 0,  0,  0,  9, 10,  1],
#        [ 0,  0,  9, 10,  1, 11],
#        [ 0,  0,  0,  0, 10,  1],
#        [ 0,  0,  0, 10,  1, 11],
#        [ 0,  0,  0,  0,  1, 11]])

# %%
# 독립변수(X)와 타겟변수(y)로 분리
X = padded_sequences[:, :-1]
y = padded_sequences[:, -1]
y
# Out:
# array([ 3,  1,  4,  5,  1,  4,  5,  4,  5,  5,  1,  7,  7,  1,  9, 10,  1,
#        11,  9, 10,  1, 11, 10,  1, 11,  1, 11, 11])

# %%
# X를 엠베딩 작업할 때 필요한 입력 bit 수 (단어수+1)
input_dim =len(t.word_index)+1
input_dim
# Out:
# 12

# %%
# y의 원핫인코딩
from tensorflow.keras.utils import to_categorical
Y = to_categorical(y, input_dim)
X.shape, Y.shape, input_dim
# Out:
# ((28, 5), (28, 12), 12)

# %%
# 2. 모델 생성하기
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding # Xi의 원핫인코딩한 희소행렬 변환
from tensorflow.keras.layers import SimpleRNN, Dense
import matplotlib.pyplot as plt

model = Sequential()
model.add(Embedding(input_dim=input_dim, # 12개로 원핫인코딩
                   output_dim=10, # 임베딩 출력의 갯수
                   input_length=X.shape[1])) # 입력(X)의 수
model.add(SimpleRNN(units=32))
model.add(Dense(12, activation='softmax'))
print(model.summary())
# 3. 모델 학습 과정 설정
model.compile(loss='categorical_crossentropy', 
              optimizer='adam',
              metrics=['accuracy'])
# 4. 모델 학습시키기
hist = model.fit(X, Y, epochs=300, verbose=2)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 5, 10)             120
#
#  simple_rnn_1 (SimpleRNN)    (None, 32)                1376
#
#  dense_1 (Dense)             (None, 12)                396
#
# =================================================================
# Total params: 1,892
# Trainable params: 1,892
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/300
# 1/1 - 1s - loss: 2.5075 - accuracy: 0.0714 - 993ms/epoch - 993ms/step
# Epoch 2/300
# 1/1 - 0s - loss: 2.4953 - accuracy: 0.0714 - 5ms/epoch - 5ms/step
# Epoch 3/300
# 1/1 - 0s - loss: 2.4837 - accuracy: 0.0714 - 4ms/epoch - 4ms/step
# Epoch 4/300
# 1/1 - 0s - loss: 2.4724 - accuracy: 0.0714 - 5ms/epoch - 5ms/step
# Epoch 5/300
# 1/1 - 0s - loss: 2.4613 - accuracy: 0.1071 - 4ms/epoch - 4ms/step
# Epoch 6/300
# 1/1 - 0s - loss: 2.4504 - accuracy: 0.2143 - 5ms/epoch - 5ms/step
# Epoch 7/300
# 1/1 - 0s - loss: 2.4396 - accuracy: 0.2857 - 4ms/epoch - 4ms/step
# Epoch 8/300
# 1/1 - 0s - loss: 2.4287 - accuracy: 0.2857 - 5ms/epoch - 5ms/step
# Epoch 9/300
# 1/1 - 0s - loss: 2.4177 - accuracy: 0.2857 - 4ms/epoch - 4ms/step
# Epoch 10/300
# 1/1 - 0s - loss: 2.4066 - accuracy: 0.3214 - 6ms/epoch - 6ms/step
# Epoch 11/300
# 1/1 - 0s - loss: 2.3951 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 12/300
# 1/1 - 0s - loss: 2.3834 - accuracy: 0.3214 - 6ms/epoch - 6ms/step
# Epoch 13/300
# 1/1 - 0s - loss: 2.3713 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 14/300
# 1/1 - 0s - loss: 2.3587 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 15/300
# 1/1 - 0s - loss: 2.3457 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 16/300
# 1/1 - 0s - loss: 2.3321 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 17/300
# 1/1 - 0s - loss: 2.3180 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 18/300
# 1/1 - 0s - loss: 2.3033 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 19/300
# 1/1 - 0s - loss: 2.2881 - accuracy: 0.3214 - 4ms/epoch - 4ms/step
# Epoch 20/300
# 1/1 - 0s - loss: 2.2723 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 21/300
# 1/1 - 0s - loss: 2.2560 - accuracy: 0.3214 - 6ms/epoch - 6ms/step
# Epoch 22/300
# 1/1 - 0s - loss: 2.2391 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 23/300
# 1/1 - 0s - loss: 2.2219 - accuracy: 0.3214 - 6ms/epoch - 6ms/step
# Epoch 24/300
# 1/1 - 0s - loss: 2.2043 - accuracy: 0.3214 - 4ms/epoch - 4ms/step
# Epoch 25/300
# 1/1 - 0s - loss: 2.1865 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 26/300
# 1/1 - 0s - loss: 2.1686 - accuracy: 0.3214 - 4ms/epoch - 4ms/step
# Epoch 27/300
# 1/1 - 0s - loss: 2.1507 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 28/300
# 1/1 - 0s - loss: 2.1331 - accuracy: 0.3214 - 4ms/epoch - 4ms/step
# Epoch 29/300
# 1/1 - 0s - loss: 2.1158 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 30/300
# 1/1 - 0s - loss: 2.0989 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 31/300
# 1/1 - 0s - loss: 2.0826 - accuracy: 0.3214 - 6ms/epoch - 6ms/step
# Epoch 32/300
# 1/1 - 0s - loss: 2.0668 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 33/300
# 1/1 - 0s - loss: 2.0517 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 34/300
# 1/1 - 0s - loss: 2.0369 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 35/300
# 1/1 - 0s - loss: 2.0225 - accuracy: 0.3214 - 6ms/epoch - 6ms/step
# Epoch 36/300
# 1/1 - 0s - loss: 2.0083 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 37/300
# 1/1 - 0s - loss: 1.9943 - accuracy: 0.3214 - 6ms/epoch - 6ms/step
# Epoch 38/300
# 1/1 - 0s - loss: 1.9802 - accuracy: 0.3214 - 4ms/epoch - 4ms/step
# Epoch 39/300
# 1/1 - 0s - loss: 1.9662 - accuracy: 0.3214 - 6ms/epoch - 6ms/step
# Epoch 40/300
# 1/1 - 0s - loss: 1.9523 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 41/300
# 1/1 - 0s - loss: 1.9384 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 42/300
# 1/1 - 0s - loss: 1.9247 - accuracy: 0.3214 - 18ms/epoch - 18ms/step
# Epoch 43/300
# 1/1 - 0s - loss: 1.9113 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 44/300
# 1/1 - 0s - loss: 1.8980 - accuracy: 0.3214 - 4ms/epoch - 4ms/step
# Epoch 45/300
# 1/1 - 0s - loss: 1.8850 - accuracy: 0.3214 - 7ms/epoch - 7ms/step
# Epoch 46/300
# 1/1 - 0s - loss: 1.8722 - accuracy: 0.3214 - 3ms/epoch - 3ms/step
# Epoch 47/300
# 1/1 - 0s - loss: 1.8595 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 48/300
# 1/1 - 0s - loss: 1.8469 - accuracy: 0.3571 - 6ms/epoch - 6ms/step
# Epoch 49/300
# 1/1 - 0s - loss: 1.8344 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 50/300
# 1/1 - 0s - loss: 1.8218 - accuracy: 0.4286 - 5ms/epoch - 5ms/step
# Epoch 51/300
# 1/1 - 0s - loss: 1.8093 - accuracy: 0.4286 - 5ms/epoch - 5ms/step
# Epoch 52/300
# 1/1 - 0s - loss: 1.7967 - accuracy: 0.4286 - 5ms/epoch - 5ms/step
# Epoch 53/300
# 1/1 - 0s - loss: 1.7840 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 54/300
# 1/1 - 0s - loss: 1.7713 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 55/300
# 1/1 - 0s - loss: 1.7585 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 56/300
# 1/1 - 0s - loss: 1.7455 - accuracy: 0.4643 - 3ms/epoch - 3ms/step
# Epoch 57/300
# 1/1 - 0s - loss: 1.7323 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 58/300
# 1/1 - 0s - loss: 1.7189 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 59/300
# 1/1 - 0s - loss: 1.7053 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 60/300
# 1/1 - 0s - loss: 1.6914 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 61/300
# 1/1 - 0s - loss: 1.6773 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 62/300
# 1/1 - 0s - loss: 1.6629 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 63/300
# 1/1 - 0s - loss: 1.6483 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 64/300
# 1/1 - 0s - loss: 1.6334 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 65/300
# 1/1 - 0s - loss: 1.6184 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 66/300
# 1/1 - 0s - loss: 1.6032 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 67/300
# 1/1 - 0s - loss: 1.5879 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 68/300
# 1/1 - 0s - loss: 1.5724 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 69/300
# 1/1 - 0s - loss: 1.5568 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 70/300
# 1/1 - 0s - loss: 1.5412 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 71/300
# 1/1 - 0s - loss: 1.5254 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 72/300
# 1/1 - 0s - loss: 1.5097 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 73/300
# 1/1 - 0s - loss: 1.4939 - accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 74/300
# 1/1 - 0s - loss: 1.4781 - accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 75/300
# 1/1 - 0s - loss: 1.4623 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 76/300
# 1/1 - 0s - loss: 1.4466 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 77/300
# 1/1 - 0s - loss: 1.4310 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 78/300
# 1/1 - 0s - loss: 1.4155 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 79/300
# 1/1 - 0s - loss: 1.4002 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 80/300
# 1/1 - 0s - loss: 1.3850 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 81/300
# 1/1 - 0s - loss: 1.3700 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 82/300
# 1/1 - 0s - loss: 1.3552 - accuracy: 0.5357 - 3ms/epoch - 3ms/step
# Epoch 83/300
# 1/1 - 0s - loss: 1.3406 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 84/300
# 1/1 - 0s - loss: 1.3262 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 85/300
# 1/1 - 0s - loss: 1.3121 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 86/300
# 1/1 - 0s - loss: 1.2983 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 87/300
# 1/1 - 0s - loss: 1.2847 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 88/300
# 1/1 - 0s - loss: 1.2713 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 89/300
# 1/1 - 0s - loss: 1.2583 - accuracy: 0.5714 - 5ms/epoch - 5ms/step
# Epoch 90/300
# 1/1 - 0s - loss: 1.2455 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 91/300
# 1/1 - 0s - loss: 1.2330 - accuracy: 0.5714 - 5ms/epoch - 5ms/step
# Epoch 92/300
# 1/1 - 0s - loss: 1.2207 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 93/300
# 1/1 - 0s - loss: 1.2087 - accuracy: 0.5714 - 5ms/epoch - 5ms/step
# Epoch 94/300
# 1/1 - 0s - loss: 1.1970 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 95/300
# 1/1 - 0s - loss: 1.1855 - accuracy: 0.6071 - 5ms/epoch - 5ms/step
# Epoch 96/300
# 1/1 - 0s - loss: 1.1742 - accuracy: 0.6071 - 4ms/epoch - 4ms/step
# Epoch 97/300
# 1/1 - 0s - loss: 1.1632 - accuracy: 0.6071 - 4ms/epoch - 4ms/step
# Epoch 98/300
# 1/1 - 0s - loss: 1.1525 - accuracy: 0.6071 - 3ms/epoch - 3ms/step
# Epoch 99/300
# 1/1 - 0s - loss: 1.1420 - accuracy: 0.6429 - 3ms/epoch - 3ms/step
# Epoch 100/300
# 1/1 - 0s - loss: 1.1317 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 101/300
# 1/1 - 0s - loss: 1.1216 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 102/300
# 1/1 - 0s - loss: 1.1117 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 103/300
# 1/1 - 0s - loss: 1.1020 - accuracy: 0.6429 - 6ms/epoch - 6ms/step
# Epoch 104/300
# 1/1 - 0s - loss: 1.0925 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 105/300
# 1/1 - 0s - loss: 1.0832 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 106/300
# 1/1 - 0s - loss: 1.0740 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 107/300
# 1/1 - 0s - loss: 1.0651 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 108/300
# 1/1 - 0s - loss: 1.0562 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 109/300
# 1/1 - 0s - loss: 1.0475 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 110/300
# 1/1 - 0s - loss: 1.0390 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 111/300
# 1/1 - 0s - loss: 1.0306 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 112/300
# 1/1 - 0s - loss: 1.0223 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 113/300
# 1/1 - 0s - loss: 1.0142 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 114/300
# 1/1 - 0s - loss: 1.0061 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 115/300
# 1/1 - 0s - loss: 0.9982 - accuracy: 0.6429 - 3ms/epoch - 3ms/step
# Epoch 116/300
# 1/1 - 0s - loss: 0.9904 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 117/300
# 1/1 - 0s - loss: 0.9827 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch
- accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 168/300
# 1/1 - 0s - loss: 0.6722 - accuracy: 0.7857 - 3ms/epoch - 3ms/step
# Epoch 169/300
# 1/1 - 0s - loss: 0.6675 - accuracy: 0.7857 - 5ms/epoch - 5ms/step
# Epoch 170/300
# 1/1 - 0s - loss: 0.6629 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 171/300
# 1/1 - 0s - loss: 0.6583 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 172/300
# 1/1 - 0s - loss: 0.6538 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 173/300
# 1/1 - 0s - loss: 0.6494 - accuracy: 0.7857 - 5ms/epoch - 5ms/step
# Epoch 174/300
# 1/1 - 0s - loss: 0.6450 - accuracy: 0.7857 - 5ms/epoch - 5ms/step
# Epoch 175/300
# 1/1 - 0s - loss: 0.6406 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 176/300
# 1/1 - 0s - loss: 0.6363 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 177/300
# 1/1 - 0s - loss: 0.6321 - accuracy: 0.7857 - 5ms/epoch - 5ms/step
# Epoch 178/300
# 1/1 - 0s - loss: 0.6279 - accuracy: 0.7857 - 13ms/epoch - 13ms/step
# Epoch 179/300
# 1/1 - 0s - loss: 0.6238 - accuracy: 0.7857 - 8ms/epoch - 8ms/step
# Epoch 180/300
# 1/1 - 0s - loss: 0.6197 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 181/300
# 1/1 - 0s - loss: 0.6156 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 182/300
# 1/1 - 0s - loss: 0.6116 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 183/300
# 1/1 - 0s - loss: 0.6077 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 184/300
# 1/1 - 0s - loss: 0.6037 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 185/300
# 1/1 - 0s - loss: 0.5999 - accuracy: 0.7857 - 7ms/epoch - 7ms/step
# Epoch 186/300
# 1/1 - 0s - loss: 0.5960 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 187/300
# 1/1 - 0s - loss: 0.5923 - accuracy: 0.8214 - 6ms/epoch - 6ms/step
# Epoch 188/300
# 1/1 - 0s - loss: 0.5885 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 189/300
# 1/1 - 0s - loss: 0.5848 - accuracy: 0.8214 - 6ms/epoch - 6ms/step
# Epoch 190/300
# 1/1 - 0s - loss: 0.5811 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 191/300
# 1/1 - 0s - loss: 0.5775 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 192/300
# 1/1 - 0s - loss: 0.5739 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 193/300
# 1/1 - 0s - loss: 0.5703 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 194/300
# 1/1 - 0s - loss: 0.5667 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 195/300
# 1/1 - 0s - loss: 0.5632 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 196/300
# 1/1 - 0s - loss: 0.5597 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 197/300
# 1/1 - 0s - loss: 0.5563 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 198/300
# 1/1 - 0s - loss: 0.5528 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 199/300
# 1/1 - 0s - loss: 0.5494 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 200/300
# 1/1 - 0s - loss: 0.5461 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 201/300
# 1/1 - 0s - loss: 0.5427 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 202/300
# 1/1 - 0s - loss: 0.5394 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 203/300
# 1/1 - 0s - loss: 0.5361 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 204/300
# 1/1 - 0s - loss: 0.5328 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 205/300
# 1/1 - 0s - loss: 0.5295 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 206/300
# 1/1 - 0s - loss: 0.5263 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 207/300
# 1/1 - 0s - loss: 0.5231 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 208/300
# 1/1 - 0s - loss: 0.5199 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 209/300
# 1/1 - 0s - loss: 0.5167 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 210/300
# 1/1 - 0s - loss: 0.5135 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 211/300
# 1/1 - 0s - loss: 0.5104 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 212/300
# 1/1 - 0s - loss: 0.5073 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 213/300
# 1/1 - 0s - loss: 0.5042 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 214/300
# 1/1 - 0s - loss: 0.5011 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch
- accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 271/300
# 1/1 - 0s - loss: 0.3584 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 272/300
# 1/1 - 0s - loss: 0.3565 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 273/300
# 1/1 - 0s - loss: 0.3547 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 274/300
# 1/1 - 0s - loss: 0.3529 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 275/300
# 1/1 - 0s - loss: 0.3511 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 276/300
# 1/1 - 0s - loss: 0.3493 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 277/300
# 1/1 - 0s - loss: 0.3475 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 278/300
# 1/1 - 0s - loss: 0.3458 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 279/300
# 1/1 - 0s - loss: 0.3440 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 280/300
# 1/1 - 0s - loss: 0.3423 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 281/300
# 1/1 - 0s - loss: 0.3407 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 282/300
# 1/1 - 0s - loss: 0.3390 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 283/300
# 1/1 - 0s - loss: 0.3374 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 284/300
# 1/1 - 0s - loss: 0.3358 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 285/300
# 1/1 - 0s - loss: 0.3342 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 286/300
# 1/1 - 0s - loss: 0.3326 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 287/300
# 1/1 - 0s - loss: 0.3310 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 288/300
# 1/1 - 0s - loss: 0.3295 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 289/300
# 1/1 - 0s - loss: 0.3280 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 290/300
# 1/1 - 0s - loss: 0.3265 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 291/300
# 1/1 - 0s - loss: 0.3250 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 292/300
# 1/1 - 0s - loss: 0.3235 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 293/300
# 1/1 - 0s - loss: 0.3221 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 294/300
# 1/1 - 0s - loss: 0.3207 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 295/300
# 1/1 - 0s - loss: 0.3192 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 296/300
# 1/1 - 0s - loss: 0.3179 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 297/300
# 1/1 - 0s - loss: 0.3165 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 298/300
# 1/1 - 0s - loss: 0.3151 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 299/300
# 1/1 - 0s - loss: 0.3138 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 300/300
# 1/1 - 0s - loss: 0.3125 - accuracy: 0.8929 - 5ms/epoch - 5ms/step

# %%
# 5. 모델 학습과정 시각화
fig, loss_ax = plt.subplots(figsize=(12,6))
loss_ax.plot(hist.history['loss'], 'y', label='train loss')
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='train accuracy')
loss_ax.set_xlabel('epochs')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')
loss_ax.legend(loc='center right')
acc_ax.legend(loc='upper left')
plt.show()

# %%
# 모델 사용하기 (경마장에 있는 말이 -> 뛰고)
input_word = input('입력단어 :')
encoded = t.texts_to_sequences([input_word])[0]
input_data = pad_sequences([encoded], maxlen=my_len-1, padding='pre')
print('입력데이터 :', input_data)
result = model.predict(input_data, verbose=0).argmax()
word = t.index_word[result]
print('예측된 단어 :', word)
# Out:
# 입력단어 :가는 말이
# 입력데이터 : [[0 0 0 8 1]]
# 예측된 단어 : 고와야

# %%
t.texts_to_sequences(['없는 단어'])
# Out:
# [[]]

# %% [markdown]
# # 2. 다음 문맥 예측해 보기

# %%
# "경마장에" 이후에 올 단어 3개 예측 -> 경마장에 있는 말이 뛰고
def sentence_generation(current_word, n):
    #print('입력된 단어 :', current_word)
    for i in range(1, n+1):
        encoded = t.texts_to_sequences([current_word])[0]
        input_data = pad_sequences([encoded], maxlen=my_len-1, padding='pre')
        result = model.predict(input_data, verbose=0).argmax()
        word = t.index_word[result]
        current_word = current_word + ' ' + word
#         print("{}번째 생성 문맥 {} ({}{})".format(i,
#                                            current_word,
#                                            encoded,
#                                            result))
    return current_word
sentence_generation('경마장에', 3)
# Out:
# '경마장에 있는 말이 뛰고'

# %%
sentence_generation('가는', 5)
# Out:
# '가는 말이 고와야 오는 말이 곱다'
